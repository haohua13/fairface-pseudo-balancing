# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Pseudo-Labeling/fix_balanced_aaf_evaluation_results.csv')

initial_row = 2 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()

# Save and show
plt.tight_layout()
plt.savefig('Balanced_FixMatch_0.6_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Balanced_FixMatch_0.6_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/last_v2_FixMatch_experiments_results.csv')

initial_row = 72 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Unbalanced_FixMatch_0.9_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Unbalanced_FixMatch_0.9_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/last_v2_FixMatch_experiments_results.csv')

initial_row = 62 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Unbalanced_FixMatch_0.6_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Unbalanced_FixMatch_0.6_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Pseudo-Labeling/fix_balanced_aaf_evaluation_results.csv')

initial_row = 12 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.savefig('Balanced_FixMatch_0.9_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Balanced_FixMatch_0.9_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Pseudo-Labeling/fix_balanced_aaf_evaluation_results.csv')

initial_row = 12 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best General Accuracy')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Lowest Gender Gap')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Unbalanced_FixMatch_0.9_Final.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/last_v2_FixMatch_experiments_results.csv')

initial_row = 82 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Unbalanced_FixMatch_0.6_East_Asian_Female_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Unbalanced_FixMatch_0.6_East_Asian_Female_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/last_v2_FixMatch_experiments_results.csv')

initial_row = 92 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Unbalanced_FixMatch_0.9_East_Asian_Female_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Unbalanced_FixMatch_0.9_East_Asian_Female_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FixMatch_experiments_results.csv')
initial_row = 310 - 2
number_iterations = 5
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Balanced_FixMatch_0.9_East_Asian_Female_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Balanced_FixMatch_0.9_East_Asian_Female_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FixMatch_experiments_results.csv')
initial_row = 302 - 2
number_iterations = 5
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('Balanced_FixMatch_0.6_East_Asian_Female_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('Balanced_FixMatch_0.6_East_Asian_Female_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FixMatch_experiments_results.csv')

initial_row = 307 - 2
number_iterations = 3
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best General Accuracy')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Lowest Gender Gap')

# Labels and title
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=12)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)

# Customize ticks
plt.xticks(iterations, fontsize=10)
plt.yticks(fontsize=10)

# Save and show
plt.tight_layout()
plt.savefig('Severe_East_Asian_Unbalanced_FixMatch_0.6_Final.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FlexMatch_experiments_results.csv')

initial_row = 110 - 2
number_iterations = 5
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)
# Save and show
plt.tight_layout()
plt.savefig('FlexMatch_Balanced_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('FlexMatch_Balanced_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/final_FlexMatch_experiments_results.csv')

initial_row = 62 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=12)

# Legend and grid
plt.legend(loc='best', ncol=4, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=10)
plt.yticks(fontsize=10)

# Save and show
plt.tight_layout()
plt.savefig('FlexMatch_Unbalanced_Final.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/final_FlexMatch_experiments_results.csv')

initial_row = 92 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)
# Save and show
plt.tight_layout()
plt.savefig('FlexMatch_balanced_East_Asian_Female_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('FlexMatch_balanced_East_Asian_Female_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/final_FlexMatch_experiments_results.csv')

initial_row = 102 - 2
number_iterations = 10
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best Acc')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Best SR')

# Labels and title
# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)
# Save and show
plt.tight_layout()
plt.savefig('FlexMatch_Unbalanced_East_Asian_Female_Final_v2.png', dpi=300, bbox_inches='tight')
plt.savefig('FlexMatch_Unbalanced_East_Asian_Female_Final_v2.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FlexMatch_experiments_results.csv')

initial_row = 115 - 2
number_iterations = 3
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best General Accuracy')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Lowest Gender Gap')

# Labels and title
# Labels and title
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=14)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=14)
plt.grid(True, linestyle='--', alpha=0.3)

# Customize ticks
plt.xticks(iterations, fontsize=16)
plt.yticks(fontsize=16)

# Save and show
plt.tight_layout()
plt.savefig('FlexMatch_Unbalanced_Final.png', dpi=300, bbox_inches='tight')
plt.savefig('FlexMatch_Unbalanced_Final.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

plt.rcParams['font.family'] = 'Arial'

data = pd.read_csv('../Controlled-Bias-Experiments/all_FlexMatch_experiments_results.csv')

initial_row = 134 - 2
number_iterations = 3
iterations = np.arange(1, number_iterations+1)
end_row = initial_row + number_iterations

general_acc = data['Accuracy'][initial_row:end_row].to_numpy()
female_acc = data['Female Accuracy'][initial_row:end_row].to_numpy()
male_acc = data['Male Accuracy'][initial_row:end_row].to_numpy()

baseline = 73.28
male_baseline = 97.94
female_baseline = 48.61
difference = np.abs(np.array(male_acc) - np.array(female_acc))
best_iteration = np.argmin(difference) + 1
best_general_acc = np.argmax(general_acc) + 1


plt.figure(figsize=(10, 6))

# Plot accuracy lines
plt.plot(iterations, general_acc, label='General', marker='o', color='#1f77b4', linewidth=2)
plt.plot(iterations, male_acc, label='Male', marker='s', color='#ff7f0e', linewidth=2)
plt.plot(iterations, female_acc, label='Female', marker='d', color='#9467bd', linewidth=2)

# Plot baselines
plt.axhline(y=baseline, color='#7f7f7f', linestyle='--', linewidth=1.5, label='Baseline')
plt.axhline(y=male_baseline, color='#ffbb78', linestyle='--', linewidth=1.5, label='Male Baseline')
plt.axhline(y=female_baseline, color='#c5b0d5', linestyle='--', linewidth=1.5, label='Female Baseline')

# Plot vertical lines for best iteration and lowest gender gap
plt.axvline(x=best_general_acc, color='#17becf', linestyle='--', linewidth=1.5, label='Best General Accuracy')
plt.axvline(x=best_iteration, color='#e377c2', linestyle='--', linewidth=1.5, label='Lowest Gender Gap')

# Labels and title
plt.xlabel('Iterations', fontsize=12)
plt.ylabel('AAF Test Set Accuracy [%]', fontsize=12)

# Legend and grid
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)

# Customize ticks
plt.xticks(iterations, fontsize=10)
plt.yticks(fontsize=10)

# Save and sho
plt.tight_layout()
plt.savefig('FlexMatch_Unbalanced_Severe_East_Asian_Final.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(10,6))


def plot_scatter(x1, y1, x2, y2, color, label1, label2):
    ax.scatter(x1, y1, c=color, marker='o', s=150, edgecolors='black', label=label1)
    ax.scatter(x2, y2, c=color, marker='s', facecolors='none', s=150, label = label2)

    ax.annotate("", xy=(x1, y1), xytext=(x2, y2),
                arrowprops=dict(arrowstyle="->", lw=2, color='gray'))


# Plot FairFace
plot_scatter(80.05, 76.8, 76.92, 59.93, 'gold', r'FF ϵ = 0.6 (PB)', r'FF ϵ= 0.6') 
plot_scatter(79.81, 93.80, 75.73, 55.59, 'gold', r'FF ϵ = 0.9 (PB)', r'FF ϵ= 0.9') # best result with pseudo-balancing
plot_scatter(76.11, 70.83, 71.47, 45.42, 'gold', r'G-B FF ϵ = 0.6 (PB)', r'FF ϵ= 0.6')
plot_scatter(78.65, 63.91, 72.86, 41.71, 'gold', r'G-B FF ϵ = 0.9 (PB)', r'FF ϵ= 0.9')


# Repeat for all comparable pairs...

ax.set_ylabel('Selection Rate [%]', fontsize=12)
ax.set_xlabel('Accuracy [%]', fontsize=12)
ax.grid(alpha=0.3)
ax.legend(bbox_to_anchor=(1.05,1))
plt.tight_layout()
# save as png
plt.savefig('Selection_Rate_Accuracy_FixMatch_FairFace.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

plt.style.use('seaborn-v0_8-poster')  # High-contrast style for presentations
fig, ax = plt.subplots(figsize=(12, 8))

def plot_scatter(acc_pb, sel_pb, acc_npb, sel_npb, dataset, eps):
    color = dataset_colors[dataset]
    
    # Pseudo-balanced point
    ax.scatter(acc_pb, sel_pb, 
               marker=pb_props['marker'], 
               s=pb_props['size'],
               facecolors=color,
               edgecolors='k',
               linewidths=1.5,
               label=f'{dataset} ε={eps} (PB)',
               )
    
    # Non-pseudo-balanced point
    ax.scatter(acc_npb, sel_npb,
               marker=npb_props['marker'],
               s=npb_props['size'],
               facecolors='white' if pb_props['face'] == 'full' else color,
               edgecolors=color,
               linewidths=1.5,
               label=f'{dataset} ε={eps}')
    
    # Comparison arrow (colored by epsilon)
    arrow_color = '#1f77b4' if eps == 0.6 else '#ff7f0e'
    ax.annotate("", xy=(acc_pb, sel_pb), xytext=(acc_npb, sel_npb),
                arrowprops=dict(arrowstyle="-|>", lw=2.5, color='k', alpha=0.7))
    # Compute the direction vector of the arrow
    dx = acc_pb - acc_npb
    dy = sel_pb - sel_npb

    # Compute angle in degrees
    angle = np.degrees(np.arctan2(dy, dx)) - 45


    # Normalize and scale for offset
    offset_factor = 0.3  # Adjust if needed
    norm = np.sqrt(dx**2 + dy**2)
    offset_x = -offset_factor * dy / norm  # Perpendicular shift
    offset_y = offset_factor * dx / norm  # Perpendicular shift

    # Compute the new text position
    text_x = (acc_npb + acc_pb) / 2 - offset_x
    text_y = (sel_npb + sel_pb) / 2 - offset_y

    # Add epsilon text with rotation
    ax.text(text_x, text_y, f'$\\mathbf{{\epsilon={eps}}}$', 
            fontsize=16, color='black', ha='center', va='center',
            rotation=angle, rotation_mode='anchor')  # Aligns with arrow
    
    

# Color scheme - dataset categories
dataset_colors = {
    'FairFace': 'b',                   # Blue for FairFace
    'Gender-Balanced': 'r',    # Red for Gender-Balanced
    # 'Severe East-Asian FF': '#2ca02c',  # Green for East-Asian
    # 'Severe Male FF': '#9467bd',        # Purple for Male
    # 'Severe Black FF': '#8c564b',       # Brown for Black
    # 'Severe Female FF': '#e377c2'       # Pink for Female
}

# Marker and edge properties
pb_props = {'marker': 's', 'face': 'full', 'size': 180}  # Square for PB
npb_props = {'marker': 'o', 'face': 'full', 'size': 180} # Circle for non-PB


# Color scheme by epsilon with visual distinction
eps_colors = {0.6: '#1f77b4', 0.9: '#ff7f0e'}  # Colorblind-friendly

# Plot all dataset comparisons


plot_scatter(80.05, 76.8, 76.92, 59.93, 'FairFace', 0.6)
plot_scatter(79.81, 93.8, 75.73, 55.59, 'FairFace', 0.9)
plot_scatter(76.11, 70.83, 71.47, 45.42, 'Gender-Balanced', 0.6)
plot_scatter(78.65, 63.91, 72.86, 41.71, 'Gender-Balanced', 0.9)


# plot baseline just scatter
ax.scatter(73.28, 49.63, 
           marker='d', s=150, 
              facecolors='k',
              edgecolors='k',

           linewidths=1.5, label='Baseline')
# also plot the lines of baseline
ax.plot([73.28, 73.28], [0, 100], color='k', linestyle='--', linewidth=1.5, alpha = 0.5 )
ax.plot([0, 100], [49.63, 49.63], color='k', linestyle='--', linewidth=1.5, alpha = 0.5)


# Highlight best result
best_result = (79.8, 93.8) 
ax.scatter(best_result[0], best_result[1], 
           marker='*', s=100,
           facecolors='gold', 
           edgecolors='k', 
           linewidths=1.5,
           zorder=10)
ax.annotate(f"{best_result[0]}% Acc\n{best_result[1]}% SR", 
            xy=best_result, 
            xytext=(80, -10),
            textcoords='offset points',
            ha='center',
            bbox=dict(boxstyle='round,pad=0.5', fc='gold', alpha=0.9),
            fontsize=20)

# Formatting for MIPR2025
ax.set_ylabel('Selection Rate [%]', fontsize=20, labelpad=10)
ax.set_xlabel('Accuracy [%]', fontsize=20, labelpad=10)
ax.set_title('Pseudo-Balancing Effect on Accuracy and Selection Rate', fontsize=16, pad=20)
ax.grid(alpha=0.2)
ax.set_xlim(70, 83)
ax.set_ylim(35, 100)
# Comprehensive legend
legend_elements = [
    Line2D([0], [0], marker='d', color='w', label='Baseline',
                  markerfacecolor='k', markersize=15, markeredgecolor='k'),
    # Dataset colors as color patches
    *[mpatches.Patch(color=color, label=name) for name, color in dataset_colors.items()],
    
    # Best result as a star marker
    Line2D([0], [0], marker='*', color='w', label='Best Model',
                  markerfacecolor='gold', markersize=20)
]

ax.legend(handles=legend_elements, 
          loc='upper left',
          framealpha=1, fontsize = 20)

plt.tight_layout()
plt.savefig('FixMatch_FairFace_ACC_SR.png', dpi=300, 
            bbox_inches='tight', transparent=False)
# SAVE AS PDF
plt.savefig('FixMatch_FairFace_ACC_SR.pdf', dpi=600, 
            bbox_inches='tight', transparent=False)

#

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

plt.style.use('seaborn-v0_8-poster')  # High-contrast style for presentations
fig, ax = plt.subplots(figsize=(12, 8))

def plot_scatter(acc_pb, sel_pb, acc_npb, sel_npb, dataset, eps):
    color = dataset_colors[dataset]
    
    # Pseudo-balanced point
    ax.scatter(acc_pb, sel_pb, 
               marker=pb_props['marker'], 
               s=pb_props['size'],
               facecolors=color,
               edgecolors='k',
               linewidths=1.5,
               label=f'{dataset} ε={eps} (PB)')
    
    # Non-pseudo-balanced point
    ax.scatter(acc_npb, sel_npb,
               marker=npb_props['marker'],
               s=npb_props['size'],
               facecolors='white' if pb_props['face'] == 'full' else color,
               edgecolors=color,
               linewidths=1.5,
               label=f'{dataset} ε={eps}')
    
    # Comparison arrow (colored by epsilon)
    arrow_color = '#1f77b4' if eps == 0.6 else '#ff7f0e'
    ax.annotate("", xy=(acc_pb, sel_pb), xytext=(acc_npb, sel_npb),
                arrowprops=dict(arrowstyle="-|>", lw=2.5, color=arrow_color, alpha=1))





# Color scheme - dataset categories
dataset_colors = {
    # 'FairFace': 'b',                   # Blue for FairFace
    # 'Gender-Balanced': 'r',    # Red for Gender-Balanced
    'East Asian Female': 'tab:cyan',
    'Black': 'tab:olive',
    'Male': 'g',
    # 'East Asian': 'tab:purple',
    'Female': 'tab:pink',

}
# Marker and edge properties
pb_props = {'marker': 's', 'face': 'full', 'size': 180}  # Square for PB
npb_props = {'marker': 'o', 'face': 'full', 'size': 180} # Circle for non-PB


# Color scheme by epsilon with visual distinction
eps_colors = {0.6: '#1f77b4', 0.9: '#ff7f0e'}  # Colorblind-friendly

# Plot all dataset comparisons


# plot_scatter(83.36, 86.03, 79.18, 74.77, 'FairFace', 0)
# plot_scatter(67.49, 42.19, 45.44, 53.04, 'Gender-Balanced', 0)
plot_scatter(69.04, 42.01, 79.08, 81.79, 'East Asian Female', 0.6)
plot_scatter(71.63, 48.82, 81.30, 84.78, 'East Asian Female', 0.9)
plot_scatter(70.70, 49.71, 67.83, 36.79, 'Black', 0.6)
plot_scatter(74.41, 53.87, 71.35, 44.08, 'Black', 0.9)
plot_scatter(78.11, 70.96, 79.40, 69.83, 'Male', 0.6)
plot_scatter(76.74, 57.93, 78.65, 65.76, 'Male', 0.9)
plot_scatter(67.12, 36.61, 77.00, 63.05, 'Female', 0.6)
plot_scatter(76.19, 55.71, 78.86, 64.58, 'Female', 0.9)

# plot baseline just scatter
ax.scatter(73.28, 49.63, 
           marker='d', s=150, 
              facecolors='k',
              edgecolors='k',
           linewidths=1.5, label='Baseline')
# also plot the lines of baseline
ax.plot([73.28, 73.28], [0, 100], color='k', linestyle='--', linewidth=1.5, alpha = 0.5 )
ax.plot([0, 100], [49.63, 49.63], color='k', linestyle='--', linewidth=1.5, alpha = 0.5)

# Highlight best result
best_result = (81.30, 84.8) 
ax.scatter(best_result[0], best_result[1], 
           marker='*', s=100,
           facecolors='gold', 
           edgecolors='k', 
           linewidths=1.5,
           zorder=10)
ax.annotate(f"{best_result[0]}% Acc\n{best_result[1]}% SR", 
            xy=best_result, 
            xytext=(15, 25),
            textcoords='offset points',
            ha='center',
            bbox=dict(boxstyle='round,pad=0.5', fc='gold', alpha=0.9),
            fontsize=20)

# Formatting for MIPR2025
ax.set_ylabel('Selection Rate [%]', fontsize=20, labelpad=10)
ax.set_xlabel('Accuracy [%]', fontsize=20, labelpad=10)
ax.set_title('Pseudo-Balancing Effect on Accuracy and Selection Rate', fontsize=16, pad=20)
ax.grid(alpha=0.2)

# Comprehensive legend
legend_elements = [
    Line2D([0], [0], marker='d', color='w', label='Baseline',
                  markerfacecolor='k', markersize=15, markeredgecolor='k'),
    # Dataset colors as color patches
    *[mpatches.Patch(color=color, label=name) for name, color in dataset_colors.items()],

    # patch for epsilon
    Line2D([0], [0], color=eps_colors[0.6], label='ε=0.6', alpha=0.7),
    Line2D([0], [0], color=eps_colors[0.9], label='ε=0.9', alpha=0.7),

    # Best result as a star marker
    Line2D([0], [0], marker='*', color='w', label='Best Model',
                  markerfacecolor='gold', markersize=20)
]


ax.legend(handles=legend_elements, 
          loc='upper left',
          framealpha=1)

ax.set_xlim(65, 85)
ax.set_ylim(30, 100)
plt.tight_layout()
plt.savefig('FixMatch_FairFace_BIASED_ACC_SR.png', dpi=300, 
            bbox_inches='tight', transparent=False)
# save as pdf
plt.savefig('FixMatch_FairFace_BIASED_ACC_SR.pdf', dpi=600, 
            bbox_inches='tight', transparent=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

plt.style.use('seaborn-v0_8-poster')  # High-contrast style for presentations
fig, ax = plt.subplots(figsize=(12, 8))

def plot_scatter(acc_pb, sel_pb, acc_npb, sel_npb, dataset, eps):
    color = dataset_colors[dataset]
    
    # Pseudo-balanced point
    ax.scatter(acc_pb, sel_pb, 
               marker=pb_props['marker'], 
               s=pb_props['size'],
               facecolors=color,
               edgecolors='k',
               linewidths=1.5,
               label=f'{dataset} ε={eps} (PB)')
    
    # Non-pseudo-balanced point
    ax.scatter(acc_npb, sel_npb,
               marker=npb_props['marker'],
               s=npb_props['size'],
               facecolors='white' if pb_props['face'] == 'full' else color,
               edgecolors=color,
               linewidths=1.5,
               label=f'{dataset} ε={eps}')
    
    # Comparison arrow (colored by epsilon)
    arrow_color = '#1f77b4' if eps == 0.6 else '#ff7f0e'
    ax.annotate("", xy=(acc_pb, sel_pb), xytext=(acc_npb, sel_npb),
                arrowprops=dict(arrowstyle="-|>", lw=2.5, color='k', alpha=0.7))
    # Compute the midpoint of the arrow
    mid_x = (acc_npb + acc_pb) / 2
    mid_y = (sel_npb + sel_pb) / 2

    # Add the epsilon value in bold and black at the midpoint of the arrow
    if eps != 0:
        ax.text(mid_x, mid_y, f'$\\mathbf{{\epsilon={eps}}}$', 
                fontsize=10, color='black', ha='center', va='center')
    

# Color scheme - dataset categories
dataset_colors = {
    'FairFace': 'b',                   # Blue for FairFace
    'Gender-Balanced': 'r',    # Red for Gender-Balanced
    'East Asian Female': 'tab:cyan',
    'Black': 'tab:olive',
    'Male': 'g',
    'East Asian': 'tab:purple',
    'Female': 'tab:pink',

}
# Marker and edge properties
pb_props = {'marker': 's', 'face': 'full', 'size': 180}  # Square for PB
npb_props = {'marker': 'o', 'face': 'full', 'size': 180} # Circle for non-PB


# Color scheme by epsilon with visual distinction
eps_colors = {0.6: '#1f77b4', 0.9: '#ff7f0e'}  # Colorblind-friendly

# Plot all dataset comparisons


plot_scatter(83.36, 86.03, 79.18, 74.77, 'FairFace', 0)
plot_scatter(67.49, 42.19, 45.44, 53.04, 'Gender-Balanced', 0)
plot_scatter(71.81, 72.27, 56.04, 47.37, 'East Asian Female', 0)
plot_scatter(61.87, 52.56, 53.41, 37.27, 'Black', 0)
plot_scatter(62.92, 71.86, 54.16, 21.28, 'Male', 0)
plot_scatter(50.46, 1.75, 53.37, 5.80, 'East Asian', 0)
plot_scatter(54.10, 57.96, 61.96, 24.63, 'Female', 0)


# plot baseline just scatter
ax.scatter(73.28, 49.63, 
           marker='d', s=150, 
              facecolors='k',
              edgecolors='k',
           linewidths=1.5, label='Baseline')
# also plot the lines of baseline
ax.plot([73.28, 73.28], [0, 100], color='k', linestyle='--', linewidth=1.5, alpha = 0.5 )
ax.plot([0, 100], [49.63, 49.63], color='k', linestyle='--', linewidth=1.5, alpha = 0.5)

# Highlight best result
best_result = (83.36, 86.03) 
ax.scatter(best_result[0], best_result[1], 
           marker='*', s=100,
           facecolors='gold', 
           edgecolors='k', 
           linewidths=1.5,
           zorder=10)
ax.annotate(f"{best_result[0]}% Acc\n{best_result[1]}% SR", 
            xy=best_result, 
            xytext=(0, 30),
            textcoords='offset points',
            ha='center',
            bbox=dict(boxstyle='round,pad=0.5', fc='gold', alpha=0.9),
            fontsize=20)

# Formatting for MIPR2025
ax.set_ylabel('Selection Rate [%]', fontsize=20, labelpad=10)
ax.set_xlabel('Accuracy [%]', fontsize=20, labelpad=10)
ax.set_title('Pseudo-Balancing Effect on Accuracy and Selection Rate', fontsize=16, pad=20)
ax.grid(alpha=0.2)

# Comprehensive legend
legend_elements = [
    Line2D([0], [0], marker='d', color='w', label='Baseline',
                  markerfacecolor='k', markersize=15, markeredgecolor='k'),
    # Dataset colors as color patches
    *[mpatches.Patch(color=color, label=name) for name, color in dataset_colors.items()],
    
    # Best result as a star marker
    Line2D([0], [0], marker='*', color='w', label='Best Model',
                  markerfacecolor='gold', markersize=20)
]


ax.legend(handles=legend_elements, 
          loc='upper left',
          framealpha=1)



plt.tight_layout()
plt.savefig('FlexMatch_FairFace_ACC_SR.png', dpi=300, 
            bbox_inches='tight', transparent=False)
# save as pdf
plt.savefig('FlexMatch_FairFace_ACC_SR.pdf', dpi=600, 
            bbox_inches='tight', transparent=False)

# %%
import pandas as pd

# Load the results from FixMatch experiments
results_fix = pd.read_csv('../Controlled-Bias-Experiments/last_v2_FixMatch_experiments_results.csv')
results_combined = results_fix

# Classify models as balanced or unbalanced based on their filenames
results_combined['Model Type'] = results_combined['Model'].apply(
    lambda x: 'Unbalanced' if '_unbalanced_' in x else ('Balanced' if '_balanced_' in x else 'Unknown')
)

# Filter out rows with 'Unknown' model type (if any)
results_combined = results_combined[results_combined['Model Type'] != 'Unknown']

# Calculate gender disparity (absolute difference between male and female accuracy)
results_combined['Gender Disparity'] = abs(results_combined['Male Accuracy'] - results_combined['Female Accuracy'])

# Initialize lists to store the best models
best_models = []

# Iterate over each dataset
for dataset in results_combined['Test Dataset'].unique():
    # Filter the results for the current dataset
    dataset_results = results_combined[results_combined['Test Dataset'] == dataset]
    
    # Iterate over each model folder within the dataset
    for model_folder in dataset_results['Model Folder'].unique():
        # Filter the results for the current model folder
        folder_results = dataset_results[dataset_results['Model Folder'] == model_folder]
        
        # Iterate over balanced and unbalanced models
        for model_type in ['Balanced', 'Unbalanced']:
            # Filter the results for the current model type
            type_results = folder_results[folder_results['Model Type'] == model_type]
            
            if not type_results.empty:
                # Find the model with the highest accuracy
                best_accuracy_row = type_results.loc[type_results['Accuracy'].idxmax()]
                best_models.append({
                    'Test Dataset': dataset,
                    'Model Folder': model_folder,
                    'Model Type': model_type,
                    'Best Metric': 'Accuracy',
                    'Model': best_accuracy_row['Model'],
                    'Accuracy': best_accuracy_row['Accuracy'],
                    'Male Accuracy': best_accuracy_row['Male Accuracy'],
                    'Female Accuracy': best_accuracy_row['Female Accuracy'],
                    'Gender Disparity': best_accuracy_row['Gender Disparity']
                })
                
                # Find the model with the lowest gender disparity
                best_disparity_row = type_results.loc[type_results['Gender Disparity'].idxmin()]
                best_models.append({
                    'Test Dataset': dataset,
                    'Model Folder': model_folder,
                    'Model Type': model_type,
                    'Best Metric': 'Gender Disparity',
                    'Model': best_disparity_row['Model'],
                    'Accuracy': best_disparity_row['Accuracy'],
                    'Male Accuracy': best_disparity_row['Male Accuracy'],
                    'Female Accuracy': best_disparity_row['Female Accuracy'],
                    'Gender Disparity': best_disparity_row['Gender Disparity']
                })

# Combine the results into a single DataFrame
best_models_df = pd.DataFrame(best_models)

# Save the results to a new CSV file
best_models_df.to_csv('v2_fix_models_by_dataset.csv', index=False)

print("Best models saved to 'v2_fix_models_by_dataset.csv'")
# Out:
# Best models saved to 'v2_fix_models_by_dataset.csv'

# %%
import pandas as pd

# Load the results from FixMatch and FlexMatch experiments
results_flex = pd.read_csv('../Controlled-Bias-Experiments/final_FlexMatch_experiments_results.csv')
results_combined = results_flex

# Classify models as balanced or unbalanced based on their filenames
results_combined['Model Type'] = results_combined['Model'].apply(
    lambda x: 'Unbalanced' if '_unbalanced_' in x else ('Balanced' if 'FlexMatch_' in x else 'Unknown')
)

# Filter out rows with 'Unknown' model type (if any)
results_combined = results_combined[results_combined['Model Type'] != 'Unknown']

# Calculate gender disparity (absolute difference between male and female accuracy)
results_combined['Gender Disparity'] = abs(results_combined['Male Accuracy'] - results_combined['Female Accuracy'])

# Initialize lists to store the best models
best_models = []

# Iterate over each dataset
for dataset in results_combined['Dataset'].unique():
    # Filter the results for the current dataset
    dataset_results = results_combined[results_combined['Dataset'] == dataset]
    
    # Iterate over each model folder within the dataset
    for model_folder in dataset_results['Model Folder'].unique():
        # Filter the results for the current model folder
        folder_results = dataset_results[dataset_results['Model Folder'] == model_folder]
        
        # Iterate over balanced and unbalanced models
        for model_type in ['Balanced', 'Unbalanced']:
            # Filter the results for the current model type
            type_results = folder_results[folder_results['Model Type'] == model_type]
            
            if not type_results.empty:
                # Find the model with the highest accuracy
                best_accuracy_row = type_results.loc[type_results['Accuracy'].idxmax()]
                best_models.append({
                    'Dataset': dataset,
                    'Model Folder': model_folder,
                    'Model Type': model_type,
                    'Best Metric': 'Accuracy',
                    'Model': best_accuracy_row['Model'],
                    'Accuracy': best_accuracy_row['Accuracy'],
                    'Male Accuracy': best_accuracy_row['Male Accuracy'],
                    'Female Accuracy': best_accuracy_row['Female Accuracy'],
                    'Gender Disparity': best_accuracy_row['Gender Disparity']
                })
                
                # Find the model with the lowest gender disparity
                best_disparity_row = type_results.loc[type_results['Gender Disparity'].idxmin()]
                best_models.append({
                    'Dataset': dataset,
                    'Model Folder': model_folder,
                    'Model Type': model_type,
                    'Best Metric': 'Gender Disparity',
                    'Model': best_disparity_row['Model'],
                    'Accuracy': best_disparity_row['Accuracy'],
                    'Male Accuracy': best_disparity_row['Male Accuracy'],
                    'Female Accuracy': best_disparity_row['Female Accuracy'],
                    'Gender Disparity': best_disparity_row['Gender Disparity']
                })

# Combine the results into a single DataFrame
best_models_df = pd.DataFrame(best_models)

# Save the results to a new CSV file
best_models_df.to_csv('v2_flex_models_by_dataset.csv', index=False)

print("Best models saved to 'best_flex_models_by_dataset.csv'")
# Out:
# Best models saved to 'best_flex_models_by_dataset.csv'
