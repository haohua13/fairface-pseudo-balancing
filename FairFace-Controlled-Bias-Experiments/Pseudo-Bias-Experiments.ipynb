# %% [markdown]
# ### 1. First Generate the FairFace Bias-Controlled Datasets

# %%
# print number of samples in training and number of female and male samples in training
import os
import numpy as np
import pandas as pd 
# Define the paths
data_dir = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset"
training_path = os.path.join(data_dir, "Training") 
training_labels_path = os.path.join("../Pseudo-Labeling/FairFace/train_labels.csv")  # Path to training metadata

# Load training metadata
file = pd.read_csv(training_labels_path)
male_samples = file[file['gender']=='Male']
female_samples = file[file['gender']=='Female']

print("Number of samples in training: ", len(file))
print(len(male_samples))
print(len(female_samples))
# Out:
# Number of samples in training:  86744
# 45986
# 40758

# %%
import os
import shutil
import pandas as pd
from tqdm.auto import tqdm

# Define the paths
data_dir = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset"
training_path = os.path.join(data_dir, "Training") 
training_labels_path = os.path.join("../Pseudo-Labeling/FairFace/train_labels.csv")  # Path to training metadata

# Define the output folders
data_dir = "bias_training_data"
output_folders = {
    "Unlabeled": os.path.join(data_dir, "Unlabeled"),
    "Gender_Balanced_Unlabeled": os.path.join(data_dir, "Gender_Balanced_Unlabeled"),
    "Severe_Male_Gender": os.path.join(data_dir, "Severe_Male_Gender"),
    "Severe_Female_Gender": os.path.join(data_dir, "Severe_Female_Gender"),
    "Severe_Black_Bias": os.path.join(data_dir, "Severe_Black_Bias"),
    "Severe_East_Asian_Bias": os.path.join(data_dir, "Severe_East_Asian_Bias"),
    "Severe_Black_Male_Bias": os.path.join(data_dir, "Severe_Black_Male_Bias"),
    "Severe_Black_Female_Bias": os.path.join(data_dir, "Severe_Black_Female_Bias"),
    "Severe_East_Asian_Female_Bias": os.path.join(data_dir, "Severe_East_Asian_Female_Bias")
}

# Ensure output directories exist
for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

# Load training metadata
training_data = pd.read_csv(training_labels_path)

# Function to copy files based on criteria
def copy_files(file_list, gender_list, source_dir, dest_dir):
    for file, gender in tqdm(zip(file_list, gender_list), desc=f"Copying files to {dest_dir}"):
        gender_folder = "male" if gender == "Male" else "female"
        file_path = os.path.join(source_dir, gender_folder, file)
        file_path = file_path.replace("\\train", "")
        if os.path.exists(file_path):
            shutil.copy(file_path, dest_dir)
        else:
            print(f"Warning: {file_path} does not exist.")
# 1. Unlabeled - contains all the training samples
copy_files(training_data["file"], training_data["gender"], training_path, output_folders["Unlabeled"])

# 2. Gender_Balanced_Unlabeled - 50% male and 50% female
male_samples = training_data[training_data["gender"] == "Male"].sample(frac=0.5, random_state=42)
female_samples = training_data[training_data["gender"] == "Female"].sample(frac=0.5, random_state=42)
gender_balanced_samples = pd.concat([male_samples, female_samples])
copy_files(gender_balanced_samples["file"], gender_balanced_samples["gender"], training_path, output_folders["Gender_Balanced_Unlabeled"])

# 3. Severe_Male_Gender - 80% male and 20% female
male_samples = training_data[training_data["gender"] == "Male"].sample(frac=0.8, random_state=42)
female_samples = training_data[training_data["gender"] == "Female"].sample(frac=0.2, random_state=42)
severe_male_gender_samples = pd.concat([male_samples, female_samples])
copy_files(severe_male_gender_samples["file"], severe_male_gender_samples["gender"], training_path, output_folders["Severe_Male_Gender"])

# 4. Severe_Female_Gender - 80% female and 20% male
female_samples = training_data[training_data["gender"] == "Female"].sample(frac=0.8, random_state=42)
male_samples = training_data[training_data["gender"] == "Male"].sample(frac=0.2, random_state=42)
severe_female_gender_samples = pd.concat([female_samples, male_samples])
copy_files(severe_female_gender_samples["file"], severe_female_gender_samples["gender"], training_path, output_folders["Severe_Female_Gender"])

# 5. Severe_Black_Bias - All samples of Black race
black_samples = training_data[training_data["race"] == "Black"]
copy_files(black_samples["file"], black_samples["gender"], training_path, output_folders["Severe_Black_Bias"])

# 6. Severe_East_Asian_Bias - All samples of East Asian race
east_asian_samples = training_data[training_data["race"] == "East Asian"]
copy_files(east_asian_samples["file"], east_asian_samples["gender"], training_path, output_folders["Severe_East_Asian_Bias"])

# 7. Severe_Black_Male_Bias - All samples of Black and Male
black_male_samples = training_data[(training_data["race"] == "Black") & (training_data["gender"] == "Male")]
copy_files(black_male_samples["file"], black_male_samples["gender"], training_path, output_folders["Severe_Black_Male_Bias"])

# 8. Severe_Black_Female_Bias - All samples of Black and Female
black_female_samples = training_data[(training_data["race"] == "Black") & (training_data["gender"] == "Female")]
copy_files(black_female_samples["file"], black_female_samples["gender"], training_path, output_folders["Severe_Black_Female_Bias"])

# 9. Severe_East_Asian_Female_Bias - All samples of East Asian and Female
east_asian_female_samples = training_data[(training_data["race"] == "East Asian") & (training_data["gender"] == "Female")]
copy_files(east_asian_female_samples["file"], east_asian_female_samples["gender"], training_path, output_folders["Severe_East_Asian_Female_Bias"])

print("Dataset organization complete.")
# Out:
# Copying files to bias_training_data\Unlabeled: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Gender_Balanced_Unlabeled: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_Male_Gender: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_Female_Gender: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_Black_Bias: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_East_Asian_Bias: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_Black_Male_Bias: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_Black_Female_Bias: 0it [00:00, ?it/s]
# Copying files to bias_training_data\Severe_East_Asian_Female_Bias: 0it [00:00, ?it/s]
# Dataset organization complete.

# %%
validation_path = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation"
test_path = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/Balanced_Validation"

# %% [markdown]
# ### 2. Then Evaluate with Pseudo-Labeling, Pseudo-Balancing and DANN

# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np

import requests

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")
test_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/Balanced_Validation")

# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Unlabeled",
    "Gender_Balanced_Unlabeled",
    "Severe_Male_Gender",
    "Severe_Female_Gender",
    "Severe_Black_Bias"
]
pseudo_label_thresholds = [0.9, 0.6]

# Define the transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# Define model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Self-training parameters
num_iterations = 5
num_epochs = 10
patience = 2

# Function to pseudo-balance the dataset
def pseudo_balancing(male_path, female_path):
    male_samples = os.listdir(male_path) if os.path.exists(male_path) else []
    female_samples = os.listdir(female_path) if os.path.exists(female_path) else []
    num_male = len(male_samples)
    num_female = len(female_samples)
    # Determine the target size for balancing
    target_size = min(num_male, num_female)
    # Randomly downsample the larger class
    if num_male > target_size:
        excess_male_samples = np.random.choice(male_samples, num_male - target_size, replace=False)
        for sample in excess_male_samples:
            os.remove(os.path.join(male_path, sample))
    elif num_female > target_size:
        excess_female_samples = np.random.choice(female_samples, num_female - target_size, replace=False)
        for sample in excess_female_samples:
            os.remove(os.path.join(female_path, sample))
    # Recount samples after balancing
    num_male = len(os.listdir(male_path))
    num_female = len(os.listdir(female_path))
    print(f"Balanced pseudo-labeled samples: Male - {num_male}, Female - {num_female}")
    return

# Loop over all experiments
for training_folder in training_folders:
 # Define the URL for the file
    url = "https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EVd9bFWzqztMrXRDdNnCHQkBsHaM4n5_1q1fue77vtQVtw?download=1"

    # Define the path where the file will be saved
    output_path = "classification_model.pth"
    # Send a GET request to download the file
    response = requests.get(url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        with open(output_path, "wb") as file:
            file.write(response.content)  # Write the content of the response to the file
        print(f"File downloaded successfully and saved as {output_path}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
    # Load pre-trained ResNet model
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    for pseudo_label_threshold in pseudo_label_thresholds:
        print(f"--- Starting Experiment: {training_folder}, Threshold: {pseudo_label_threshold} ---")
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Balanced_{training_folder}_{pseudo_label_threshold}")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_{pseudo_label_threshold}")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        for iteration in range(num_iterations):
            print(f"--- Starting Iteration {iteration + 1}/{num_iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling
            model.eval()
            new_samples = 0
            print("Pseudo-labeling unlabeled samples...")
            for filename in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, filename)
                img = Image.open(img_path).convert('RGB')  # Make sure it's RGB
                img = transforms_val(img)  # Apply transformations
                # Forward pass through the model
                with torch.no_grad():
                    inputs = img.unsqueeze(0).to(device)  # Unsqueeze to add batch dimension
                    outputs = model(inputs)
                    probs = torch.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                # Select samples with high confidence
                confident_mask = max_probs > pseudo_label_threshold
                if confident_mask.any():
                    for pred_label in preds[confident_mask]:
                        if pred_label == 1:
                            destination_folder = aaf_training_male_path
                        elif pred_label == 0:
                            destination_folder = aaf_training_female_path
                        else:
                            continue  # Skip samples with unexpected labels
                        # Move the image to the destination folder
                        shutil.copy(img_path, destination_folder)
                new_samples += 1
                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")
                del img, inputs, outputs, probs, max_probs, preds
                torch.cuda.empty_cache()

            print(f"Iteration {iteration + 1}: Added {new_samples} pseudo-labeled samples.")
            print(f"Number of pseudo-labeled male {len(os.listdir(aaf_training_male_path))} and female {len(os.listdir(aaf_training_female_path))} samples")

            # 3. Balance the training dataset
            pseudo_balancing(aaf_training_male_path, aaf_training_female_path)

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)

            # 4. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizer.step()
                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_balanced_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_balanced_best.pth'))
            print(f"Self-training completed for {training_folder}, Threshold: {pseudo_label_threshold}.")

print("All experiments completed.")
# Out:
# File downloaded successfully and saved as classification_model.pth
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\haohu\AppData\Local\Temp\ipykernel_16192\3455979332.py:102: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
# --- Starting Experiment: Unlabeled, Threshold: 0.9 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 1: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 28244 and female 12927 samples
# Balanced pseudo-labeled samples: Male - 12927, Female - 12927
# Iteration 1, Epoch 1, Train Loss: 0.0379
# Iteration 1, Epoch 1, Validation Loss: 0.7299, Accuracy: 0.7974
# Iteration 1, Epoch 2, Train Loss: 0.0235
# Iteration 1, Epoch 2, Validation Loss: 0.7081, Accuracy: 0.7987
# Iteration 1, Epoch 3, Train Loss: 0.0150
# Iteration 1, Epoch 3, Validation Loss: 0.8830, Accuracy: 0.7935
# Iteration 1, Epoch 4, Train Loss: 0.0081
# Iteration 1, Epoch 4, Validation Loss: 0.8684, Accuracy: 0.8032
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 2: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 45693 and female 27166 samples
# Balanced pseudo-labeled samples: Male - 27166, Female - 27166
# Iteration 2, Epoch 1, Train Loss: 0.1057
# Iteration 2, Epoch 1, Validation Loss: 0.7443, Accuracy: 0.7968
# Iteration 2, Epoch 2, Train Loss: 0.0714
# Iteration 2, Epoch 2, Validation Loss: 0.8804, Accuracy: 0.8123
# Iteration 2, Epoch 3, Train Loss: 0.0582
# Iteration 2, Epoch 3, Validation Loss: 0.9231, Accuracy: 0.8052
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 3: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 46159 and female 28734 samples
# Balanced pseudo-labeled samples: Male - 28734, Female - 28734
# Iteration 3, Epoch 1, Train Loss: 0.0598
# Iteration 3, Epoch 1, Validation Loss: 1.1340, Accuracy: 0.7955
# Iteration 3, Epoch 2, Train Loss: 0.0463
# Iteration 3, Epoch 2, Validation Loss: 1.0690, Accuracy: 0.8013
# Iteration 3, Epoch 3, Train Loss: 0.0403
# Iteration 3, Epoch 3, Validation Loss: 1.0832, Accuracy: 0.8039
# Iteration 3, Epoch 4, Train Loss: 0.0309
# Iteration 3, Epoch 4, Validation Loss: 1.1355, Accuracy: 0.8110
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 4: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47109 and female 31528 samples
# Balanced pseudo-labeled samples: Male - 31528, Female - 31528
# Iteration 4, Epoch 1, Train Loss: 0.0568
# Iteration 4, Epoch 1, Validation Loss: 1.1009, Accuracy: 0.8077
# Iteration 4, Epoch 2, Train Loss: 0.0417
# Iteration 4, Epoch 2, Validation Loss: 1.3210, Accuracy: 0.8032
# Iteration 4, Epoch 3, Train Loss: 0.0365
# Iteration 4, Epoch 3, Validation Loss: 1.1711, Accuracy: 0.8142
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 5: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 46836 and female 32892 samples
# Balanced pseudo-labeled samples: Male - 32892, Female - 32892
# Iteration 5, Epoch 1, Train Loss: 0.0446
# Iteration 5, Epoch 1, Validation Loss: 1.1336, Accuracy: 0.8084
# Iteration 5, Epoch 2, Train Loss: 0.0371
# Iteration 5, Epoch 2, Validation Loss: 1.2282, Accuracy: 0.8110
# Iteration 5, Epoch 3, Train Loss: 0.0305
# Iteration 5, Epoch 3, Validation Loss: 1.2787, Accuracy: 0.8077
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 6: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 48157 and female 32695 samples
# Balanced pseudo-labeled samples: Male - 32695, Female - 32695
# Iteration 6, Epoch 1, Train Loss: 0.0428
# Iteration 6, Epoch 1, Validation Loss: 1.0202, Accuracy: 0.8174
# Iteration 6, Epoch 2, Train Loss: 0.0363
# Iteration 6, Epoch 2, Validation Loss: 1.2759, Accuracy: 0.8077
# Iteration 6, Epoch 3, Train Loss: 0.0300
# Iteration 6, Epoch 3, Validation Loss: 1.1896, Accuracy: 0.8200
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 7: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 46015 and female 34928 samples
# Balanced pseudo-labeled samples: Male - 34928, Female - 34928
# Iteration 7, Epoch 1, Train Loss: 0.0397
# Iteration 7, Epoch 1, Validation Loss: 1.1717, Accuracy: 0.8097
# Iteration 7, Epoch 2, Train Loss: 0.0334
# Iteration 7, Epoch 2, Validation Loss: 1.2879, Accuracy: 0.8058
# Iteration 7, Epoch 3, Train Loss: 0.0269
# Iteration 7, Epoch 3, Validation Loss: 1.3180, Accuracy: 0.8110
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 8: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 46104 and female 35442 samples
# Balanced pseudo-labeled samples: Male - 35442, Female - 35442
# Iteration 8, Epoch 1, Train Loss: 0.0379
# Iteration 8, Epoch 1, Validation Loss: 1.2607, Accuracy: 0.7974
# Iteration 8, Epoch 2, Train Loss: 0.0310
# Iteration 8, Epoch 2, Validation Loss: 1.3685, Accuracy: 0.8103
# Iteration 8, Epoch 3, Train Loss: 0.0277
# Iteration 8, Epoch 3, Validation Loss: 1.3890, Accuracy: 0.8058
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 9: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47138 and female 35276 samples
# Balanced pseudo-labeled samples: Male - 35276, Female - 35276
# Iteration 9, Epoch 1, Train Loss: 0.0310
# Iteration 9, Epoch 1, Validation Loss: 1.4521, Accuracy: 0.8045
# Iteration 9, Epoch 2, Train Loss: 0.0281
# Iteration 9, Epoch 2, Validation Loss: 1.4783, Accuracy: 0.8142
# Iteration 9, Epoch 3, Train Loss: 0.0234
# Iteration 9, Epoch 3, Validation Loss: 1.4748, Accuracy: 0.8090
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 10: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 46834 and female 36073 samples
# Balanced pseudo-labeled samples: Male - 36073, Female - 36073
# Iteration 10, Epoch 1, Train Loss: 0.0368
# Iteration 10, Epoch 1, Validation Loss: 1.3366, Accuracy: 0.8103
# Iteration 10, Epoch 2, Train Loss: 0.0272
# Iteration 10, Epoch 2, Validation Loss: 1.5053, Accuracy: 0.8148
# Iteration 10, Epoch 3, Train Loss: 0.0253
# Iteration 10, Epoch 3, Validation Loss: 1.5093, Accuracy: 0.8077
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Experiment: Unlabeled, Threshold: 0.6 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 1: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 48402 and female 37761 samples
# Balanced pseudo-labeled samples: Male - 37761, Female - 37761
# Iteration 1, Epoch 1, Train Loss: 0.0599
# Iteration 1, Epoch 1, Validation Loss: 1.1424, Accuracy: 0.8116
# Iteration 1, Epoch 2, Train Loss: 0.0451
# Iteration 1, Epoch 2, Validation Loss: 1.3447, Accuracy: 0.8000
# Iteration 1, Epoch 3, Train Loss: 0.0391
# Iteration 1, Epoch 3, Validation Loss: 1.2768, Accuracy: 0.8110
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 2: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47867 and female 38308 samples
# Balanced pseudo-labeled samples: Male - 38308, Female - 38308
# Iteration 2, Epoch 1, Train Loss: 0.0510
# Iteration 2, Epoch 1, Validation Loss: 1.1211, Accuracy: 0.8129
# Iteration 2, Epoch 2, Train Loss: 0.0399
# Iteration 2, Epoch 2, Validation Loss: 1.1775, Accuracy: 0.8129
# Iteration 2, Epoch 3, Train Loss: 0.0345
# Iteration 2, Epoch 3, Validation Loss: 1.3359, Accuracy: 0.8058
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 3: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 48060 and female 38301 samples
# Balanced pseudo-labeled samples: Male - 38301, Female - 38301
# Iteration 3, Epoch 1, Train Loss: 0.0408
# Iteration 3, Epoch 1, Validation Loss: 1.2032, Accuracy: 0.8110
# Iteration 3, Epoch 2, Train Loss: 0.0320
# Iteration 3, Epoch 2, Validation Loss: 1.2739, Accuracy: 0.8084
# Iteration 3, Epoch 3, Train Loss: 0.0277
# Iteration 3, Epoch 3, Validation Loss: 1.4486, Accuracy: 0.8090
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 4: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47830 and female 38629 samples
# Balanced pseudo-labeled samples: Male - 38629, Female - 38629
# Iteration 4, Epoch 1, Train Loss: 0.0378
# Iteration 4, Epoch 1, Validation Loss: 1.2559, Accuracy: 0.8110
# Iteration 4, Epoch 2, Train Loss: 0.0305
# Iteration 4, Epoch 2, Validation Loss: 1.3242, Accuracy: 0.8129
# Iteration 4, Epoch 3, Train Loss: 0.0247
# Iteration 4, Epoch 3, Validation Loss: 1.3895, Accuracy: 0.8052
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 5: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47963 and female 38524 samples
# Balanced pseudo-labeled samples: Male - 38524, Female - 38524
# Iteration 5, Epoch 1, Train Loss: 0.0334
# Iteration 5, Epoch 1, Validation Loss: 1.3564, Accuracy: 0.8142
# Iteration 5, Epoch 2, Train Loss: 0.0249
# Iteration 5, Epoch 2, Validation Loss: 1.4020, Accuracy: 0.8090
# Iteration 5, Epoch 3, Train Loss: 0.0222
# Iteration 5, Epoch 3, Validation Loss: 1.5053, Accuracy: 0.8052
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 6: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47823 and female 38696 samples
# Balanced pseudo-labeled samples: Male - 38696, Female - 38696
# Iteration 6, Epoch 1, Train Loss: 0.0281
# Iteration 6, Epoch 1, Validation Loss: 1.2992, Accuracy: 0.7968
# Iteration 6, Epoch 2, Train Loss: 0.0222
# Iteration 6, Epoch 2, Validation Loss: 1.6097, Accuracy: 0.8103
# Iteration 6, Epoch 3, Train Loss: 0.0224
# Iteration 6, Epoch 3, Validation Loss: 1.3929, Accuracy: 0.8052
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 7: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47391 and female 39037 samples
# Balanced pseudo-labeled samples: Male - 39037, Female - 39037
# Iteration 7, Epoch 1, Train Loss: 0.0307
# Iteration 7, Epoch 1, Validation Loss: 1.2704, Accuracy: 0.8148
# Iteration 7, Epoch 2, Train Loss: 0.0218
# Iteration 7, Epoch 2, Validation Loss: 1.4285, Accuracy: 0.8026
# Iteration 7, Epoch 3, Train Loss: 0.0204
# Iteration 7, Epoch 3, Validation Loss: 1.3580, Accuracy: 0.8084
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 8: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47492 and female 38995 samples
# Balanced pseudo-labeled samples: Male - 38995, Female - 38995
# Iteration 8, Epoch 1, Train Loss: 0.0289
# Iteration 8, Epoch 1, Validation Loss: 1.2877, Accuracy: 0.7968
# Iteration 8, Epoch 2, Train Loss: 0.0207
# Iteration 8, Epoch 2, Validation Loss: 1.3182, Accuracy: 0.7981
# Iteration 8, Epoch 3, Train Loss: 0.0197
# Iteration 8, Epoch 3, Validation Loss: 1.6311, Accuracy: 0.7974
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 9: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47587 and female 39030 samples
# Balanced pseudo-labeled samples: Male - 39030, Female - 39030
# Iteration 9, Epoch 1, Train Loss: 0.0241
# Iteration 9, Epoch 1, Validation Loss: 1.3661, Accuracy: 0.8052
# Iteration 9, Epoch 2, Train Loss: 0.0164
# Iteration 9, Epoch 2, Validation Loss: 1.4507, Accuracy: 0.8065
# Iteration 9, Epoch 3, Train Loss: 0.0134
# Iteration 9, Epoch 3, Validation Loss: 1.6119, Accuracy: 0.7994
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 10: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 47554 and female 39105 samples
# Balanced pseudo-labeled samples: Male - 39105, Female - 39105
# Iteration 10, Epoch 1, Train Loss: 0.0218
# Iteration 10, Epoch 1, Validation Loss: 1.4350, Accuracy: 0.8065
# Iteration 10, Epoch 2, Train Loss: 0.0135
# Iteration 10, Epoch 2, Validation Loss: 1.7534, Accuracy: 0.8026
# Iteration 10, Epoch 3, Train Loss: 0.0143
# Iteration 10, Epoch 3, Validation Loss: 1.7845, Accuracy: 0.8013
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Gender_Balanced_Unlabeled, Threshold: 0.9 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 14097 and female 6479 samples
# Balanced pseudo-labeled samples: Male - 6479, Female - 6479
# Iteration 1, Epoch 1, Train Loss: 0.0361
# Iteration 1, Epoch 1, Validation Loss: 0.6366, Accuracy: 0.7942
# Iteration 1, Epoch 2, Train Loss: 0.0182
# Iteration 1, Epoch 2, Validation Loss: 0.9019, Accuracy: 0.7787
# Iteration 1, Epoch 3, Train Loss: 0.0206
# Iteration 1, Epoch 3, Validation Loss: 0.7772, Accuracy: 0.7910
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 20133 and female 14669 samples
# Balanced pseudo-labeled samples: Male - 14669, Female - 14669
# Iteration 2, Epoch 1, Train Loss: 0.1186
# Iteration 2, Epoch 1, Validation Loss: 0.7667, Accuracy: 0.7890
# Iteration 2, Epoch 2, Train Loss: 0.0733
# Iteration 2, Epoch 2, Validation Loss: 0.8057, Accuracy: 0.8084
# Iteration 2, Epoch 3, Train Loss: 0.0606
# Iteration 2, Epoch 3, Validation Loss: 0.8172, Accuracy: 0.8019
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 20730 and female 15562 samples
# Balanced pseudo-labeled samples: Male - 15562, Female - 15562
# Iteration 3, Epoch 1, Train Loss: 0.0736
# Iteration 3, Epoch 1, Validation Loss: 0.8648, Accuracy: 0.8026
# Iteration 3, Epoch 2, Train Loss: 0.0523
# Iteration 3, Epoch 2, Validation Loss: 1.0497, Accuracy: 0.8013
# Iteration 3, Epoch 3, Train Loss: 0.0466
# Iteration 3, Epoch 3, Validation Loss: 0.9785, Accuracy: 0.8013
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 4: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 21706 and female 16534 samples
# Balanced pseudo-labeled samples: Male - 16534, Female - 16534
# Iteration 4, Epoch 1, Train Loss: 0.0612
# Iteration 4, Epoch 1, Validation Loss: 0.9721, Accuracy: 0.8071
# Iteration 4, Epoch 2, Train Loss: 0.0488
# Iteration 4, Epoch 2, Validation Loss: 0.9921, Accuracy: 0.8039
# Iteration 4, Epoch 3, Train Loss: 0.0422
# Iteration 4, Epoch 3, Validation Loss: 1.0237, Accuracy: 0.8065
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 5: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23090 and female 16211 samples
# Balanced pseudo-labeled samples: Male - 16211, Female - 16211
# Iteration 5, Epoch 1, Train Loss: 0.0561
# Iteration 5, Epoch 1, Validation Loss: 0.9493, Accuracy: 0.8123
# Iteration 5, Epoch 2, Train Loss: 0.0458
# Iteration 5, Epoch 2, Validation Loss: 1.0102, Accuracy: 0.8006
# Iteration 5, Epoch 3, Train Loss: 0.0425
# Iteration 5, Epoch 3, Validation Loss: 0.9789, Accuracy: 0.8116
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 6: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23706 and female 15618 samples
# Balanced pseudo-labeled samples: Male - 15618, Female - 15618
# Iteration 6, Epoch 1, Train Loss: 0.0447
# Iteration 6, Epoch 1, Validation Loss: 1.0088, Accuracy: 0.8155
# Iteration 6, Epoch 2, Train Loss: 0.0310
# Iteration 6, Epoch 2, Validation Loss: 1.2063, Accuracy: 0.8135
# Iteration 6, Epoch 3, Train Loss: 0.0267
# Iteration 6, Epoch 3, Validation Loss: 1.2930, Accuracy: 0.8148
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 7: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24240 and female 16402 samples
# Balanced pseudo-labeled samples: Male - 16402, Female - 16402
# Iteration 7, Epoch 1, Train Loss: 0.0557
# Iteration 7, Epoch 1, Validation Loss: 1.1121, Accuracy: 0.8084
# Iteration 7, Epoch 2, Train Loss: 0.0437
# Iteration 7, Epoch 2, Validation Loss: 1.0976, Accuracy: 0.8058
# Iteration 7, Epoch 3, Train Loss: 0.0302
# Iteration 7, Epoch 3, Validation Loss: 1.2183, Accuracy: 0.8148
# Iteration 7, Epoch 4, Train Loss: 0.0284
# Iteration 7, Epoch 4, Validation Loss: 1.2283, Accuracy: 0.8123
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 8: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24199 and female 17051 samples
# Balanced pseudo-labeled samples: Male - 17051, Female - 17051
# Iteration 8, Epoch 1, Train Loss: 0.0418
# Iteration 8, Epoch 1, Validation Loss: 1.0977, Accuracy: 0.8174
# Iteration 8, Epoch 2, Train Loss: 0.0355
# Iteration 8, Epoch 2, Validation Loss: 1.1621, Accuracy: 0.8026
# Iteration 8, Epoch 3, Train Loss: 0.0259
# Iteration 8, Epoch 3, Validation Loss: 1.2913, Accuracy: 0.8148
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 9: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23782 and female 17642 samples
# Balanced pseudo-labeled samples: Male - 17642, Female - 17642
# Iteration 9, Epoch 1, Train Loss: 0.0379
# Iteration 9, Epoch 1, Validation Loss: 1.1285, Accuracy: 0.8181
# Iteration 9, Epoch 2, Train Loss: 0.0324
# Iteration 9, Epoch 2, Validation Loss: 1.2950, Accuracy: 0.8090
# Iteration 9, Epoch 3, Train Loss: 0.0307
# Iteration 9, Epoch 3, Validation Loss: 1.1932, Accuracy: 0.8239
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 10: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23973 and female 17679 samples
# Balanced pseudo-labeled samples: Male - 17679, Female - 17679
# Iteration 10, Epoch 1, Train Loss: 0.0264
# Iteration 10, Epoch 1, Validation Loss: 1.2042, Accuracy: 0.8135
# Iteration 10, Epoch 2, Train Loss: 0.0241
# Iteration 10, Epoch 2, Validation Loss: 1.4510, Accuracy: 0.8116
# Iteration 10, Epoch 3, Train Loss: 0.0235
# Iteration 10, Epoch 3, Validation Loss: 1.1912, Accuracy: 0.8168
# Iteration 10, Epoch 4, Train Loss: 0.0181
# Iteration 10, Epoch 4, Validation Loss: 1.3692, Accuracy: 0.8142
# Iteration 10, Epoch 5, Train Loss: 0.0207
# Iteration 10, Epoch 5, Validation Loss: 1.3172, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Experiment: Gender_Balanced_Unlabeled, Threshold: 0.6 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24709 and female 18421 samples
# Balanced pseudo-labeled samples: Male - 18421, Female - 18421
# Iteration 1, Epoch 1, Train Loss: 0.0555
# Iteration 1, Epoch 1, Validation Loss: 0.9873, Accuracy: 0.8123
# Iteration 1, Epoch 2, Train Loss: 0.0384
# Iteration 1, Epoch 2, Validation Loss: 1.0791, Accuracy: 0.8155
# Iteration 1, Epoch 3, Train Loss: 0.0324
# Iteration 1, Epoch 3, Validation Loss: 1.2059, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24279 and female 18841 samples
# Balanced pseudo-labeled samples: Male - 18841, Female - 18841
# Iteration 2, Epoch 1, Train Loss: 0.0510
# Iteration 2, Epoch 1, Validation Loss: 0.9430, Accuracy: 0.8019
# Iteration 2, Epoch 2, Train Loss: 0.0356
# Iteration 2, Epoch 2, Validation Loss: 1.2280, Accuracy: 0.8142
# Iteration 2, Epoch 3, Train Loss: 0.0317
# Iteration 2, Epoch 3, Validation Loss: 1.3439, Accuracy: 0.8071
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24397 and female 18844 samples
# Balanced pseudo-labeled samples: Male - 18844, Female - 18844
# Iteration 3, Epoch 1, Train Loss: 0.0355
# Iteration 3, Epoch 1, Validation Loss: 1.1233, Accuracy: 0.8077
# Iteration 3, Epoch 2, Train Loss: 0.0282
# Iteration 3, Epoch 2, Validation Loss: 1.2837, Accuracy: 0.8103
# Iteration 3, Epoch 3, Train Loss: 0.0214
# Iteration 3, Epoch 3, Validation Loss: 1.2647, Accuracy: 0.8026
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 4: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24200 and female 18952 samples
# Balanced pseudo-labeled samples: Male - 18952, Female - 18952
# Iteration 4, Epoch 1, Train Loss: 0.0459
# Iteration 4, Epoch 1, Validation Loss: 1.0183, Accuracy: 0.8103
# Iteration 4, Epoch 2, Train Loss: 0.0296
# Iteration 4, Epoch 2, Validation Loss: 1.2027, Accuracy: 0.8045
# Iteration 4, Epoch 3, Train Loss: 0.0272
# Iteration 4, Epoch 3, Validation Loss: 1.2831, Accuracy: 0.8045
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 5: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24246 and female 19014 samples
# Balanced pseudo-labeled samples: Male - 19014, Female - 19014
# Iteration 5, Epoch 1, Train Loss: 0.0298
# Iteration 5, Epoch 1, Validation Loss: 1.2235, Accuracy: 0.8142
# Iteration 5, Epoch 2, Train Loss: 0.0229
# Iteration 5, Epoch 2, Validation Loss: 1.4531, Accuracy: 0.8077
# Iteration 5, Epoch 3, Train Loss: 0.0187
# Iteration 5, Epoch 3, Validation Loss: 1.3702, Accuracy: 0.8097
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 6: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24340 and female 18948 samples
# Balanced pseudo-labeled samples: Male - 18948, Female - 18948
# Iteration 6, Epoch 1, Train Loss: 0.0281
# Iteration 6, Epoch 1, Validation Loss: 1.3217, Accuracy: 0.8013
# Iteration 6, Epoch 2, Train Loss: 0.0194
# Iteration 6, Epoch 2, Validation Loss: 1.3961, Accuracy: 0.8032
# Iteration 6, Epoch 3, Train Loss: 0.0149
# Iteration 6, Epoch 3, Validation Loss: 1.4641, Accuracy: 0.7987
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 7: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24243 and female 19055 samples
# Balanced pseudo-labeled samples: Male - 19055, Female - 19055
# Iteration 7, Epoch 1, Train Loss: 0.0233
# Iteration 7, Epoch 1, Validation Loss: 1.4117, Accuracy: 0.8032
# Iteration 7, Epoch 2, Train Loss: 0.0159
# Iteration 7, Epoch 2, Validation Loss: 1.3309, Accuracy: 0.8148
# Iteration 7, Epoch 3, Train Loss: 0.0145
# Iteration 7, Epoch 3, Validation Loss: 1.5543, Accuracy: 0.8019
# Iteration 7, Epoch 4, Train Loss: 0.0106
# Iteration 7, Epoch 4, Validation Loss: 1.6017, Accuracy: 0.8013
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 8: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24211 and female 19100 samples
# Balanced pseudo-labeled samples: Male - 19100, Female - 19100
# Iteration 8, Epoch 1, Train Loss: 0.0193
# Iteration 8, Epoch 1, Validation Loss: 1.4968, Accuracy: 0.8077
# Iteration 8, Epoch 2, Train Loss: 0.0147
# Iteration 8, Epoch 2, Validation Loss: 1.6218, Accuracy: 0.8006
# Iteration 8, Epoch 3, Train Loss: 0.0128
# Iteration 8, Epoch 3, Validation Loss: 1.5373, Accuracy: 0.7955
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 9: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23946 and female 19285 samples
# Balanced pseudo-labeled samples: Male - 19285, Female - 19285
# Iteration 9, Epoch 1, Train Loss: 0.0331
# Iteration 9, Epoch 1, Validation Loss: 1.2535, Accuracy: 0.8039
# Iteration 9, Epoch 2, Train Loss: 0.0192
# Iteration 9, Epoch 2, Validation Loss: 1.4190, Accuracy: 0.8032
# Iteration 9, Epoch 3, Train Loss: 0.0162
# Iteration 9, Epoch 3, Validation Loss: 1.3834, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 10: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 24083 and female 19220 samples
# Balanced pseudo-labeled samples: Male - 19220, Female - 19220
# Iteration 10, Epoch 1, Train Loss: 0.0222
# Iteration 10, Epoch 1, Validation Loss: 1.3109, Accuracy: 0.8045
# Iteration 10, Epoch 2, Train Loss: 0.0149
# Iteration 10, Epoch 2, Validation Loss: 1.5485, Accuracy: 0.8097
# Iteration 10, Epoch 3, Train Loss: 0.0122
# Iteration 10, Epoch 3, Validation Loss: 1.4610, Accuracy: 0.8071
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Severe_Male_Gender, Threshold: 0.9 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 20761 and female 3017 samples
# Balanced pseudo-labeled samples: Male - 3017, Female - 3017
# Iteration 1, Epoch 1, Train Loss: 0.0562
# Iteration 1, Epoch 1, Validation Loss: 0.6507, Accuracy: 0.7981
# Iteration 1, Epoch 2, Train Loss: 0.0273
# Iteration 1, Epoch 2, Validation Loss: 0.9516, Accuracy: 0.7542
# Iteration 1, Epoch 3, Train Loss: 0.0279
# Iteration 1, Epoch 3, Validation Loss: 0.6811, Accuracy: 0.7903
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 26993 and female 8558 samples
# Balanced pseudo-labeled samples: Male - 8558, Female - 8558
# Iteration 2, Epoch 1, Train Loss: 0.1322
# Iteration 2, Epoch 1, Validation Loss: 0.7528, Accuracy: 0.7916
# Iteration 2, Epoch 2, Train Loss: 0.0790
# Iteration 2, Epoch 2, Validation Loss: 0.9136, Accuracy: 0.7826
# Iteration 2, Epoch 3, Train Loss: 0.0704
# Iteration 2, Epoch 3, Validation Loss: 0.9189, Accuracy: 0.7800
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 29473 and female 8767 samples
# Balanced pseudo-labeled samples: Male - 8767, Female - 8767
# Iteration 3, Epoch 1, Train Loss: 0.0797
# Iteration 3, Epoch 1, Validation Loss: 0.8951, Accuracy: 0.7794
# Iteration 3, Epoch 2, Train Loss: 0.0611
# Iteration 3, Epoch 2, Validation Loss: 1.0828, Accuracy: 0.7800
# Iteration 3, Epoch 3, Train Loss: 0.0468
# Iteration 3, Epoch 3, Validation Loss: 1.2614, Accuracy: 0.7761
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 4: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 29349 and female 10633 samples
# Balanced pseudo-labeled samples: Male - 10633, Female - 10633
# Iteration 4, Epoch 1, Train Loss: 0.0771
# Iteration 4, Epoch 1, Validation Loss: 0.9632, Accuracy: 0.7826
# Iteration 4, Epoch 2, Train Loss: 0.0562
# Iteration 4, Epoch 2, Validation Loss: 1.2804, Accuracy: 0.7735
# Iteration 4, Epoch 3, Train Loss: 0.0585
# Iteration 4, Epoch 3, Validation Loss: 1.2630, Accuracy: 0.7806
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 5: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 28662 and female 11745 samples
# Balanced pseudo-labeled samples: Male - 11745, Female - 11745
# Iteration 5, Epoch 1, Train Loss: 0.0672
# Iteration 5, Epoch 1, Validation Loss: 1.2274, Accuracy: 0.7729
# Iteration 5, Epoch 2, Train Loss: 0.0512
# Iteration 5, Epoch 2, Validation Loss: 1.4058, Accuracy: 0.7800
# Iteration 5, Epoch 3, Train Loss: 0.0387
# Iteration 5, Epoch 3, Validation Loss: 1.3543, Accuracy: 0.7787
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 6: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 29044 and female 12040 samples
# Balanced pseudo-labeled samples: Male - 12040, Female - 12040
# Iteration 6, Epoch 1, Train Loss: 0.0706
# Iteration 6, Epoch 1, Validation Loss: 1.1712, Accuracy: 0.7742
# Iteration 6, Epoch 2, Train Loss: 0.0510
# Iteration 6, Epoch 2, Validation Loss: 1.2172, Accuracy: 0.7723
# Iteration 6, Epoch 3, Train Loss: 0.0418
# Iteration 6, Epoch 3, Validation Loss: 1.2443, Accuracy: 0.7748
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 7: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 28815 and female 12267 samples
# Balanced pseudo-labeled samples: Male - 12267, Female - 12267
# Iteration 7, Epoch 1, Train Loss: 0.0493
# Iteration 7, Epoch 1, Validation Loss: 1.2730, Accuracy: 0.7645
# Iteration 7, Epoch 2, Train Loss: 0.0423
# Iteration 7, Epoch 2, Validation Loss: 1.3714, Accuracy: 0.7806
# Iteration 7, Epoch 3, Train Loss: 0.0329
# Iteration 7, Epoch 3, Validation Loss: 1.4475, Accuracy: 0.7794
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 8: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 28576 and female 12914 samples
# Balanced pseudo-labeled samples: Male - 12914, Female - 12914
# Iteration 8, Epoch 1, Train Loss: 0.0454
# Iteration 8, Epoch 1, Validation Loss: 1.4114, Accuracy: 0.7819
# Iteration 8, Epoch 2, Train Loss: 0.0435
# Iteration 8, Epoch 2, Validation Loss: 1.3090, Accuracy: 0.7774
# Iteration 8, Epoch 3, Train Loss: 0.0378
# Iteration 8, Epoch 3, Validation Loss: 1.3720, Accuracy: 0.7716
# Iteration 8, Epoch 4, Train Loss: 0.0289
# Iteration 8, Epoch 4, Validation Loss: 1.5696, Accuracy: 0.7742
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 9: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 27593 and female 14109 samples
# Balanced pseudo-labeled samples: Male - 14109, Female - 14109
# Iteration 9, Epoch 1, Train Loss: 0.0469
# Iteration 9, Epoch 1, Validation Loss: 1.5574, Accuracy: 0.7832
# Iteration 9, Epoch 2, Train Loss: 0.0407
# Iteration 9, Epoch 2, Validation Loss: 1.5778, Accuracy: 0.7735
# Iteration 9, Epoch 3, Train Loss: 0.0326
# Iteration 9, Epoch 3, Validation Loss: 1.7815, Accuracy: 0.7813
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 10: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 27735 and female 14392 samples
# Balanced pseudo-labeled samples: Male - 14392, Female - 14392
# Iteration 10, Epoch 1, Train Loss: 0.0456
# Iteration 10, Epoch 1, Validation Loss: 1.4682, Accuracy: 0.7761
# Iteration 10, Epoch 2, Train Loss: 0.0327
# Iteration 10, Epoch 2, Validation Loss: 1.7291, Accuracy: 0.7639
# Iteration 10, Epoch 3, Train Loss: 0.0321
# Iteration 10, Epoch 3, Validation Loss: 1.6982, Accuracy: 0.7755
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Experiment: Severe_Male_Gender, Threshold: 0.6 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 28481 and female 15983 samples
# Balanced pseudo-labeled samples: Male - 15983, Female - 15983
# Iteration 1, Epoch 1, Train Loss: 0.0919
# Iteration 1, Epoch 1, Validation Loss: 1.3473, Accuracy: 0.7819
# Iteration 1, Epoch 2, Train Loss: 0.0642
# Iteration 1, Epoch 2, Validation Loss: 1.3032, Accuracy: 0.7761
# Iteration 1, Epoch 3, Train Loss: 0.0534
# Iteration 1, Epoch 3, Validation Loss: 1.2600, Accuracy: 0.7845
# Iteration 1, Epoch 4, Train Loss: 0.0460
# Iteration 1, Epoch 4, Validation Loss: 1.7126, Accuracy: 0.7684
# Iteration 1, Epoch 5, Train Loss: 0.0393
# Iteration 1, Epoch 5, Validation Loss: 1.7159, Accuracy: 0.7671
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 28007 and female 16583 samples
# Balanced pseudo-labeled samples: Male - 16583, Female - 16583
# Iteration 2, Epoch 1, Train Loss: 0.0710
# Iteration 2, Epoch 1, Validation Loss: 1.4880, Accuracy: 0.7658
# Iteration 2, Epoch 2, Train Loss: 0.0505
# Iteration 2, Epoch 2, Validation Loss: 1.5389, Accuracy: 0.7690
# Iteration 2, Epoch 3, Train Loss: 0.0428
# Iteration 2, Epoch 3, Validation Loss: 1.7462, Accuracy: 0.7665
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 27336 and female 17194 samples
# Balanced pseudo-labeled samples: Male - 17194, Female - 17194
# Iteration 3, Epoch 1, Train Loss: 0.0740
# Iteration 3, Epoch 1, Validation Loss: 1.3515, Accuracy: 0.7568
# Iteration 3, Epoch 2, Train Loss: 0.0537
# Iteration 3, Epoch 2, Validation Loss: 1.7425, Accuracy: 0.7606
# Iteration 3, Epoch 3, Train Loss: 0.0449
# Iteration 3, Epoch 3, Validation Loss: 1.8184, Accuracy: 0.7626
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 4: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 26982 and female 17592 samples
# Balanced pseudo-labeled samples: Male - 17592, Female - 17592
# Iteration 4, Epoch 1, Train Loss: 0.0687
# Iteration 4, Epoch 1, Validation Loss: 1.3755, Accuracy: 0.7690
# Iteration 4, Epoch 2, Train Loss: 0.0493
# Iteration 4, Epoch 2, Validation Loss: 1.7157, Accuracy: 0.7606
# Iteration 4, Epoch 3, Train Loss: 0.0433
# Iteration 4, Epoch 3, Validation Loss: 1.7665, Accuracy: 0.7587
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 5: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 26717 and female 17906 samples
# Balanced pseudo-labeled samples: Male - 17906, Female - 17906
# Iteration 5, Epoch 1, Train Loss: 0.0604
# Iteration 5, Epoch 1, Validation Loss: 1.6894, Accuracy: 0.7626
# Iteration 5, Epoch 2, Train Loss: 0.0445
# Iteration 5, Epoch 2, Validation Loss: 1.8813, Accuracy: 0.7710
# Iteration 5, Epoch 3, Train Loss: 0.0382
# Iteration 5, Epoch 3, Validation Loss: 1.7331, Accuracy: 0.7671
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 6: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 26995 and female 17700 samples
# Balanced pseudo-labeled samples: Male - 17700, Female - 17700
# Iteration 6, Epoch 1, Train Loss: 0.0509
# Iteration 6, Epoch 1, Validation Loss: 1.5342, Accuracy: 0.7594
# Iteration 6, Epoch 2, Train Loss: 0.0367
# Iteration 6, Epoch 2, Validation Loss: 1.8285, Accuracy: 0.7613
# Iteration 6, Epoch 3, Train Loss: 0.0357
# Iteration 6, Epoch 3, Validation Loss: 1.7983, Accuracy: 0.7555
# ...
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6481 and female 2799 samples
# Balanced pseudo-labeled samples: Male - 2799, Female - 2799
# Iteration 2, Epoch 1, Train Loss: 0.1434
# Iteration 2, Epoch 1, Validation Loss: 0.7624, Accuracy: 0.7645
# Iteration 2, Epoch 2, Train Loss: 0.1009
# Iteration 2, Epoch 2, Validation Loss: 0.7881, Accuracy: 0.7877
# Iteration 2, Epoch 3, Train Loss: 0.0608
# Iteration 2, Epoch 3, Validation Loss: 0.9502, Accuracy: 0.7729
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 7270 and female 3081 samples
# Balanced pseudo-labeled samples: Male - 3081, Female - 3081
# Iteration 3, Epoch 1, Train Loss: 0.1074
# Iteration 3, Epoch 1, Validation Loss: 0.8773, Accuracy: 0.7774
# Iteration 3, Epoch 2, Train Loss: 0.0935
# Iteration 3, Epoch 2, Validation Loss: 0.9207, Accuracy: 0.7677
# Iteration 3, Epoch 3, Train Loss: 0.0592
# Iteration 3, Epoch 3, Validation Loss: 1.0758, Accuracy: 0.7729
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 4: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6491 and female 4079 samples
# Balanced pseudo-labeled samples: Male - 4079, Female - 4079
# Iteration 4, Epoch 1, Train Loss: 0.1125
# Iteration 4, Epoch 1, Validation Loss: 0.8478, Accuracy: 0.7574
# Iteration 4, Epoch 2, Train Loss: 0.0827
# Iteration 4, Epoch 2, Validation Loss: 1.1848, Accuracy: 0.7594
# Iteration 4, Epoch 3, Train Loss: 0.0721
# Iteration 4, Epoch 3, Validation Loss: 1.0375, Accuracy: 0.7677
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 5: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6196 and female 4353 samples
# Balanced pseudo-labeled samples: Male - 4353, Female - 4353
# Iteration 5, Epoch 1, Train Loss: 0.0730
# Iteration 5, Epoch 1, Validation Loss: 1.0632, Accuracy: 0.7542
# Iteration 5, Epoch 2, Train Loss: 0.0538
# Iteration 5, Epoch 2, Validation Loss: 1.0514, Accuracy: 0.7587
# Iteration 5, Epoch 3, Train Loss: 0.0483
# Iteration 5, Epoch 3, Validation Loss: 1.2340, Accuracy: 0.7574
# Iteration 5, Epoch 4, Train Loss: 0.0377
# Iteration 5, Epoch 4, Validation Loss: 1.2133, Accuracy: 0.7626
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 6: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6718 and female 4490 samples
# Balanced pseudo-labeled samples: Male - 4490, Female - 4490
# Iteration 6, Epoch 1, Train Loss: 0.0982
# Iteration 6, Epoch 1, Validation Loss: 1.2292, Accuracy: 0.7258
# Iteration 6, Epoch 2, Train Loss: 0.0525
# Iteration 6, Epoch 2, Validation Loss: 1.2339, Accuracy: 0.7658
# Iteration 6, Epoch 3, Train Loss: 0.0403
# Iteration 6, Epoch 3, Validation Loss: 1.3251, Accuracy: 0.7645
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 7: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6626 and female 4715 samples
# Balanced pseudo-labeled samples: Male - 4715, Female - 4715
# Iteration 7, Epoch 1, Train Loss: 0.0487
# Iteration 7, Epoch 1, Validation Loss: 1.3372, Accuracy: 0.7690
# Iteration 7, Epoch 2, Train Loss: 0.0448
# Iteration 7, Epoch 2, Validation Loss: 1.3338, Accuracy: 0.7432
# Iteration 7, Epoch 3, Train Loss: 0.0401
# Iteration 7, Epoch 3, Validation Loss: 1.3796, Accuracy: 0.7574
# Iteration 7, Epoch 4, Train Loss: 0.0407
# Iteration 7, Epoch 4, Validation Loss: 1.2147, Accuracy: 0.7600
# Iteration 7, Epoch 5, Train Loss: 0.0208
# Iteration 7, Epoch 5, Validation Loss: 1.4787, Accuracy: 0.7594
# Iteration 7, Epoch 6, Train Loss: 0.0204
# Iteration 7, Epoch 6, Validation Loss: 1.5074, Accuracy: 0.7600
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 8: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6772 and female 4789 samples
# Balanced pseudo-labeled samples: Male - 4789, Female - 4789
# Iteration 8, Epoch 1, Train Loss: 0.0543
# Iteration 8, Epoch 1, Validation Loss: 1.3666, Accuracy: 0.7516
# Iteration 8, Epoch 2, Train Loss: 0.0372
# Iteration 8, Epoch 2, Validation Loss: 1.4856, Accuracy: 0.7432
# Iteration 8, Epoch 3, Train Loss: 0.0293
# Iteration 8, Epoch 3, Validation Loss: 1.5685, Accuracy: 0.7523
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 9: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6695 and female 4878 samples
# Balanced pseudo-labeled samples: Male - 4878, Female - 4878
# Iteration 9, Epoch 1, Train Loss: 0.0406
# Iteration 9, Epoch 1, Validation Loss: 1.6253, Accuracy: 0.7581
# Iteration 9, Epoch 2, Train Loss: 0.0346
# Iteration 9, Epoch 2, Validation Loss: 1.4877, Accuracy: 0.7568
# Iteration 9, Epoch 3, Train Loss: 0.0225
# Iteration 9, Epoch 3, Validation Loss: 1.6378, Accuracy: 0.7568
# Iteration 9, Epoch 4, Train Loss: 0.0180
# Iteration 9, Epoch 4, Validation Loss: 1.6797, Accuracy: 0.7613
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 10: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6778 and female 4998 samples
# Balanced pseudo-labeled samples: Male - 4998, Female - 4998
# Iteration 10, Epoch 1, Train Loss: 0.0444
# Iteration 10, Epoch 1, Validation Loss: 1.6360, Accuracy: 0.7555
# Iteration 10, Epoch 2, Train Loss: 0.0306
# Iteration 10, Epoch 2, Validation Loss: 1.5893, Accuracy: 0.7613
# Iteration 10, Epoch 3, Train Loss: 0.0283
# Iteration 10, Epoch 3, Validation Loss: 1.7683, Accuracy: 0.7452
# Iteration 10, Epoch 4, Train Loss: 0.0205
# Iteration 10, Epoch 4, Validation Loss: 1.7337, Accuracy: 0.7542
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Experiment: Severe_Black_Bias, Threshold: 0.6 ---
# --- Starting Iteration 1/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 1: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6916 and female 5258 samples
# Balanced pseudo-labeled samples: Male - 5258, Female - 5258
# Iteration 1, Epoch 1, Train Loss: 0.0670
# Iteration 1, Epoch 1, Validation Loss: 1.3875, Accuracy: 0.7574
# Iteration 1, Epoch 2, Train Loss: 0.0398
# Iteration 1, Epoch 2, Validation Loss: 1.3444, Accuracy: 0.7671
# Iteration 1, Epoch 3, Train Loss: 0.0338
# Iteration 1, Epoch 3, Validation Loss: 1.5627, Accuracy: 0.7574
# Iteration 1, Epoch 4, Train Loss: 0.0315
# Iteration 1, Epoch 4, Validation Loss: 1.5899, Accuracy: 0.7581
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 2/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6945 and female 5229 samples
# Balanced pseudo-labeled samples: Male - 5229, Female - 5229
# Iteration 2, Epoch 1, Train Loss: 0.0414
# Iteration 2, Epoch 1, Validation Loss: 1.6616, Accuracy: 0.7471
# Iteration 2, Epoch 2, Train Loss: 0.0344
# Iteration 2, Epoch 2, Validation Loss: 1.5164, Accuracy: 0.7516
# Iteration 2, Epoch 3, Train Loss: 0.0174
# Iteration 2, Epoch 3, Validation Loss: 1.4692, Accuracy: 0.7645
# Iteration 2, Epoch 4, Train Loss: 0.0191
# Iteration 2, Epoch 4, Validation Loss: 1.6621, Accuracy: 0.7574
# Iteration 2, Epoch 5, Train Loss: 0.0154
# Iteration 2, Epoch 5, Validation Loss: 1.9079, Accuracy: 0.7471
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 3/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6944 and female 5271 samples
# Balanced pseudo-labeled samples: Male - 5271, Female - 5271
# Iteration 3, Epoch 1, Train Loss: 0.0237
# Iteration 3, Epoch 1, Validation Loss: 1.9824, Accuracy: 0.7445
# Iteration 3, Epoch 2, Train Loss: 0.0234
# Iteration 3, Epoch 2, Validation Loss: 1.7496, Accuracy: 0.7619
# Iteration 3, Epoch 3, Train Loss: 0.0271
# Iteration 3, Epoch 3, Validation Loss: 1.5763, Accuracy: 0.7600
# Iteration 3, Epoch 4, Train Loss: 0.0128
# Iteration 3, Epoch 4, Validation Loss: 1.9024, Accuracy: 0.7548
# Iteration 3, Epoch 5, Train Loss: 0.0078
# Iteration 3, Epoch 5, Validation Loss: 2.0307, Accuracy: 0.7561
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 4/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 4: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6933 and female 5287 samples
# Balanced pseudo-labeled samples: Male - 5287, Female - 5287
# Iteration 4, Epoch 1, Train Loss: 0.0285
# Iteration 4, Epoch 1, Validation Loss: 1.8375, Accuracy: 0.7419
# Iteration 4, Epoch 2, Train Loss: 0.0181
# Iteration 4, Epoch 2, Validation Loss: 1.8086, Accuracy: 0.7548
# Iteration 4, Epoch 3, Train Loss: 0.0203
# Iteration 4, Epoch 3, Validation Loss: 1.7553, Accuracy: 0.7548
# Iteration 4, Epoch 4, Train Loss: 0.0117
# Iteration 4, Epoch 4, Validation Loss: 2.1039, Accuracy: 0.7535
# Iteration 4, Epoch 5, Train Loss: 0.0082
# Iteration 4, Epoch 5, Validation Loss: 1.8544, Accuracy: 0.7626
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 5/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 5: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6938 and female 5290 samples
# Balanced pseudo-labeled samples: Male - 5290, Female - 5290
# Iteration 5, Epoch 1, Train Loss: 0.0177
# Iteration 5, Epoch 1, Validation Loss: 1.7246, Accuracy: 0.7632
# Iteration 5, Epoch 2, Train Loss: 0.0069
# Iteration 5, Epoch 2, Validation Loss: 1.9432, Accuracy: 0.7587
# Iteration 5, Epoch 3, Train Loss: 0.0046
# Iteration 5, Epoch 3, Validation Loss: 1.9616, Accuracy: 0.7594
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 6/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 6: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6942 and female 5291 samples
# Balanced pseudo-labeled samples: Male - 5291, Female - 5291
# Iteration 6, Epoch 1, Train Loss: 0.0043
# Iteration 6, Epoch 1, Validation Loss: 2.1012, Accuracy: 0.7497
# Iteration 6, Epoch 2, Train Loss: 0.0095
# Iteration 6, Epoch 2, Validation Loss: 2.0025, Accuracy: 0.7548
# Iteration 6, Epoch 3, Train Loss: 0.0050
# Iteration 6, Epoch 3, Validation Loss: 2.1048, Accuracy: 0.7645
# Iteration 6, Epoch 4, Train Loss: 0.0180
# Iteration 6, Epoch 4, Validation Loss: 2.0777, Accuracy: 0.7426
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 7/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 7: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6944 and female 5274 samples
# Balanced pseudo-labeled samples: Male - 5274, Female - 5274
# Iteration 7, Epoch 1, Train Loss: 0.0311
# Iteration 7, Epoch 1, Validation Loss: 1.9090, Accuracy: 0.7529
# Iteration 7, Epoch 2, Train Loss: 0.0141
# Iteration 7, Epoch 2, Validation Loss: 1.8477, Accuracy: 0.7529
# Iteration 7, Epoch 3, Train Loss: 0.0158
# Iteration 7, Epoch 3, Validation Loss: 2.0234, Accuracy: 0.7394
# Iteration 7, Epoch 4, Train Loss: 0.0108
# Iteration 7, Epoch 4, Validation Loss: 1.7973, Accuracy: 0.7568
# Iteration 7, Epoch 5, Train Loss: 0.0051
# Iteration 7, Epoch 5, Validation Loss: 2.1713, Accuracy: 0.7561
# Iteration 7, Epoch 6, Train Loss: 0.0129
# Iteration 7, Epoch 6, Validation Loss: 2.0368, Accuracy: 0.7503
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 8/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 8: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6944 and female 5287 samples
# Balanced pseudo-labeled samples: Male - 5287, Female - 5287
# Iteration 8, Epoch 1, Train Loss: 0.0070
# Iteration 8, Epoch 1, Validation Loss: 2.1964, Accuracy: 0.7432
# Iteration 8, Epoch 2, Train Loss: 0.0122
# Iteration 8, Epoch 2, Validation Loss: 2.2866, Accuracy: 0.7465
# Iteration 8, Epoch 3, Train Loss: 0.0113
# Iteration 8, Epoch 3, Validation Loss: 2.0636, Accuracy: 0.7465
# Iteration 8, Epoch 4, Train Loss: 0.0077
# Iteration 8, Epoch 4, Validation Loss: 1.8446, Accuracy: 0.7471
# Iteration 8, Epoch 5, Train Loss: 0.0056
# Iteration 8, Epoch 5, Validation Loss: 1.9557, Accuracy: 0.7542
# Iteration 8, Epoch 6, Train Loss: 0.0127
# Iteration 8, Epoch 6, Validation Loss: 1.5979, Accuracy: 0.7387
# Iteration 8, Epoch 7, Train Loss: 0.0080
# Iteration 8, Epoch 7, Validation Loss: 1.8729, Accuracy: 0.7490
# Iteration 8, Epoch 8, Train Loss: 0.0050
# Iteration 8, Epoch 8, Validation Loss: 1.9270, Accuracy: 0.7535
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 9/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 9: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6942 and female 5289 samples
# Balanced pseudo-labeled samples: Male - 5289, Female - 5289
# Iteration 9, Epoch 1, Train Loss: 0.0045
# Iteration 9, Epoch 1, Validation Loss: 2.2454, Accuracy: 0.7419
# Iteration 9, Epoch 2, Train Loss: 0.0230
# Iteration 9, Epoch 2, Validation Loss: 2.0607, Accuracy: 0.7419
# Iteration 9, Epoch 3, Train Loss: 0.0307
# Iteration 9, Epoch 3, Validation Loss: 1.7921, Accuracy: 0.7581
# Iteration 9, Epoch 4, Train Loss: 0.0057
# Iteration 9, Epoch 4, Validation Loss: 1.8212, Accuracy: 0.7639
# Iteration 9, Epoch 5, Train Loss: 0.0032
# Iteration 9, Epoch 5, Validation Loss: 1.8055, Accuracy: 0.7542
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 10/10 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 10: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 6943 and female 5290 samples
# Balanced pseudo-labeled samples: Male - 5290, Female - 5290
# Iteration 10, Epoch 1, Train Loss: 0.0098
# Iteration 10, Epoch 1, Validation Loss: 1.8428, Accuracy: 0.7665
# Iteration 10, Epoch 2, Train Loss: 0.0082
# Iteration 10, Epoch 2, Validation Loss: 1.8056, Accuracy: 0.7735
# Iteration 10, Epoch 3, Train Loss: 0.0037
# Iteration 10, Epoch 3, Validation Loss: 2.1091, Accuracy: 0.7542
# Iteration 10, Epoch 4, Train Loss: 0.0021
# Iteration 10, Epoch 4, Validation Loss: 2.3261, Accuracy: 0.7471
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# All experiments completed.

# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np

import requests

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")
test_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/Balanced_Validation")

# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Severe_East_Asian_Female_Bias",
    "Severe_East_Asian_Bias"
]
pseudo_label_thresholds = [0.9, 0.6]

# Define the transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# Define model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Self-training parameters
num_iterations = 5
num_epochs = 10
patience = 2

# Function to pseudo-balance the dataset
def pseudo_balancing(male_path, female_path):
    male_samples = os.listdir(male_path) if os.path.exists(male_path) else []
    female_samples = os.listdir(female_path) if os.path.exists(female_path) else []
    num_male = len(male_samples)
    num_female = len(female_samples)
    # Determine the target size for balancing
    target_size = min(num_male, num_female)
    # Randomly downsample the larger class
    if num_male > target_size:
        excess_male_samples = np.random.choice(male_samples, num_male - target_size, replace=False)
        for sample in excess_male_samples:
            os.remove(os.path.join(male_path, sample))
    elif num_female > target_size:
        excess_female_samples = np.random.choice(female_samples, num_female - target_size, replace=False)
        for sample in excess_female_samples:
            os.remove(os.path.join(female_path, sample))
    # Recount samples after balancing
    num_male = len(os.listdir(male_path))
    num_female = len(os.listdir(female_path))
    print(f"Balanced pseudo-labeled samples: Male - {num_male}, Female - {num_female}")
    return

# Loop over all experiments
for training_folder in training_folders:
 # Define the URL for the file
    url = "https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EVd9bFWzqztMrXRDdNnCHQkBsHaM4n5_1q1fue77vtQVtw?download=1"

    # Define the path where the file will be saved
    output_path = "classification_model.pth"
    # Send a GET request to download the file
    response = requests.get(url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        with open(output_path, "wb") as file:
            file.write(response.content)  # Write the content of the response to the file
        print(f"File downloaded successfully and saved as {output_path}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
    # Load pre-trained ResNet model
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    for pseudo_label_threshold in pseudo_label_thresholds:
        print(f"--- Starting Experiment: {training_folder}, Threshold: {pseudo_label_threshold} ---")
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Balanced_{training_folder}_{pseudo_label_threshold}")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_{pseudo_label_threshold}")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        for iteration in range(num_iterations):
            print(f"--- Starting Iteration {iteration + 1}/{num_iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling
            model.eval()
            new_samples = 0
            print("Pseudo-labeling unlabeled samples...")
            for filename in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, filename)
                img = Image.open(img_path).convert('RGB')  # Make sure it's RGB
                img = transforms_val(img)  # Apply transformations
                # Forward pass through the model
                with torch.no_grad():
                    inputs = img.unsqueeze(0).to(device)  # Unsqueeze to add batch dimension
                    outputs = model(inputs)
                    probs = torch.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                # Select samples with high confidence
                confident_mask = max_probs > pseudo_label_threshold
                if confident_mask.any():
                    for pred_label in preds[confident_mask]:
                        if pred_label == 1:
                            destination_folder = aaf_training_male_path
                        elif pred_label == 0:
                            destination_folder = aaf_training_female_path
                        else:
                            continue  # Skip samples with unexpected labels
                        # Move the image to the destination folder
                        shutil.copy(img_path, destination_folder)
                new_samples += 1
                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")
                del img, inputs, outputs, probs, max_probs, preds
                torch.cuda.empty_cache()

            print(f"Iteration {iteration + 1}: Added {new_samples} pseudo-labeled samples.")
            print(f"Number of pseudo-labeled male {len(os.listdir(aaf_training_male_path))} and female {len(os.listdir(aaf_training_female_path))} samples")

            # 3. Balance the training dataset
            pseudo_balancing(aaf_training_male_path, aaf_training_female_path)

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)

            # 4. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizer.step()
                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_balanced_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_balanced_best.pth'))
            print(f"Self-training completed for {training_folder}, Threshold: {pseudo_label_threshold}.")

print("All experiments completed.")
# Out:
# File downloaded successfully and saved as classification_model.pth
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\haohu\AppData\Local\Temp\ipykernel_16192\3531196264.py:99: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
# --- Starting Experiment: Severe_East_Asian_Female_Bias, Threshold: 0.9 ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 1: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 381 and female 1835 samples
# Balanced pseudo-labeled samples: Male - 381, Female - 381
# Iteration 1, Epoch 1, Train Loss: 0.0680
# Iteration 1, Epoch 1, Validation Loss: 0.7060, Accuracy: 0.7761
# Iteration 1, Epoch 2, Train Loss: 0.0349
# Iteration 1, Epoch 2, Validation Loss: 0.6947, Accuracy: 0.7800
# Iteration 1, Epoch 3, Train Loss: 0.0178
# Iteration 1, Epoch 3, Validation Loss: 0.7992, Accuracy: 0.7826
# Iteration 1, Epoch 4, Train Loss: 0.0248
# Iteration 1, Epoch 4, Validation Loss: 0.7717, Accuracy: 0.7858
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 2: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1355 and female 3001 samples
# Balanced pseudo-labeled samples: Male - 1355, Female - 1355
# Iteration 2, Epoch 1, Train Loss: 0.1328
# Iteration 2, Epoch 1, Validation Loss: 1.2854, Accuracy: 0.7774
# Iteration 2, Epoch 2, Train Loss: 0.0981
# Iteration 2, Epoch 2, Validation Loss: 1.1597, Accuracy: 0.7781
# Iteration 2, Epoch 3, Train Loss: 0.0512
# Iteration 2, Epoch 3, Validation Loss: 1.3618, Accuracy: 0.7742
# Iteration 2, Epoch 4, Train Loss: 0.0467
# Iteration 2, Epoch 4, Validation Loss: 1.3323, Accuracy: 0.7768
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 3: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1993 and female 3074 samples
# Balanced pseudo-labeled samples: Male - 1993, Female - 1993
# Iteration 3, Epoch 1, Train Loss: 0.1573
# Iteration 3, Epoch 1, Validation Loss: 1.0728, Accuracy: 0.7852
# Iteration 3, Epoch 2, Train Loss: 0.1180
# Iteration 3, Epoch 2, Validation Loss: 1.3275, Accuracy: 0.7606
# Iteration 3, Epoch 3, Train Loss: 0.0839
# Iteration 3, Epoch 3, Validation Loss: 1.6954, Accuracy: 0.7587
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 4: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2286 and female 3045 samples
# Balanced pseudo-labeled samples: Male - 2286, Female - 2286
# Iteration 4, Epoch 1, Train Loss: 0.1155
# Iteration 4, Epoch 1, Validation Loss: 1.3828, Accuracy: 0.7742
# Iteration 4, Epoch 2, Train Loss: 0.0884
# Iteration 4, Epoch 2, Validation Loss: 1.6117, Accuracy: 0.7613
# Iteration 4, Epoch 3, Train Loss: 0.0664
# Iteration 4, Epoch 3, Validation Loss: 1.7209, Accuracy: 0.7619
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 5: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2396 and female 3056 samples
# Balanced pseudo-labeled samples: Male - 2396, Female - 2396
# Iteration 5, Epoch 1, Train Loss: 0.0880
# Iteration 5, Epoch 1, Validation Loss: 1.7893, Accuracy: 0.7600
# Iteration 5, Epoch 2, Train Loss: 0.0534
# Iteration 5, Epoch 2, Validation Loss: 2.1783, Accuracy: 0.7510
# Iteration 5, Epoch 3, Train Loss: 0.0427
# Iteration 5, Epoch 3, Validation Loss: 2.0125, Accuracy: 0.7619
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Experiment: Severe_East_Asian_Female_Bias, Threshold: 0.6 ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 1: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2607 and female 3431 samples
# Balanced pseudo-labeled samples: Male - 2607, Female - 2607
# Iteration 1, Epoch 1, Train Loss: 0.1307
# Iteration 1, Epoch 1, Validation Loss: 1.2185, Accuracy: 0.7742
# Iteration 1, Epoch 2, Train Loss: 0.1008
# Iteration 1, Epoch 2, Validation Loss: 1.7778, Accuracy: 0.7555
# Iteration 1, Epoch 3, Train Loss: 0.0831
# Iteration 1, Epoch 3, Validation Loss: 1.6280, Accuracy: 0.7703
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 2: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2552 and female 3504 samples
# Balanced pseudo-labeled samples: Male - 2552, Female - 2552
# Iteration 2, Epoch 1, Train Loss: 0.0988
# Iteration 2, Epoch 1, Validation Loss: 1.5764, Accuracy: 0.7690
# Iteration 2, Epoch 2, Train Loss: 0.0735
# Iteration 2, Epoch 2, Validation Loss: 1.8750, Accuracy: 0.7645
# Iteration 2, Epoch 3, Train Loss: 0.0587
# Iteration 2, Epoch 3, Validation Loss: 1.8984, Accuracy: 0.7523
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 3: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2647 and female 3464 samples
# Balanced pseudo-labeled samples: Male - 2647, Female - 2647
# Iteration 3, Epoch 1, Train Loss: 0.0674
# Iteration 3, Epoch 1, Validation Loss: 1.8945, Accuracy: 0.7626
# Iteration 3, Epoch 2, Train Loss: 0.0568
# Iteration 3, Epoch 2, Validation Loss: 2.1703, Accuracy: 0.7523
# Iteration 3, Epoch 3, Train Loss: 0.0550
# Iteration 3, Epoch 3, Validation Loss: 1.6095, Accuracy: 0.7639
# Iteration 3, Epoch 4, Train Loss: 0.0271
# Iteration 3, Epoch 4, Validation Loss: 2.0119, Accuracy: 0.7465
# Iteration 3, Epoch 5, Train Loss: 0.0271
# Iteration 3, Epoch 5, Validation Loss: 2.0815, Accuracy: 0.7497
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 4: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2678 and female 3431 samples
# Balanced pseudo-labeled samples: Male - 2678, Female - 2678
# Iteration 4, Epoch 1, Train Loss: 0.0446
# Iteration 4, Epoch 1, Validation Loss: 2.0135, Accuracy: 0.7587
# Iteration 4, Epoch 2, Train Loss: 0.0330
# Iteration 4, Epoch 2, Validation Loss: 1.8023, Accuracy: 0.7652
# Iteration 4, Epoch 3, Train Loss: 0.0339
# Iteration 4, Epoch 3, Validation Loss: 2.3507, Accuracy: 0.7452
# Iteration 4, Epoch 4, Train Loss: 0.0287
# Iteration 4, Epoch 4, Validation Loss: 1.9126, Accuracy: 0.7665
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 5: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 2659 and female 3456 samples
# Balanced pseudo-labeled samples: Male - 2659, Female - 2659
# Iteration 5, Epoch 1, Train Loss: 0.0687
# Iteration 5, Epoch 1, Validation Loss: 1.9372, Accuracy: 0.7684
# Iteration 5, Epoch 2, Train Loss: 0.0529
# Iteration 5, Epoch 2, Validation Loss: 1.9298, Accuracy: 0.7613
# Iteration 5, Epoch 3, Train Loss: 0.0351
# Iteration 5, Epoch 3, Validation Loss: 1.9653, Accuracy: 0.7690
# Iteration 5, Epoch 4, Train Loss: 0.0222
# Iteration 5, Epoch 4, Validation Loss: 1.8181, Accuracy: 0.7748
# Iteration 5, Epoch 5, Train Loss: 0.0205
# Iteration 5, Epoch 5, Validation Loss: 2.2662, Accuracy: 0.7613
# Iteration 5, Epoch 6, Train Loss: 0.0199
# Iteration 5, Epoch 6, Validation Loss: 1.7905, Accuracy: 0.7581
# Iteration 5, Epoch 7, Train Loss: 0.0202
# Iteration 5, Epoch 7, Validation Loss: 2.3614, Accuracy: 0.7555
# Iteration 5, Epoch 8, Train Loss: 0.0164
# Iteration 5, Epoch 8, Validation Loss: 2.3173, Accuracy: 0.7632
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Severe_East_Asian_Bias, Threshold: 0.9 ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 1: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 3233 and female 1909 samples
# Balanced pseudo-labeled samples: Male - 1909, Female - 1909
# Iteration 1, Epoch 1, Train Loss: 0.0389
# Iteration 1, Epoch 1, Validation Loss: 0.6688, Accuracy: 0.7871
# Iteration 1, Epoch 2, Train Loss: 0.0178
# Iteration 1, Epoch 2, Validation Loss: 0.6755, Accuracy: 0.8026
# Iteration 1, Epoch 3, Train Loss: 0.0179
# Iteration 1, Epoch 3, Validation Loss: 0.6952, Accuracy: 0.7994
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.9.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 5295 and female 4219 samples
# Balanced pseudo-labeled samples: Male - 4219, Female - 4219
# Iteration 2, Epoch 1, Train Loss: 0.1110
# Iteration 2, Epoch 1, Validation Loss: 0.7939, Accuracy: 0.8032
# Iteration 2, Epoch 2, Train Loss: 0.0897
# Iteration 2, Epoch 2, Validation Loss: 0.7897, Accuracy: 0.8116
# Iteration 2, Epoch 3, Train Loss: 0.0609
# Iteration 2, Epoch 3, Validation Loss: 0.9300, Accuracy: 0.7968
# Iteration 2, Epoch 4, Train Loss: 0.0481
# Iteration 2, Epoch 4, Validation Loss: 0.8610, Accuracy: 0.8039
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.9.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 5749 and female 4886 samples
# Balanced pseudo-labeled samples: Male - 4886, Female - 4886
# Iteration 3, Epoch 1, Train Loss: 0.0918
# Iteration 3, Epoch 1, Validation Loss: 0.8764, Accuracy: 0.7935
# Iteration 3, Epoch 2, Train Loss: 0.0664
# Iteration 3, Epoch 2, Validation Loss: 0.9559, Accuracy: 0.8077
# Iteration 3, Epoch 3, Train Loss: 0.0561
# Iteration 3, Epoch 3, Validation Loss: 0.8987, Accuracy: 0.7981
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.9.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 4: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 5664 and female 5237 samples
# Balanced pseudo-labeled samples: Male - 5237, Female - 5237
# Iteration 4, Epoch 1, Train Loss: 0.0737
# Iteration 4, Epoch 1, Validation Loss: 0.7977, Accuracy: 0.8161
# Iteration 4, Epoch 2, Train Loss: 0.0442
# Iteration 4, Epoch 2, Validation Loss: 0.8834, Accuracy: 0.8000
# Iteration 4, Epoch 3, Train Loss: 0.0326
# Iteration 4, Epoch 3, Validation Loss: 1.1378, Accuracy: 0.8039
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.9.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 5: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6112 and female 5311 samples
# Balanced pseudo-labeled samples: Male - 5311, Female - 5311
# Iteration 5, Epoch 1, Train Loss: 0.0632
# Iteration 5, Epoch 1, Validation Loss: 0.9031, Accuracy: 0.8065
# Iteration 5, Epoch 2, Train Loss: 0.0485
# Iteration 5, Epoch 2, Validation Loss: 0.9556, Accuracy: 0.8168
# Iteration 5, Epoch 3, Train Loss: 0.0422
# Iteration 5, Epoch 3, Validation Loss: 0.9276, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.9.
# --- Starting Experiment: Severe_East_Asian_Bias, Threshold: 0.6 ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 1: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6552 and female 5581 samples
# Balanced pseudo-labeled samples: Male - 5581, Female - 5581
# Iteration 1, Epoch 1, Train Loss: 0.1039
# Iteration 1, Epoch 1, Validation Loss: 0.7865, Accuracy: 0.8097
# Iteration 1, Epoch 2, Train Loss: 0.0718
# Iteration 1, Epoch 2, Validation Loss: 0.8324, Accuracy: 0.8084
# Iteration 1, Epoch 3, Train Loss: 0.0491
# Iteration 1, Epoch 3, Validation Loss: 1.0174, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.6.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6552 and female 5661 samples
# Balanced pseudo-labeled samples: Male - 5661, Female - 5661
# Iteration 2, Epoch 1, Train Loss: 0.0625
# Iteration 2, Epoch 1, Validation Loss: 0.9630, Accuracy: 0.8123
# Iteration 2, Epoch 2, Train Loss: 0.0466
# Iteration 2, Epoch 2, Validation Loss: 0.9442, Accuracy: 0.8271
# Iteration 2, Epoch 3, Train Loss: 0.0333
# Iteration 2, Epoch 3, Validation Loss: 1.0192, Accuracy: 0.8245
# Iteration 2, Epoch 4, Train Loss: 0.0278
# Iteration 2, Epoch 4, Validation Loss: 1.1504, Accuracy: 0.8142
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.6.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6494 and female 5746 samples
# Balanced pseudo-labeled samples: Male - 5746, Female - 5746
# Iteration 3, Epoch 1, Train Loss: 0.0530
# Iteration 3, Epoch 1, Validation Loss: 0.8077, Accuracy: 0.8194
# Iteration 3, Epoch 2, Train Loss: 0.0407
# Iteration 3, Epoch 2, Validation Loss: 1.0052, Accuracy: 0.8045
# Iteration 3, Epoch 3, Train Loss: 0.0345
# Iteration 3, Epoch 3, Validation Loss: 1.1077, Accuracy: 0.8168
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.6.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 4: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6578 and female 5658 samples
# Balanced pseudo-labeled samples: Male - 5658, Female - 5658
# Iteration 4, Epoch 1, Train Loss: 0.0533
# Iteration 4, Epoch 1, Validation Loss: 0.9464, Accuracy: 0.8277
# Iteration 4, Epoch 2, Train Loss: 0.0372
# Iteration 4, Epoch 2, Validation Loss: 1.1121, Accuracy: 0.8200
# Iteration 4, Epoch 3, Train Loss: 0.0300
# Iteration 4, Epoch 3, Validation Loss: 1.2571, Accuracy: 0.8219
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.6.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 12287
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 5: Added 12287 pseudo-labeled samples.
# Number of pseudo-labeled male 6615 and female 5631 samples
# Balanced pseudo-labeled samples: Male - 5631, Female - 5631
# Iteration 5, Epoch 1, Train Loss: 0.0450
# Iteration 5, Epoch 1, Validation Loss: 1.1505, Accuracy: 0.8071
# Iteration 5, Epoch 2, Train Loss: 0.0328
# Iteration 5, Epoch 2, Validation Loss: 1.0673, Accuracy: 0.8168
# Iteration 5, Epoch 3, Train Loss: 0.0219
# Iteration 5, Epoch 3, Validation Loss: 1.2467, Accuracy: 0.8194
# Iteration 5, Epoch 4, Train Loss: 0.0221
# Iteration 5, Epoch 4, Validation Loss: 1.3154, Accuracy: 0.7890
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias, Threshold: 0.6.
# All experiments completed.

# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")
test_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/Balanced_Validation")

# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Unlabeled",
    "Gender_Balanced_Unlabeled",
    "Severe_Male_Gender",
    "Severe_Black_Bias",
    "Severe_East_Asian_Female_Bias"
]

pseudo_label_thresholds = [0.9, 0.6]
# Define the transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# Define model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Self-training parameters
num_iterations = 3
num_epochs = 10
patience = 2

# Loop over all experiments
for training_folder in training_folders:
     # Define the URL for the file
    url = "https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EVd9bFWzqztMrXRDdNnCHQkBsHaM4n5_1q1fue77vtQVtw?download=1"

    # Define the path where the file will be saved
    output_path = "classification_model.pth"
    # Send a GET request to download the file
    response = requests.get(url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        with open(output_path, "wb") as file:
            file.write(response.content)  # Write the content of the response to the file
        print(f"File downloaded successfully and saved as {output_path}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
    # Load pre-trained ResNet model
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    for pseudo_label_threshold in pseudo_label_thresholds:
        print(f"--- Starting Experiment: {training_folder}, Threshold: {pseudo_label_threshold} ---")
        
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Unbalanced_{training_folder}_{pseudo_label_threshold}")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_{pseudo_label_threshold}")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        for iteration in range(num_iterations):
            print(f"--- Starting Iteration {iteration + 1}/{num_iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling
            model.eval()
            new_samples = 0
            print("Pseudo-labeling unlabeled samples...")
            for filename in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, filename)
                img = Image.open(img_path).convert('RGB')  # Make sure it's RGB
                img = transforms_val(img)  # Apply transformations
                # Forward pass through the model
                with torch.no_grad():
                    inputs = img.unsqueeze(0).to(device)  # Unsqueeze to add batch dimension
                    outputs = model(inputs)
                    probs = torch.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                # Select samples with high confidence
                confident_mask = max_probs > pseudo_label_threshold
                if confident_mask.any():
                    for pred_label in preds[confident_mask]:
                        if pred_label == 1:
                            destination_folder = aaf_training_male_path
                        elif pred_label == 0:
                            destination_folder = aaf_training_female_path
                        else:
                            continue  # Skip samples with unexpected labels
                        # Move the image to the destination folder
                        shutil.copy(img_path, destination_folder)
                new_samples += 1
                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")
                del img, inputs, outputs, probs, max_probs, preds
                torch.cuda.empty_cache()

            print(f"Iteration {iteration + 1}: Added {new_samples} pseudo-labeled samples.")
            print(f"Number of pseudo-labeled male {len(os.listdir(aaf_training_male_path))} and female {len(os.listdir(aaf_training_female_path))} samples")

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)

            # 4. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizer.step()
                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_unbalanced_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_unbalanced_best.pth'))
            print(f"Self-training completed for {training_folder}, Threshold: {pseudo_label_threshold}.")

print("All experiments completed.")
# Out:
# File downloaded successfully and saved as classification_model.pth
# C:\Users\haohu\AppData\Local\Temp\ipykernel_16192\3443443054.py:77: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
# --- Starting Experiment: Unlabeled, Threshold: 0.9 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 1: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 28244 and female 12927 samples
# Iteration 1, Epoch 1, Train Loss: 0.0304
# Iteration 1, Epoch 1, Validation Loss: 0.7713, Accuracy: 0.7806
# Iteration 1, Epoch 2, Train Loss: 0.0153
# Iteration 1, Epoch 2, Validation Loss: 1.0568, Accuracy: 0.7755
# Iteration 1, Epoch 3, Train Loss: 0.0107
# Iteration 1, Epoch 3, Validation Loss: 0.9578, Accuracy: 0.7903
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 2: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 48197 and female 25500 samples
# Iteration 2, Epoch 1, Train Loss: 0.0918
# Iteration 2, Epoch 1, Validation Loss: 1.0313, Accuracy: 0.7929
# Iteration 2, Epoch 2, Train Loss: 0.0625
# Iteration 2, Epoch 2, Validation Loss: 1.0624, Accuracy: 0.7916
# Iteration 2, Epoch 3, Train Loss: 0.0479
# Iteration 2, Epoch 3, Validation Loss: 0.9159, Accuracy: 0.7961
# Iteration 2, Epoch 4, Train Loss: 0.0383
# Iteration 2, Epoch 4, Validation Loss: 1.1229, Accuracy: 0.7955
# Iteration 2, Epoch 5, Train Loss: 0.0354
# Iteration 2, Epoch 5, Validation Loss: 1.1006, Accuracy: 0.8084
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 3: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 51511 and female 25736 samples
# Iteration 3, Epoch 1, Train Loss: 0.0446
# Iteration 3, Epoch 1, Validation Loss: 0.9640, Accuracy: 0.8135
# Iteration 3, Epoch 2, Train Loss: 0.0343
# Iteration 3, Epoch 2, Validation Loss: 1.5050, Accuracy: 0.7994
# Iteration 3, Epoch 3, Train Loss: 0.0305
# Iteration 3, Epoch 3, Validation Loss: 1.6073, Accuracy: 0.7877
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.9.
# --- Starting Experiment: Unlabeled, Threshold: 0.6 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 1: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 56760 and female 28647 samples
# Iteration 1, Epoch 1, Train Loss: 0.0925
# Iteration 1, Epoch 1, Validation Loss: 1.0141, Accuracy: 0.7935
# Iteration 1, Epoch 2, Train Loss: 0.0776
# Iteration 1, Epoch 2, Validation Loss: 1.3454, Accuracy: 0.7877
# Iteration 1, Epoch 3, Train Loss: 0.0651
# Iteration 1, Epoch 3, Validation Loss: 1.2761, Accuracy: 0.7987
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 2: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 57384 and female 28412 samples
# Iteration 2, Epoch 1, Train Loss: 0.0694
# Iteration 2, Epoch 1, Validation Loss: 1.2343, Accuracy: 0.8065
# Iteration 2, Epoch 2, Train Loss: 0.0592
# Iteration 2, Epoch 2, Validation Loss: 1.2031, Accuracy: 0.8058
# Iteration 2, Epoch 3, Train Loss: 0.0497
# Iteration 2, Epoch 3, Validation Loss: 1.5174, Accuracy: 0.7948
# Iteration 2, Epoch 4, Train Loss: 0.0448
# Iteration 2, Epoch 4, Validation Loss: 1.3239, Accuracy: 0.7929
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 86744
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# Iteration 3: Added 86744 pseudo-labeled samples.
# Number of pseudo-labeled male 56603 and female 29425 samples
# Iteration 3, Epoch 1, Train Loss: 0.0592
# Iteration 3, Epoch 1, Validation Loss: 1.2136, Accuracy: 0.7910
# Iteration 3, Epoch 2, Train Loss: 0.0469
# Iteration 3, Epoch 2, Validation Loss: 1.1761, Accuracy: 0.7923
# Iteration 3, Epoch 3, Train Loss: 0.0404
# Iteration 3, Epoch 3, Validation Loss: 1.3622, Accuracy: 0.7968
# Iteration 3, Epoch 4, Train Loss: 0.0344
# Iteration 3, Epoch 4, Validation Loss: 1.7008, Accuracy: 0.7948
# Early stopping triggered.
# Self-training completed for Unlabeled, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Gender_Balanced_Unlabeled, Threshold: 0.9 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 14097 and female 6479 samples
# Iteration 1, Epoch 1, Train Loss: 0.0369
# Iteration 1, Epoch 1, Validation Loss: 0.8101, Accuracy: 0.7826
# Iteration 1, Epoch 2, Train Loss: 0.0211
# Iteration 1, Epoch 2, Validation Loss: 0.8088, Accuracy: 0.7968
# Iteration 1, Epoch 3, Train Loss: 0.0145
# Iteration 1, Epoch 3, Validation Loss: 0.9106, Accuracy: 0.7839
# Iteration 1, Epoch 4, Train Loss: 0.0095
# Iteration 1, Epoch 4, Validation Loss: 0.9296, Accuracy: 0.7768
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 23931 and female 11888 samples
# Iteration 2, Epoch 1, Train Loss: 0.0933
# Iteration 2, Epoch 1, Validation Loss: 0.8442, Accuracy: 0.7929
# Iteration 2, Epoch 2, Train Loss: 0.0632
# Iteration 2, Epoch 2, Validation Loss: 0.9690, Accuracy: 0.7961
# Iteration 2, Epoch 3, Train Loss: 0.0468
# Iteration 2, Epoch 3, Validation Loss: 1.0690, Accuracy: 0.7890
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 25313 and female 12613 samples
# Iteration 3, Epoch 1, Train Loss: 0.0666
# Iteration 3, Epoch 1, Validation Loss: 1.0690, Accuracy: 0.7819
# Iteration 3, Epoch 2, Train Loss: 0.0513
# Iteration 3, Epoch 2, Validation Loss: 1.1487, Accuracy: 0.7916
# Iteration 3, Epoch 3, Train Loss: 0.0357
# Iteration 3, Epoch 3, Validation Loss: 1.1661, Accuracy: 0.7974
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.9.
# --- Starting Experiment: Gender_Balanced_Unlabeled, Threshold: 0.6 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 27243 and female 15433 samples
# Iteration 1, Epoch 1, Train Loss: 0.1162
# Iteration 1, Epoch 1, Validation Loss: 0.9778, Accuracy: 0.7832
# Iteration 1, Epoch 2, Train Loss: 0.0894
# Iteration 1, Epoch 2, Validation Loss: 0.9188, Accuracy: 0.8116
# Iteration 1, Epoch 3, Train Loss: 0.0712
# Iteration 1, Epoch 3, Validation Loss: 1.1703, Accuracy: 0.7903
# Iteration 1, Epoch 4, Train Loss: 0.0625
# Iteration 1, Epoch 4, Validation Loss: 1.2537, Accuracy: 0.7897
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 27540 and female 15436 samples
# Iteration 2, Epoch 1, Train Loss: 0.0750
# Iteration 2, Epoch 1, Validation Loss: 1.0782, Accuracy: 0.7916
# Iteration 2, Epoch 2, Train Loss: 0.0597
# Iteration 2, Epoch 2, Validation Loss: 1.3284, Accuracy: 0.8026
# Iteration 2, Epoch 3, Train Loss: 0.0532
# Iteration 2, Epoch 3, Validation Loss: 1.3246, Accuracy: 0.7929
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 43372
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 43372 pseudo-labeled samples.
# Number of pseudo-labeled male 27861 and female 15175 samples
# Iteration 3, Epoch 1, Train Loss: 0.0618
# Iteration 3, Epoch 1, Validation Loss: 1.1471, Accuracy: 0.8013
# Iteration 3, Epoch 2, Train Loss: 0.0500
# Iteration 3, Epoch 2, Validation Loss: 1.4405, Accuracy: 0.7916
# Iteration 3, Epoch 3, Train Loss: 0.0425
# Iteration 3, Epoch 3, Validation Loss: 1.3307, Accuracy: 0.7948
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Severe_Male_Gender, Threshold: 0.9 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 20761 and female 3017 samples
# Iteration 1, Epoch 1, Train Loss: 0.0248
# Iteration 1, Epoch 1, Validation Loss: 0.8331, Accuracy: 0.7865
# Iteration 1, Epoch 2, Train Loss: 0.0086
# Iteration 1, Epoch 2, Validation Loss: 0.9050, Accuracy: 0.7877
# Iteration 1, Epoch 3, Train Loss: 0.0070
# Iteration 1, Epoch 3, Validation Loss: 0.8368, Accuracy: 0.7845
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 31516 and female 6776 samples
# Iteration 2, Epoch 1, Train Loss: 0.0756
# Iteration 2, Epoch 1, Validation Loss: 0.9082, Accuracy: 0.7813
# Iteration 2, Epoch 2, Train Loss: 0.0517
# Iteration 2, Epoch 2, Validation Loss: 1.0076, Accuracy: 0.7852
# Iteration 2, Epoch 3, Train Loss: 0.0354
# Iteration 2, Epoch 3, Validation Loss: 1.0020, Accuracy: 0.7994
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 32894 and female 7707 samples
# Iteration 3, Epoch 1, Train Loss: 0.0535
# Iteration 3, Epoch 1, Validation Loss: 0.8943, Accuracy: 0.8052
# Iteration 3, Epoch 2, Train Loss: 0.0414
# Iteration 3, Epoch 2, Validation Loss: 1.2018, Accuracy: 0.7968
# Iteration 3, Epoch 3, Train Loss: 0.0321
# Iteration 3, Epoch 3, Validation Loss: 0.9874, Accuracy: 0.8045
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.9.
# --- Starting Experiment: Severe_Male_Gender, Threshold: 0.6 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 1: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 34572 and female 9734 samples
# Iteration 1, Epoch 1, Train Loss: 0.0982
# Iteration 1, Epoch 1, Validation Loss: 0.9478, Accuracy: 0.7955
# Iteration 1, Epoch 2, Train Loss: 0.0742
# Iteration 1, Epoch 2, Validation Loss: 0.7425, Accuracy: 0.8065
# Iteration 1, Epoch 3, Train Loss: 0.0627
# Iteration 1, Epoch 3, Validation Loss: 0.9065, Accuracy: 0.7994
# Iteration 1, Epoch 4, Train Loss: 0.0498
# Iteration 1, Epoch 4, Validation Loss: 1.1310, Accuracy: 0.7955
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 2: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 35022 and female 9537 samples
# Iteration 2, Epoch 1, Train Loss: 0.0656
# Iteration 2, Epoch 1, Validation Loss: 1.0407, Accuracy: 0.7955
# Iteration 2, Epoch 2, Train Loss: 0.0493
# Iteration 2, Epoch 2, Validation Loss: 1.0597, Accuracy: 0.8019
# Iteration 2, Epoch 3, Train Loss: 0.0433
# Iteration 2, Epoch 3, Validation Loss: 1.1499, Accuracy: 0.7948
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 44941
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Iteration 3: Added 44941 pseudo-labeled samples.
# Number of pseudo-labeled male 34891 and female 9770 samples
# Iteration 3, Epoch 1, Train Loss: 0.0532
# Iteration 3, Epoch 1, Validation Loss: 1.1578, Accuracy: 0.7916
# Iteration 3, Epoch 2, Train Loss: 0.0413
# Iteration 3, Epoch 2, Validation Loss: 1.2751, Accuracy: 0.7935
# Iteration 3, Epoch 3, Train Loss: 0.0306
# Iteration 3, Epoch 3, Validation Loss: 1.2168, Accuracy: 0.7974
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Severe_Black_Bias, Threshold: 0.9 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 1: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 3646 and female 1197 samples
# Iteration 1, Epoch 1, Train Loss: 0.0632
# Iteration 1, Epoch 1, Validation Loss: 0.6385, Accuracy: 0.7935
# Iteration 1, Epoch 2, Train Loss: 0.0320
# Iteration 1, Epoch 2, Validation Loss: 0.8910, Accuracy: 0.7574
# Iteration 1, Epoch 3, Train Loss: 0.0222
# Iteration 1, Epoch 3, Validation Loss: 0.9492, Accuracy: 0.7716
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 8019 and female 1828 samples
# Iteration 2, Epoch 1, Train Loss: 0.0834
# Iteration 2, Epoch 1, Validation Loss: 1.1492, Accuracy: 0.7490
# Iteration 2, Epoch 2, Train Loss: 0.0587
# Iteration 2, Epoch 2, Validation Loss: 1.1004, Accuracy: 0.7684
# Iteration 2, Epoch 3, Train Loss: 0.0401
# Iteration 2, Epoch 3, Validation Loss: 1.1150, Accuracy: 0.7652
# Iteration 2, Epoch 4, Train Loss: 0.0345
# Iteration 2, Epoch 4, Validation Loss: 1.1366, Accuracy: 0.7755
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 8294 and female 2397 samples
# Iteration 3, Epoch 1, Train Loss: 0.0754
# Iteration 3, Epoch 1, Validation Loss: 1.6278, Accuracy: 0.7497
# Iteration 3, Epoch 2, Train Loss: 0.0597
# Iteration 3, Epoch 2, Validation Loss: 1.3668, Accuracy: 0.7626
# Iteration 3, Epoch 3, Train Loss: 0.0434
# Iteration 3, Epoch 3, Validation Loss: 1.2172, Accuracy: 0.7852
# Iteration 3, Epoch 4, Train Loss: 0.0406
# Iteration 3, Epoch 4, Validation Loss: 1.3938, Accuracy: 0.7684
# Iteration 3, Epoch 5, Train Loss: 0.0364
# Iteration 3, Epoch 5, Validation Loss: 1.5212, Accuracy: 0.7742
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.9.
# --- Starting Experiment: Severe_Black_Bias, Threshold: 0.6 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 1: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 9277 and female 2776 samples
# Iteration 1, Epoch 1, Train Loss: 0.1117
# Iteration 1, Epoch 1, Validation Loss: 1.2226, Accuracy: 0.7619
# Iteration 1, Epoch 2, Train Loss: 0.0740
# Iteration 1, Epoch 2, Validation Loss: 1.1180, Accuracy: 0.7729
# Iteration 1, Epoch 3, Train Loss: 0.0618
# Iteration 1, Epoch 3, Validation Loss: 1.7282, Accuracy: 0.7529
# Iteration 1, Epoch 4, Train Loss: 0.0465
# Iteration 1, Epoch 4, Validation Loss: 1.5871, Accuracy: 0.7671
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 2: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 9369 and female 2810 samples
# Iteration 2, Epoch 1, Train Loss: 0.0549
# Iteration 2, Epoch 1, Validation Loss: 1.5363, Accuracy: 0.7671
# Iteration 2, Epoch 2, Train Loss: 0.0375
# Iteration 2, Epoch 2, Validation Loss: 1.7735, Accuracy: 0.7716
# Iteration 2, Epoch 3, Train Loss: 0.0311
# Iteration 2, Epoch 3, Validation Loss: 1.6178, Accuracy: 0.7606
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 12233
# Pseudo-labeling unlabeled samples...
# Processed 10000 images
# Iteration 3: Added 12233 pseudo-labeled samples.
# Number of pseudo-labeled male 9396 and female 2784 samples
# Iteration 3, Epoch 1, Train Loss: 0.0445
# Iteration 3, Epoch 1, Validation Loss: 1.4928, Accuracy: 0.7710
# Iteration 3, Epoch 2, Train Loss: 0.0328
# Iteration 3, Epoch 2, Validation Loss: 1.5300, Accuracy: 0.7735
# Iteration 3, Epoch 3, Train Loss: 0.0227
# Iteration 3, Epoch 3, Validation Loss: 1.8505, Accuracy: 0.7606
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias, Threshold: 0.6.
# File downloaded successfully and saved as classification_model.pth
# --- Starting Experiment: Severe_East_Asian_Female_Bias, Threshold: 0.9 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 1: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 381 and female 1835 samples
# Iteration 1, Epoch 1, Train Loss: 0.1302
# Iteration 1, Epoch 1, Validation Loss: 0.7736, Accuracy: 0.7768
# Iteration 1, Epoch 2, Train Loss: 0.0302
# Iteration 1, Epoch 2, Validation Loss: 0.7245, Accuracy: 0.7742
# Iteration 1, Epoch 3, Train Loss: 0.0210
# Iteration 1, Epoch 3, Validation Loss: 0.7541, Accuracy: 0.7942
# Iteration 1, Epoch 4, Train Loss: 0.0093
# Iteration 1, Epoch 4, Validation Loss: 0.7616, Accuracy: 0.7884
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 2: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1182 and female 3504 samples
# Iteration 2, Epoch 1, Train Loss: 0.0983
# Iteration 2, Epoch 1, Validation Loss: 0.8726, Accuracy: 0.7735
# Iteration 2, Epoch 2, Train Loss: 0.0844
# Iteration 2, Epoch 2, Validation Loss: 0.9149, Accuracy: 0.7729
# Iteration 2, Epoch 3, Train Loss: 0.0652
# Iteration 2, Epoch 3, Validation Loss: 1.0137, Accuracy: 0.7626
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 3: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1335 and female 3888 samples
# Iteration 3, Epoch 1, Train Loss: 0.0725
# Iteration 3, Epoch 1, Validation Loss: 1.0937, Accuracy: 0.7613
# Iteration 3, Epoch 2, Train Loss: 0.0667
# Iteration 3, Epoch 2, Validation Loss: 1.2588, Accuracy: 0.7671
# Iteration 3, Epoch 3, Train Loss: 0.0418
# Iteration 3, Epoch 3, Validation Loss: 1.1948, Accuracy: 0.7716
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.9.
# --- Starting Experiment: Severe_East_Asian_Female_Bias, Threshold: 0.6 ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 1: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1686 and female 4326 samples
# Iteration 1, Epoch 1, Train Loss: 0.1470
# Iteration 1, Epoch 1, Validation Loss: 1.1474, Accuracy: 0.7484
# Iteration 1, Epoch 2, Train Loss: 0.0957
# Iteration 1, Epoch 2, Validation Loss: 1.0256, Accuracy: 0.7581
# Iteration 1, Epoch 3, Train Loss: 0.0808
# Iteration 1, Epoch 3, Validation Loss: 1.1037, Accuracy: 0.7555
# Iteration 1, Epoch 4, Train Loss: 0.0566
# Iteration 1, Epoch 4, Validation Loss: 1.1269, Accuracy: 0.7561
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 2: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1713 and female 4373 samples
# Iteration 2, Epoch 1, Train Loss: 0.0721
# Iteration 2, Epoch 1, Validation Loss: 1.0964, Accuracy: 0.7594
# Iteration 2, Epoch 2, Train Loss: 0.0598
# Iteration 2, Epoch 2, Validation Loss: 1.2742, Accuracy: 0.7555
# Iteration 2, Epoch 3, Train Loss: 0.0489
# Iteration 2, Epoch 3, Validation Loss: 1.1072, Accuracy: 0.7581
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 6141
# Pseudo-labeling unlabeled samples...
# Iteration 3: Added 6141 pseudo-labeled samples.
# Number of pseudo-labeled male 1678 and female 4432 samples
# Iteration 3, Epoch 1, Train Loss: 0.0474
# Iteration 3, Epoch 1, Validation Loss: 1.2165, Accuracy: 0.7658
# Iteration 3, Epoch 2, Train Loss: 0.0429
# Iteration 3, Epoch 2, Validation Loss: 1.2608, Accuracy: 0.7574
# Iteration 3, Epoch 3, Train Loss: 0.0374
# Iteration 3, Epoch 3, Validation Loss: 1.2668, Accuracy: 0.7619
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias, Threshold: 0.6.
# All experiments completed.

# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np

import requests

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")
test_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/Balanced_Validation")

# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Severe_East_Asian_Female_Bias",
    "Severe_East_Asian_Bias"
]
pseudo_label_thresholds = [0.9, 0.6]

# Define the transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)

# Define model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Self-training parameters
num_iterations = 5
num_epochs = 10
patience = 2

# Function to pseudo-balance the dataset
def pseudo_balancing(male_path, female_path):
    male_samples = os.listdir(male_path) if os.path.exists(male_path) else []
    female_samples = os.listdir(female_path) if os.path.exists(female_path) else []
    num_male = len(male_samples)
    num_female = len(female_samples)
    # Determine the target size for balancing
    target_size = min(num_male, num_female)
    # Randomly downsample the larger class
    if num_male > target_size:
        excess_male_samples = np.random.choice(male_samples, num_male - target_size, replace=False)
        for sample in excess_male_samples:
            os.remove(os.path.join(male_path, sample))
    elif num_female > target_size:
        excess_female_samples = np.random.choice(female_samples, num_female - target_size, replace=False)
        for sample in excess_female_samples:
            os.remove(os.path.join(female_path, sample))
    # Recount samples after balancing
    num_male = len(os.listdir(male_path))
    num_female = len(os.listdir(female_path))
    print(f"Balanced pseudo-labeled samples: Male - {num_male}, Female - {num_female}")
    return

# Loop over all experiments
for training_folder in training_folders:
 # Define the URL for the file
    url = "https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EVd9bFWzqztMrXRDdNnCHQkBsHaM4n5_1q1fue77vtQVtw?download=1"

    # Define the path where the file will be saved
    output_path = "classification_model.pth"
    # Send a GET request to download the file
    response = requests.get(url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        with open(output_path, "wb") as file:
            file.write(response.content)  # Write the content of the response to the file
        print(f"File downloaded successfully and saved as {output_path}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
    # Load pre-trained ResNet model
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    for pseudo_label_threshold in pseudo_label_thresholds:
        print(f"--- Starting Experiment: {training_folder}, Threshold: {pseudo_label_threshold} ---")
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Unbalanced_{training_folder}_{pseudo_label_threshold}")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_{pseudo_label_threshold}")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        for iteration in range(num_iterations):
            print(f"--- Starting Iteration {iteration + 1}/{num_iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling
            model.eval()
            new_samples = 0
            print("Pseudo-labeling unlabeled samples...")
            for filename in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, filename)
                img = Image.open(img_path).convert('RGB')  # Make sure it's RGB
                img = transforms_val(img)  # Apply transformations
                # Forward pass through the model
                with torch.no_grad():
                    inputs = img.unsqueeze(0).to(device)  # Unsqueeze to add batch dimension
                    outputs = model(inputs)
                    probs = torch.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                # Select samples with high confidence
                confident_mask = max_probs > pseudo_label_threshold
                if confident_mask.any():
                    for pred_label in preds[confident_mask]:
                        if pred_label == 1:
                            destination_folder = aaf_training_male_path
                        elif pred_label == 0:
                            destination_folder = aaf_training_female_path
                        else:
                            continue  # Skip samples with unexpected labels
                        # Move the image to the destination folder
                        shutil.copy(img_path, destination_folder)
                new_samples += 1
                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")
                del img, inputs, outputs, probs, max_probs, preds
                torch.cuda.empty_cache()

            print(f"Iteration {iteration + 1}: Added {new_samples} pseudo-labeled samples.")
            print(f"Number of pseudo-labeled male {len(os.listdir(aaf_training_male_path))} and female {len(os.listdir(aaf_training_female_path))} samples")

            # 3. Balance the training dataset
            # pseudo_balancing(aaf_training_male_path, aaf_training_female_path)

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)

            # 4. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizer.step()
                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_unbalanced_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'Controlled_Bias_{pseudo_label_threshold}_{iteration + 1}_unbalanced_best.pth'))
            print(f"Self-training completed for {training_folder}, Threshold: {pseudo_label_threshold}.")

print("All experiments completed.")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
import shutil
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from PIL import Image
import requests

# Define the non-linear mapping function (e.g., convex function)
def non_linear_mapping(x):
    return x / (2 - x)  # Convex function for threshold adjustment

# Initialize class-specific thresholds and counts
num_classes = 2  # Male and Female
base_threshold = 0.95  # Base confidence threshold for pseudo-labeling
iterations = 5  # Number of self-training iterations
num_epochs = 10  # Epochs per iteration
batch_size = 16
patience = 2  # Early stopping patience

# Define device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")

# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Unlabeled",
    "Gender_Balanced_Unlabeled",
    "Severe_Male_Gender",
    "Severe_Female_Gender",
    "Severe_Black_Bias",
    "Severe_East_Asian_Bias",
    "Severe_East_Asian_Female_Bias"
]  
# Define transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = datasets.ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Define model
def load_pretrained_model():
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    return model

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Function to pseudo-balance the dataset
def pseudo_balancing(male_path, female_path):
    male_samples = os.listdir(male_path) if os.path.exists(male_path) else []
    female_samples = os.listdir(female_path) if os.path.exists(female_path) else []
    num_male = len(male_samples)
    num_female = len(female_samples)
    target_size = min(num_male, num_female)
    if num_male > target_size:
        excess_male_samples = np.random.choice(male_samples, num_male - target_size, replace=False)
        for sample in excess_male_samples:
            os.remove(os.path.join(male_path, sample))
    elif num_female > target_size:
        excess_female_samples = np.random.choice(female_samples, num_female - target_size, replace=False)
        for sample in excess_female_samples:
            os.remove(os.path.join(female_path, sample))
    num_male = len(os.listdir(male_path))
    num_female = len(os.listdir(female_path))
    print(f"Balanced pseudo-labeled samples: Male - {num_male}, Female - {num_female}")
    return

# Loop over all experiments
for training_folder in training_folders:
        print(f"--- Starting Experiment: {training_folder} ---")
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Balanced_{training_folder}_FlexMatch")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_FlexMatch")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        # Load pre-trained model
        model = load_pretrained_model()
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

        # Initialize class thresholds and counts
        class_thresholds = torch.ones(num_classes) * base_threshold

        for iteration in range(iterations):
            print(f"--- Starting Iteration {iteration + 1}/{iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder, ignore_errors=True)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling using FlexMatch
            model.eval()
            class_counts = torch.zeros(num_classes)
            new_samples = 0

            for unlabeled_data in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, unlabeled_data)
                img = Image.open(img_path).convert('RGB')
                input = transforms_val(img).unsqueeze(0).to(device)

                with torch.no_grad():
                    output = model(input)
                    probs = F.softmax(output, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                    # Apply FlexMatch thresholds
                    for c in range(num_classes):
                        mask = (preds == c) & (max_probs > class_thresholds[c])
                        if mask.any():
                            class_counts[c] += mask.sum().item()
                            if c == 0:
                                shutil.copy(img_path, os.path.join(aaf_training_female_path, unlabeled_data))
                            elif c == 1:
                                shutil.copy(img_path, os.path.join(aaf_training_male_path, unlabeled_data))
                            new_samples += 1

                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")

            # 3. Update class thresholds based on learning status
            normalized_counts = class_counts / class_counts.sum()
            for c in range(num_classes):
                class_thresholds[c] = non_linear_mapping(normalized_counts[c]) * base_threshold

            print("FlexMatch thresholds of the two classes:", class_thresholds)

            # 4. Balance the training dataset
            pseudo_balancing(aaf_training_male_path, aaf_training_female_path)

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = datasets.ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

            # 5. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    probs = F.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                    # Supervised loss
                    supervised_loss = criterion(outputs, labels)

                    # Unsupervised loss (FlexMatch)
                    unsupervised_loss = 0.0
                    for c in range(num_classes):
                        mask = (preds == c) & (max_probs > class_thresholds[c])
                        if mask.any():
                            unsupervised_loss += F.cross_entropy(outputs[mask], preds[mask])

                    # Total loss
                    loss = supervised_loss + unsupervised_loss
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"FlexMatch_{iteration + 1}_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'FlexMatch_{iteration + 1}_final.pth'))
            print(f"Self-training completed for {training_folder}.")

print("All experiments completed.")
# Out:
# --- Starting Experiment: Unlabeled ---
# C:\Users\haohu\AppData\Local\Temp\ipykernel_16192\1389751758.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 86744
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# Processed 10000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 30000 images
# Processed 30000 images
# Processed 30000 images
# FlexMatch thresholds of the two classes: tensor([0.1686, 0.5100])
# Balanced pseudo-labeled samples: Male - 9499, Female - 9499
# Iteration 1, Epoch 1, Train Loss: 0.0302
# Iteration 1, Epoch 1, Validation Loss: 0.9623, Accuracy: 0.7826
# Iteration 1, Epoch 2, Train Loss: 0.0260
# Iteration 1, Epoch 2, Validation Loss: 0.9308, Accuracy: 0.7806
# Iteration 1, Epoch 3, Train Loss: 0.0132
# Iteration 1, Epoch 3, Validation Loss: 0.8846, Accuracy: 0.7923
# Iteration 1, Epoch 4, Train Loss: 0.0198
# Iteration 1, Epoch 4, Validation Loss: 0.9437, Accuracy: 0.8135
# Iteration 1, Epoch 5, Train Loss: 0.0107
# Iteration 1, Epoch 5, Validation Loss: 1.0273, Accuracy: 0.8006
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2463, 0.3959])
# Balanced pseudo-labeled samples: Male - 35676, Female - 35676
# Iteration 2, Epoch 1, Train Loss: 0.4095
# Iteration 2, Epoch 1, Validation Loss: 0.9486, Accuracy: 0.7858
# Iteration 2, Epoch 2, Train Loss: 0.3269
# Iteration 2, Epoch 2, Validation Loss: 0.7755, Accuracy: 0.8116
# Iteration 2, Epoch 3, Train Loss: 0.2912
# Iteration 2, Epoch 3, Validation Loss: 0.8263, Accuracy: 0.8019
# Iteration 2, Epoch 4, Train Loss: 0.2667
# Iteration 2, Epoch 4, Validation Loss: 0.8235, Accuracy: 0.8116
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2507, 0.3904])
# Balanced pseudo-labeled samples: Male - 36218, Female - 36218
# Iteration 3, Epoch 1, Train Loss: 0.2392
# Iteration 3, Epoch 1, Validation Loss: 0.9396, Accuracy: 0.8084
# Iteration 3, Epoch 2, Train Loss: 0.2104
# Iteration 3, Epoch 2, Validation Loss: 1.0301, Accuracy: 0.8045
# Iteration 3, Epoch 3, Train Loss: 0.1983
# Iteration 3, Epoch 3, Validation Loss: 1.0710, Accuracy: 0.8006
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2660, 0.3718])
# Balanced pseudo-labeled samples: Male - 37945, Female - 37945
# Iteration 4, Epoch 1, Train Loss: 0.2018
# Iteration 4, Epoch 1, Validation Loss: 1.2237, Accuracy: 0.8026
# Iteration 4, Epoch 2, Train Loss: 0.1824
# Iteration 4, Epoch 2, Validation Loss: 1.1502, Accuracy: 0.8116
# Iteration 4, Epoch 3, Train Loss: 0.1646
# Iteration 4, Epoch 3, Validation Loss: 1.2294, Accuracy: 0.8026
# Iteration 4, Epoch 4, Train Loss: 0.1547
# Iteration 4, Epoch 4, Validation Loss: 1.4408, Accuracy: 0.7968
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2814, 0.3540])
# Balanced pseudo-labeled samples: Male - 39644, Female - 39644
# Iteration 5, Epoch 1, Train Loss: 0.1782
# Iteration 5, Epoch 1, Validation Loss: 1.1129, Accuracy: 0.8071
# Iteration 5, Epoch 2, Train Loss: 0.1587
# Iteration 5, Epoch 2, Validation Loss: 1.4877, Accuracy: 0.7910
# Iteration 5, Epoch 3, Train Loss: 0.1430
# Iteration 5, Epoch 3, Validation Loss: 1.3930, Accuracy: 0.8000
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Experiment: Gender_Balanced_Unlabeled ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 43372
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.1694, 0.5085])
# Balanced pseudo-labeled samples: Male - 4799, Female - 4799
# Iteration 1, Epoch 1, Train Loss: 0.0358
# Iteration 1, Epoch 1, Validation Loss: 0.7009, Accuracy: 0.7929
# Iteration 1, Epoch 2, Train Loss: 0.0224
# Iteration 1, Epoch 2, Validation Loss: 0.8124, Accuracy: 0.7781
# Iteration 1, Epoch 3, Train Loss: 0.0181
# Iteration 1, Epoch 3, Validation Loss: 0.8392, Accuracy: 0.7897
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2087, 0.4469])
# Balanced pseudo-labeled samples: Male - 15601, Female - 15601
# Iteration 2, Epoch 1, Train Loss: 0.4941
# Iteration 2, Epoch 1, Validation Loss: 0.7944, Accuracy: 0.7994
# Iteration 2, Epoch 2, Train Loss: 0.4018
# Iteration 2, Epoch 2, Validation Loss: 0.7691, Accuracy: 0.7942
# Iteration 2, Epoch 3, Train Loss: 0.3587
# Iteration 2, Epoch 3, Validation Loss: 0.7624, Accuracy: 0.8077
# Iteration 2, Epoch 4, Train Loss: 0.3211
# Iteration 2, Epoch 4, Validation Loss: 0.7864, Accuracy: 0.8123
# Iteration 2, Epoch 5, Train Loss: 0.3006
# Iteration 2, Epoch 5, Validation Loss: 0.8813, Accuracy: 0.8052
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2108, 0.4438])
# Balanced pseudo-labeled samples: Male - 15753, Female - 15753
# Iteration 3, Epoch 1, Train Loss: 0.2946
# Iteration 3, Epoch 1, Validation Loss: 0.8250, Accuracy: 0.8052
# Iteration 3, Epoch 2, Train Loss: 0.2583
# Iteration 3, Epoch 2, Validation Loss: 1.0379, Accuracy: 0.8000
# Iteration 3, Epoch 3, Train Loss: 0.2299
# Iteration 3, Epoch 3, Validation Loss: 0.9377, Accuracy: 0.8168
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2269, 0.4213])
# Balanced pseudo-labeled samples: Male - 16723, Female - 16723
# Iteration 4, Epoch 1, Train Loss: 0.2373
# Iteration 4, Epoch 1, Validation Loss: 0.8673, Accuracy: 0.8142
# Iteration 4, Epoch 2, Train Loss: 0.2082
# Iteration 4, Epoch 2, Validation Loss: 1.0277, Accuracy: 0.8129
# Iteration 4, Epoch 3, Train Loss: 0.1924
# Iteration 4, Epoch 3, Validation Loss: 0.9798, Accuracy: 0.8135
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2473, 0.3946])
# Balanced pseudo-labeled samples: Male - 17916, Female - 17916
# Iteration 5, Epoch 1, Train Loss: 0.2202
# Iteration 5, Epoch 1, Validation Loss: 1.0372, Accuracy: 0.8006
# Iteration 5, Epoch 2, Train Loss: 0.1928
# Iteration 5, Epoch 2, Validation Loss: 0.9039, Accuracy: 0.8116
# Iteration 5, Epoch 3, Train Loss: 0.1711
# Iteration 5, Epoch 3, Validation Loss: 1.0762, Accuracy: 0.8135
# Iteration 5, Epoch 4, Train Loss: 0.1608
# Iteration 5, Epoch 4, Validation Loss: 1.1252, Accuracy: 0.8045
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Experiment: Severe_Male_Gender ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 44941
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.0570, 0.7568])
# Balanced pseudo-labeled samples: Male - 2133, Female - 2133
# Iteration 1, Epoch 1, Train Loss: 0.0421
# Iteration 1, Epoch 1, Validation Loss: 0.6502, Accuracy: 0.7916
# Iteration 1, Epoch 2, Train Loss: 0.0240
# Iteration 1, Epoch 2, Validation Loss: 0.7293, Accuracy: 0.7858
# Iteration 1, Epoch 3, Train Loss: 0.0265
# Iteration 1, Epoch 3, Validation Loss: 0.7075, Accuracy: 0.7923
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.1445, 0.5531])
# Balanced pseudo-labeled samples: Male - 11289, Female - 11289
# Iteration 2, Epoch 1, Train Loss: 0.4642
# Iteration 2, Epoch 1, Validation Loss: 0.9233, Accuracy: 0.7852
# Iteration 2, Epoch 2, Train Loss: 0.3656
# Iteration 2, Epoch 2, Validation Loss: 0.9162, Accuracy: 0.7806
# Iteration 2, Epoch 3, Train Loss: 0.3111
# Iteration 2, Epoch 3, Validation Loss: 1.0562, Accuracy: 0.7897
# Iteration 2, Epoch 4, Train Loss: 0.2794
# Iteration 2, Epoch 4, Validation Loss: 0.9744, Accuracy: 0.7961
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.1963, 0.4653])
# Balanced pseudo-labeled samples: Male - 15296, Female - 15296
# Iteration 3, Epoch 1, Train Loss: 0.3568
# Iteration 3, Epoch 1, Validation Loss: 0.9846, Accuracy: 0.7871
# Iteration 3, Epoch 2, Train Loss: 0.3203
# Iteration 3, Epoch 2, Validation Loss: 1.0023, Accuracy: 0.7794
# Iteration 3, Epoch 3, Train Loss: 0.2727
# Iteration 3, Epoch 3, Validation Loss: 1.2736, Accuracy: 0.7697
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2329, 0.4132])
# Balanced pseudo-labeled samples: Male - 17695, Female - 17695
# Iteration 4, Epoch 1, Train Loss: 0.3031
# Iteration 4, Epoch 1, Validation Loss: 1.2790, Accuracy: 0.7600
# Iteration 4, Epoch 2, Train Loss: 0.2720
# Iteration 4, Epoch 2, Validation Loss: 1.3183, Accuracy: 0.7665
# Iteration 4, Epoch 3, Train Loss: 0.2373
# Iteration 4, Epoch 3, Validation Loss: 1.4820, Accuracy: 0.7684
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2402, 0.4036])
# Balanced pseudo-labeled samples: Male - 18142, Female - 18142
# Iteration 5, Epoch 1, Train Loss: 0.2451
# Iteration 5, Epoch 1, Validation Loss: 1.4538, Accuracy: 0.7432
# Iteration 5, Epoch 2, Train Loss: 0.2177
# Iteration 5, Epoch 2, Validation Loss: 1.3398, Accuracy: 0.7658
# Iteration 5, Epoch 3, Train Loss: 0.2043
# Iteration 5, Epoch 3, Validation Loss: 1.5113, Accuracy: 0.7658
# Iteration 5, Epoch 4, Train Loss: 0.1738
# Iteration 5, Epoch 4, Validation Loss: 1.6626, Accuracy: 0.7671
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Experiment: Severe_Female_Gender ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 41803
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.3871, 0.2533])
# Balanced pseudo-labeled samples: Male - 5404, Female - 5404
# Iteration 1, Epoch 1, Train Loss: 0.0514
# Iteration 1, Epoch 1, Validation Loss: 0.8582, Accuracy: 0.7910
# Iteration 1, Epoch 2, Train Loss: 0.0252
# Iteration 1, Epoch 2, Validation Loss: 0.8478, Accuracy: 0.7948
# Iteration 1, Epoch 3, Train Loss: 0.0196
# Iteration 1, Epoch 3, Validation Loss: 0.8489, Accuracy: 0.8032
# Iteration 1, Epoch 4, Train Loss: 0.0147
# Iteration 1, Epoch 4, Validation Loss: 1.0052, Accuracy: 0.7910
# Early stopping triggered.
# Self-training completed for Severe_Female_Gender.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 41803
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.3760, 0.2624])
# Balanced pseudo-labeled samples: Male - 18094, Female - 18094
# Iteration 2, Epoch 1, Train Loss: 0.5115
# Iteration 2, Epoch 1, Validation Loss: 0.9224, Accuracy: 0.7935
# Iteration 2, Epoch 2, Train Loss: 0.4194
# Iteration 2, Epoch 2, Validation Loss: 0.9951, Accuracy: 0.7852
# Iteration 2, Epoch 3, Train Loss: 0.3736
# Iteration 2, Epoch 3, Validation Loss: 1.0638, Accuracy: 0.7974
# Early stopping triggered.
# Self-training completed for Severe_Female_Gender.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 41803
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.3650, 0.2717])
# Balanced pseudo-labeled samples: Male - 18596, Female - 18596
# Iteration 3, Epoch 1, Train Loss: 0.3263
# Iteration 3, Epoch 1, Validation Loss: 1.0730, Accuracy: 0.8019
# Iteration 3, Epoch 2, Train Loss: 0.2898
# Iteration 3, Epoch 2, Validation Loss: 0.9659, Accuracy: 0.7832
# Iteration 3, Epoch 3, Train Loss: 0.2619
# Iteration 3, Epoch 3, Validation Loss: 1.1390, Accuracy: 0.7974
# Iteration 3, Epoch 4, Train Loss: 0.2330
# Iteration 3, Epoch 4, Validation Loss: 1.2114, Accuracy: 0.7974
# Early stopping triggered.
# Self-training completed for Severe_Female_Gender.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 41803
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.3711, 0.2665])
# Balanced pseudo-labeled samples: Male - 18317, Female - 18317
# Iteration 4, Epoch 1, Train Loss: 0.2438
# Iteration 4, Epoch 1, Validation Loss: 1.2074, Accuracy: 0.7916
# Iteration 4, Epoch 2, Train Loss: 0.2046
# Iteration 4, Epoch 2, Validation Loss: 1.4130, Accuracy: 0.7865
# Iteration 4, Epoch 3, Train Loss: 0.1915
# Iteration 4, Epoch 3, Validation Loss: 1.3384, Accuracy: 0.7910
# Early stopping triggered.
# Self-training completed for Severe_Female_Gender.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 41803
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.3581, 0.2778])
# Balanced pseudo-labeled samples: Male - 18917, Female - 18917
# Iteration 5, Epoch 1, Train Loss: 0.2099
# Iteration 5, Epoch 1, Validation Loss: 1.3058, Accuracy: 0.7961
# Iteration 5, Epoch 2, Train Loss: 0.1877
# Iteration 5, Epoch 2, Validation Loss: 1.5201, Accuracy: 0.7871
# Iteration 5, Epoch 3, Train Loss: 0.1689
# Iteration 5, Epoch 3, Validation Loss: 1.3301, Accuracy: 0.7948
# Early stopping triggered.
# Self-training completed for Severe_Female_Gender.
# --- Starting Experiment: Severe_Black_Bias ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 12233
# FlexMatch thresholds of the two classes: tensor([0.1230, 0.5957])
# Balanced pseudo-labeled samples: Male - 784, Female - 784
# Iteration 1, Epoch 1, Train Loss: 0.0793
# Iteration 1, Epoch 1, Validation Loss: 0.6530, Accuracy: 0.7800
# Iteration 1, Epoch 2, Train Loss: 0.0328
# Iteration 1, Epoch 2, Validation Loss: 0.6760, Accuracy: 0.7813
# Iteration 1, Epoch 3, Train Loss: 0.0305
# Iteration 1, Epoch 3, Validation Loss: 0.6955, Accuracy: 0.7897
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2140, 0.4392])
# Balanced pseudo-labeled samples: Male - 4397, Female - 4397
# Iteration 2, Epoch 1, Train Loss: 0.6173
# Iteration 2, Epoch 1, Validation Loss: 0.8317, Accuracy: 0.7729
# Iteration 2, Epoch 2, Train Loss: 0.5096
# Iteration 2, Epoch 2, Validation Loss: 1.1740, Accuracy: 0.7400
# Iteration 2, Epoch 3, Train Loss: 0.4374
# Iteration 2, Epoch 3, Validation Loss: 1.2016, Accuracy: 0.7252
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.3188, 0.3145])
# Balanced pseudo-labeled samples: Male - 6085, Female - 6085
# Iteration 3, Epoch 1, Train Loss: 0.4955
# Iteration 3, Epoch 1, Validation Loss: 1.0482, Accuracy: 0.7484
# Iteration 3, Epoch 2, Train Loss: 0.4311
# Iteration 3, Epoch 2, Validation Loss: 1.1277, Accuracy: 0.7394
# Iteration 3, Epoch 3, Train Loss: 0.3915
# Iteration 3, Epoch 3, Validation Loss: 1.2632, Accuracy: 0.7445
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.3188, 0.3146])
# Balanced pseudo-labeled samples: Male - 6086, Female - 6086
# Iteration 4, Epoch 1, Train Loss: 0.3701
# Iteration 4, Epoch 1, Validation Loss: 1.5362, Accuracy: 0.7077
# Iteration 4, Epoch 2, Train Loss: 0.3397
# Iteration 4, Epoch 2, Validation Loss: 1.7406, Accuracy: 0.6961
# Iteration 4, Epoch 3, Train Loss: 0.2933
# Iteration 4, Epoch 3, Validation Loss: 1.3714, Accuracy: 0.7348
# Iteration 4, Epoch 4, Train Loss: 0.2739
# Iteration 4, Epoch 4, Validation Loss: 1.6855, Accuracy: 0.7123
# Iteration 4, Epoch 5, Train Loss: 0.2462
# Iteration 4, Epoch 5, Validation Loss: 1.6471, Accuracy: 0.7413
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.3250, 0.3084])
# Balanced pseudo-labeled samples: Male - 5996, Female - 5996
# Iteration 5, Epoch 1, Train Loss: 0.2657
# Iteration 5, Epoch 1, Validation Loss: 1.5525, Accuracy: 0.7129
# Iteration 5, Epoch 2, Train Loss: 0.2151
# Iteration 5, Epoch 2, Validation Loss: 1.7417, Accuracy: 0.7168
# Iteration 5, Epoch 3, Train Loss: 0.2157
# Iteration 5, Epoch 3, Validation Loss: 1.2992, Accuracy: 0.7594
# Iteration 5, Epoch 4, Train Loss: 0.1951
# Iteration 5, Epoch 4, Validation Loss: 1.8899, Accuracy: 0.7194
# Iteration 5, Epoch 5, Train Loss: 0.1651
# Iteration 5, Epoch 5, Validation Loss: 1.7822, Accuracy: 0.7342
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Experiment: Severe_East_Asian_Bias ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 12287
# Processed 0 images
# Processed 0 images
# Processed 0 images
# Processed 0 images
# FlexMatch thresholds of the two classes: tensor([0.2139, 0.4393])
# Balanced pseudo-labeled samples: Male - 1328, Female - 1328
# Iteration 1, Epoch 1, Train Loss: 0.0518
# Iteration 1, Epoch 1, Validation Loss: 0.6396, Accuracy: 0.7923
# Iteration 1, Epoch 2, Train Loss: 0.0203
# Iteration 1, Epoch 2, Validation Loss: 0.6985, Accuracy: 0.7942
# Iteration 1, Epoch 3, Train Loss: 0.0157
# Iteration 1, Epoch 3, Validation Loss: 0.7460, Accuracy: 0.7910
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 12287
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2430, 0.4001])
# Balanced pseudo-labeled samples: Male - 5005, Female - 5005
# Iteration 2, Epoch 1, Train Loss: 0.5124
# Iteration 2, Epoch 1, Validation Loss: 0.7988, Accuracy: 0.7929
# Iteration 2, Epoch 2, Train Loss: 0.4395
# Iteration 2, Epoch 2, Validation Loss: 0.7724, Accuracy: 0.8013
# Iteration 2, Epoch 3, Train Loss: 0.3740
# Iteration 2, Epoch 3, Validation Loss: 1.1368, Accuracy: 0.7690
# Iteration 2, Epoch 4, Train Loss: 0.3334
# Iteration 2, Epoch 4, Validation Loss: 0.9656, Accuracy: 0.8013
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 12287
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2336, 0.4123])
# Balanced pseudo-labeled samples: Male - 4850, Female - 4850
# Iteration 3, Epoch 1, Train Loss: 0.3470
# Iteration 3, Epoch 1, Validation Loss: 1.1153, Accuracy: 0.7794
# Iteration 3, Epoch 2, Train Loss: 0.2986
# Iteration 3, Epoch 2, Validation Loss: 1.0746, Accuracy: 0.7974
# Iteration 3, Epoch 3, Train Loss: 0.2658
# Iteration 3, Epoch 3, Validation Loss: 1.0692, Accuracy: 0.8019
# Iteration 3, Epoch 4, Train Loss: 0.2406
# Iteration 3, Epoch 4, Validation Loss: 1.2574, Accuracy: 0.7884
# Iteration 3, Epoch 5, Train Loss: 0.2070
# Iteration 3, Epoch 5, Validation Loss: 1.1082, Accuracy: 0.8065
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 12287
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2815, 0.3539])
# Balanced pseudo-labeled samples: Male - 5617, Female - 5617
# Iteration 4, Epoch 1, Train Loss: 0.3341
# Iteration 4, Epoch 1, Validation Loss: 0.8173, Accuracy: 0.8084
# Iteration 4, Epoch 2, Train Loss: 0.2662
# Iteration 4, Epoch 2, Validation Loss: 1.1470, Accuracy: 0.7658
# Iteration 4, Epoch 3, Train Loss: 0.2409
# Iteration 4, Epoch 3, Validation Loss: 1.0256, Accuracy: 0.8077
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 12287
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2905, 0.3440])
# Balanced pseudo-labeled samples: Male - 5754, Female - 5754
# Iteration 5, Epoch 1, Train Loss: 0.2534
# Iteration 5, Epoch 1, Validation Loss: 1.0373, Accuracy: 0.8058
# Iteration 5, Epoch 2, Train Loss: 0.2060
# Iteration 5, Epoch 2, Validation Loss: 1.0036, Accuracy: 0.8019
# Iteration 5, Epoch 3, Train Loss: 0.1901
# Iteration 5, Epoch 3, Validation Loss: 1.1031, Accuracy: 0.8032
# Iteration 5, Epoch 4, Train Loss: 0.1521
# Iteration 5, Epoch 4, Validation Loss: 1.2853, Accuracy: 0.8039
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Bias.
# --- Starting Experiment: Severe_East_Asian_Female_Bias ---
# --- Starting Iteration 1/5 ---
# Unlabeled dataset size: 6141
# Processed 0 images
# Processed 0 images
# FlexMatch thresholds of the two classes: tensor([0.7419, 0.0622])
# Balanced pseudo-labeled samples: Male - 183, Female - 183
# Iteration 1, Epoch 1, Train Loss: 0.0776
# Iteration 1, Epoch 1, Validation Loss: 0.5944, Accuracy: 0.7832
# Iteration 1, Epoch 2, Train Loss: 0.0441
# Iteration 1, Epoch 2, Validation Loss: 0.8183, Accuracy: 0.7665
# Iteration 1, Epoch 3, Train Loss: 0.0368
# Iteration 1, Epoch 3, Validation Loss: 1.1484, Accuracy: 0.7368
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 2/5 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.2768, 0.3592])
# Balanced pseudo-labeled samples: Male - 2545, Female - 2545
# Iteration 2, Epoch 1, Train Loss: 0.4943
# Iteration 2, Epoch 1, Validation Loss: 2.1868, Accuracy: 0.6897
# Iteration 2, Epoch 2, Train Loss: 0.3906
# Iteration 2, Epoch 2, Validation Loss: 1.9128, Accuracy: 0.7155
# Iteration 2, Epoch 3, Train Loss: 0.3336
# Iteration 2, Epoch 3, Validation Loss: 1.9308, Accuracy: 0.7097
# Iteration 2, Epoch 4, Train Loss: 0.2955
# Iteration 2, Epoch 4, Validation Loss: 1.8967, Accuracy: 0.7239
# Iteration 2, Epoch 5, Train Loss: 0.2799
# Iteration 2, Epoch 5, Validation Loss: 1.7779, Accuracy: 0.7355
# Iteration 2, Epoch 6, Train Loss: 0.1946
# Iteration 2, Epoch 6, Validation Loss: 2.9611, Accuracy: 0.6942
# Iteration 2, Epoch 7, Train Loss: 0.2013
# Iteration 2, Epoch 7, Validation Loss: 3.1982, Accuracy: 0.7000
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 3/5 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.2576, 0.3818])
# Balanced pseudo-labeled samples: Male - 2620, Female - 2620
# Iteration 3, Epoch 1, Train Loss: 0.3410
# Iteration 3, Epoch 1, Validation Loss: 2.6908, Accuracy: 0.6987
# Iteration 3, Epoch 2, Train Loss: 0.2815
# Iteration 3, Epoch 2, Validation Loss: 2.7106, Accuracy: 0.6974
# Iteration 3, Epoch 3, Train Loss: 0.2493
# Iteration 3, Epoch 3, Validation Loss: 2.3376, Accuracy: 0.7187
# Iteration 3, Epoch 4, Train Loss: 0.1955
# Iteration 3, Epoch 4, Validation Loss: 2.8969, Accuracy: 0.7226
# Iteration 3, Epoch 5, Train Loss: 0.1922
# Iteration 3, Epoch 5, Validation Loss: 3.3936, Accuracy: 0.6968
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 4/5 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.2599, 0.3791])
# Balanced pseudo-labeled samples: Male - 2638, Female - 2638
# Iteration 4, Epoch 1, Train Loss: 0.2007
# Iteration 4, Epoch 1, Validation Loss: 2.6023, Accuracy: 0.7097
# Iteration 4, Epoch 2, Train Loss: 0.2022
# Iteration 4, Epoch 2, Validation Loss: 2.3586, Accuracy: 0.7219
# Iteration 4, Epoch 3, Train Loss: 0.1585
# Iteration 4, Epoch 3, Validation Loss: 2.9953, Accuracy: 0.6955
# Iteration 4, Epoch 4, Train Loss: 0.1345
# Iteration 4, Epoch 4, Validation Loss: 2.7410, Accuracy: 0.7226
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 5/5 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.2660, 0.3717])
# Balanced pseudo-labeled samples: Male - 2687, Female - 2687
# Iteration 5, Epoch 1, Train Loss: 0.1696
# Iteration 5, Epoch 1, Validation Loss: 2.8182, Accuracy: 0.7123
# Iteration 5, Epoch 2, Train Loss: 0.1686
# Iteration 5, Epoch 2, Validation Loss: 3.4912, Accuracy: 0.6839
# Iteration 5, Epoch 3, Train Loss: 0.1423
# Iteration 5, Epoch 3, Validation Loss: 3.2774, Accuracy: 0.6768
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# All experiments completed.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
import shutil
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from PIL import Image
import requests

# Define the non-linear mapping function (e.g., convex function)
def non_linear_mapping(x):
    return x / (2 - x)  # Convex function for threshold adjustment

# Initialize class-specific thresholds and counts
num_classes = 2  # Male and Female
base_threshold = 0.95  # Base confidence threshold for pseudo-labeling
iterations = 3  # Number of self-training iterations
num_epochs = 10  # Epochs per iteration
batch_size = 16
patience = 2  # Early stopping patience

# Define device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define paths
bias_folder = "./bias_training_data"
validation_folder = os.path.join("../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset/East_Asian_Validation")

# Define the training folders and pseudo-labeling thresholds
# Define the training folders and pseudo-labeling thresholds
training_folders = [
    "Unlabeled",
    "Gender_Balanced_Unlabeled",
    "Severe_Male_Gender",
    "Severe_Black_Bias",
    "Severe_East_Asian_Female_Bias"
]

# Define transformations
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = datasets.ImageFolder(validation_folder, transform=transforms_val)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Define model
def load_pretrained_model():
    model = models.resnet18(pretrained=True)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, 2)  # Output layer for binary classification
    pretrained_weights_path = 'classification_model.pth'
    model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
    model = model.to(device)
    return model

# Loss and optimizer
criterion = nn.CrossEntropyLoss()

# Function to pseudo-balance the dataset
def pseudo_balancing(male_path, female_path):
    male_samples = os.listdir(male_path) if os.path.exists(male_path) else []
    female_samples = os.listdir(female_path) if os.path.exists(female_path) else []
    num_male = len(male_samples)
    num_female = len(female_samples)
    target_size = min(num_male, num_female)
    if num_male > target_size:
        excess_male_samples = np.random.choice(male_samples, num_male - target_size, replace=False)
        for sample in excess_male_samples:
            os.remove(os.path.join(male_path, sample))
    elif num_female > target_size:
        excess_female_samples = np.random.choice(female_samples, num_female - target_size, replace=False)
        for sample in excess_female_samples:
            os.remove(os.path.join(female_path, sample))
    num_male = len(os.listdir(male_path))
    num_female = len(os.listdir(female_path))
    print(f"Balanced pseudo-labeled samples: Male - {num_male}, Female - {num_female}")
    return

# Loop over all experiments
for training_folder in training_folders:
        print(f"--- Starting Experiment: {training_folder} ---")
        # Define paths for this experiment
        unlabeled_folder = os.path.join(bias_folder, training_folder)
        train_folder = os.path.join(bias_folder, f"Training_pseudo_Balanced_{training_folder}_FlexMatch")
        aaf_training_female_path = os.path.join(train_folder, "female")
        aaf_training_male_path = os.path.join(train_folder, "male")
        model_save_folder = os.path.join(bias_folder, f"bias_{training_folder}_FlexMatch")
        os.makedirs(model_save_folder, exist_ok=True)

        # Create directories if they don't exist
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(aaf_training_female_path, exist_ok=True)
        os.makedirs(aaf_training_male_path, exist_ok=True)

        # Load pre-trained model
        model = load_pretrained_model()
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

        # Initialize class thresholds and counts
        class_thresholds = torch.ones(num_classes) * base_threshold

        for iteration in range(iterations):
            print(f"--- Starting Iteration {iteration + 1}/{iterations} ---")
            print("Unlabeled dataset size:", len(os.listdir(unlabeled_folder)))

            # 1. Clean the training folder
            shutil.rmtree(train_folder, ignore_errors=True)
            os.makedirs(train_folder, exist_ok=True)
            os.makedirs(aaf_training_female_path, exist_ok=True)
            os.makedirs(aaf_training_male_path, exist_ok=True)

            # 2. Pseudo-labeling using FlexMatch
            model.eval()
            class_counts = torch.zeros(num_classes)
            new_samples = 0

            for unlabeled_data in os.listdir(unlabeled_folder):
                img_path = os.path.join(unlabeled_folder, unlabeled_data)
                img = Image.open(img_path).convert('RGB')
                input = transforms_val(img).unsqueeze(0).to(device)

                with torch.no_grad():
                    output = model(input)
                    probs = F.softmax(output, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                    # Apply FlexMatch thresholds
                    for c in range(num_classes):
                        mask = (preds == c) & (max_probs > class_thresholds[c])
                        if mask.any():
                            class_counts[c] += mask.sum().item()
                            if c == 0:
                                shutil.copy(img_path, os.path.join(aaf_training_female_path, unlabeled_data))
                            elif c == 1:
                                shutil.copy(img_path, os.path.join(aaf_training_male_path, unlabeled_data))
                            new_samples += 1

                if new_samples % 10000 == 0:
                    print(f"Processed {new_samples} images")

            # 3. Update class thresholds based on learning status
            normalized_counts = class_counts / class_counts.sum()
            for c in range(num_classes):
                class_thresholds[c] = non_linear_mapping(normalized_counts[c]) * base_threshold

            print("FlexMatch thresholds of the two classes:", class_thresholds)

            # Reload training dataset with new pseudo-labeled samples
            train_dataset = datasets.ImageFolder(train_folder, transform=transforms_train)
            train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

            # 5. Training with early stopping
            best_val_loss = float('inf')
            wait = 0

            for epoch in range(num_epochs):
                model.train()
                running_loss = 0.0

                for inputs, labels in train_dataloader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    optimizer.zero_grad()
                    outputs = model(inputs)
                    probs = F.softmax(outputs, dim=1)
                    max_probs, preds = torch.max(probs, dim=1)

                    # Supervised loss
                    supervised_loss = criterion(outputs, labels)

                    # Unsupervised loss (FlexMatch)
                    unsupervised_loss = 0.0
                    for c in range(num_classes):
                        mask = (preds == c) & (max_probs > class_thresholds[c])
                        if mask.any():
                            unsupervised_loss += F.cross_entropy(outputs[mask], preds[mask])

                    # Total loss
                    loss = supervised_loss + unsupervised_loss
                    loss.backward()
                    optimizer.step()

                    running_loss += loss.item() * inputs.size(0)

                epoch_loss = running_loss / len(train_dataset)
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}")

                # Validation
                model.eval()
                val_loss = 0.0
                correct = 0
                total = 0

                with torch.no_grad():
                    for inputs, labels in val_dataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        val_loss += criterion(outputs, labels).item() * inputs.size(0)
                        _, preds = torch.max(outputs, 1)
                        correct += (preds == labels).sum().item()
                        total += labels.size(0)

                val_loss /= len(val_dataset)
                val_accuracy = correct / total
                print(f"Iteration {iteration + 1}, Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    wait = 0
                    torch.save(model.state_dict(), os.path.join(model_save_folder, f"FlexMatch_{iteration + 1}_unbalanced_best.pth"))
                else:
                    wait += 1
                    if wait >= patience:
                        print("Early stopping triggered.")
                        break

            # Save the final model
            torch.save(model.state_dict(), os.path.join(model_save_folder, f'FlexMatch_{iteration + 1}_unbalanced_final.pth'))
            print(f"Self-training completed for {training_folder}.")

print("All experiments completed.")
# Out:
# --- Starting Experiment: Unlabeled ---
# C:\Users\haohu\AppData\Local\Temp\ipykernel_16192\3913148396.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained_weights_path, map_location=device))
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 86744
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# Processed 10000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 20000 images
# Processed 30000 images
# Processed 30000 images
# Processed 30000 images
# FlexMatch thresholds of the two classes: tensor([0.1686, 0.5100])
# Iteration 1, Epoch 1, Train Loss: 0.0622
# Iteration 1, Epoch 1, Validation Loss: 0.8102, Accuracy: 0.8194
# Iteration 1, Epoch 2, Train Loss: 0.0472
# Iteration 1, Epoch 2, Validation Loss: 0.8955, Accuracy: 0.8026
# Iteration 1, Epoch 3, Train Loss: 0.0435
# Iteration 1, Epoch 3, Validation Loss: 0.8809, Accuracy: 0.8071
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2618, 0.3767])
# Iteration 2, Epoch 1, Train Loss: 0.4107
# Iteration 2, Epoch 1, Validation Loss: 0.7390, Accuracy: 0.8084
# Iteration 2, Epoch 2, Train Loss: 0.3461
# Iteration 2, Epoch 2, Validation Loss: 0.7189, Accuracy: 0.8135
# Iteration 2, Epoch 3, Train Loss: 0.3105
# Iteration 2, Epoch 3, Validation Loss: 0.8128, Accuracy: 0.8019
# Iteration 2, Epoch 4, Train Loss: 0.2824
# Iteration 2, Epoch 4, Validation Loss: 0.7863, Accuracy: 0.8206
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 86744
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# Processed 50000 images
# Processed 60000 images
# Processed 70000 images
# Processed 80000 images
# FlexMatch thresholds of the two classes: tensor([0.2666, 0.3711])
# Iteration 3, Epoch 1, Train Loss: 0.2508
# Iteration 3, Epoch 1, Validation Loss: 1.0047, Accuracy: 0.8181
# Iteration 3, Epoch 2, Train Loss: 0.2187
# Iteration 3, Epoch 2, Validation Loss: 0.9912, Accuracy: 0.8181
# Iteration 3, Epoch 3, Train Loss: 0.2033
# Iteration 3, Epoch 3, Validation Loss: 1.1174, Accuracy: 0.8123
# Iteration 3, Epoch 4, Train Loss: 0.1874
# Iteration 3, Epoch 4, Validation Loss: 1.0944, Accuracy: 0.8174
# Early stopping triggered.
# Self-training completed for Unlabeled.
# --- Starting Experiment: Gender_Balanced_Unlabeled ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 43372
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.1694, 0.5085])
# Iteration 1, Epoch 1, Train Loss: 0.0578
# Iteration 1, Epoch 1, Validation Loss: 0.9040, Accuracy: 0.7877
# Iteration 1, Epoch 2, Train Loss: 0.0584
# Iteration 1, Epoch 2, Validation Loss: 1.0704, Accuracy: 0.7658
# Iteration 1, Epoch 3, Train Loss: 0.0365
# Iteration 1, Epoch 3, Validation Loss: 1.2987, Accuracy: 0.7948
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.1996, 0.4603])
# Iteration 2, Epoch 1, Train Loss: 0.4003
# Iteration 2, Epoch 1, Validation Loss: 0.9315, Accuracy: 0.7961
# Iteration 2, Epoch 2, Train Loss: 0.3235
# Iteration 2, Epoch 2, Validation Loss: 1.1177, Accuracy: 0.7910
# Iteration 2, Epoch 3, Train Loss: 0.2994
# Iteration 2, Epoch 3, Validation Loss: 1.2065, Accuracy: 0.7832
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 43372
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.1867, 0.4802])
# Iteration 3, Epoch 1, Train Loss: 0.2647
# Iteration 3, Epoch 1, Validation Loss: 1.2687, Accuracy: 0.7916
# Iteration 3, Epoch 2, Train Loss: 0.2410
# Iteration 3, Epoch 2, Validation Loss: 1.3586, Accuracy: 0.7794
# Iteration 3, Epoch 3, Train Loss: 0.2237
# Iteration 3, Epoch 3, Validation Loss: 1.6255, Accuracy: 0.7819
# Early stopping triggered.
# Self-training completed for Gender_Balanced_Unlabeled.
# --- Starting Experiment: Severe_Male_Gender ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 44941
# Processed 0 images
# Processed 10000 images
# Processed 10000 images
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.0570, 0.7568])
# Iteration 1, Epoch 1, Train Loss: 0.2623
# Iteration 1, Epoch 1, Validation Loss: 1.2173, Accuracy: 0.7503
# Iteration 1, Epoch 2, Train Loss: 0.3121
# Iteration 1, Epoch 2, Validation Loss: 1.1201, Accuracy: 0.6994
# Iteration 1, Epoch 3, Train Loss: 0.3446
# Iteration 1, Epoch 3, Validation Loss: 0.8976, Accuracy: 0.7155
# Iteration 1, Epoch 4, Train Loss: 0.3531
# Iteration 1, Epoch 4, Validation Loss: 1.0572, Accuracy: 0.7355
# Iteration 1, Epoch 5, Train Loss: 0.2886
# Iteration 1, Epoch 5, Validation Loss: 1.0711, Accuracy: 0.6839
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2848, 0.3502])
# Iteration 2, Epoch 1, Train Loss: 0.3965
# Iteration 2, Epoch 1, Validation Loss: 1.3832, Accuracy: 0.6794
# Iteration 2, Epoch 2, Train Loss: 0.3265
# Iteration 2, Epoch 2, Validation Loss: 1.5202, Accuracy: 0.6800
# Iteration 2, Epoch 3, Train Loss: 0.2916
# Iteration 2, Epoch 3, Validation Loss: 1.6372, Accuracy: 0.6697
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 44941
# Processed 10000 images
# Processed 20000 images
# Processed 30000 images
# Processed 40000 images
# FlexMatch thresholds of the two classes: tensor([0.2970, 0.3370])
# Iteration 3, Epoch 1, Train Loss: 0.2917
# Iteration 3, Epoch 1, Validation Loss: 2.0042, Accuracy: 0.6581
# Iteration 3, Epoch 2, Train Loss: 0.2623
# Iteration 3, Epoch 2, Validation Loss: 1.8378, Accuracy: 0.6806
# Iteration 3, Epoch 3, Train Loss: 0.2304
# Iteration 3, Epoch 3, Validation Loss: 1.9625, Accuracy: 0.6723
# Iteration 3, Epoch 4, Train Loss: 0.2209
# Iteration 3, Epoch 4, Validation Loss: 2.1676, Accuracy: 0.6735
# Early stopping triggered.
# Self-training completed for Severe_Male_Gender.
# --- Starting Experiment: Severe_Black_Bias ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 12233
# FlexMatch thresholds of the two classes: tensor([0.1230, 0.5957])
# Iteration 1, Epoch 1, Train Loss: 0.1052
# Iteration 1, Epoch 1, Validation Loss: 0.6925, Accuracy: 0.7839
# Iteration 1, Epoch 2, Train Loss: 0.0907
# Iteration 1, Epoch 2, Validation Loss: 0.9142, Accuracy: 0.7742
# Iteration 1, Epoch 3, Train Loss: 0.0862
# Iteration 1, Epoch 3, Validation Loss: 1.0859, Accuracy: 0.7310
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.2879, 0.3468])
# Iteration 2, Epoch 1, Train Loss: 0.6521
# Iteration 2, Epoch 1, Validation Loss: 1.7256, Accuracy: 0.6619
# Iteration 2, Epoch 2, Train Loss: 0.5033
# Iteration 2, Epoch 2, Validation Loss: 1.1678, Accuracy: 0.7381
# Iteration 2, Epoch 3, Train Loss: 0.4618
# Iteration 2, Epoch 3, Validation Loss: 1.1198, Accuracy: 0.7426
# Iteration 2, Epoch 4, Train Loss: 0.4078
# Iteration 2, Epoch 4, Validation Loss: 1.1668, Accuracy: 0.7342
# Iteration 2, Epoch 5, Train Loss: 0.3823
# Iteration 2, Epoch 5, Validation Loss: 1.4603, Accuracy: 0.7019
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 12233
# Processed 10000 images
# FlexMatch thresholds of the two classes: tensor([0.3206, 0.3128])
# Iteration 3, Epoch 1, Train Loss: 0.4070
# Iteration 3, Epoch 1, Validation Loss: 1.5239, Accuracy: 0.6981
# Iteration 3, Epoch 2, Train Loss: 0.3513
# Iteration 3, Epoch 2, Validation Loss: 1.2222, Accuracy: 0.7587
# Iteration 3, Epoch 3, Train Loss: 0.3364
# Iteration 3, Epoch 3, Validation Loss: 1.7934, Accuracy: 0.6903
# Iteration 3, Epoch 4, Train Loss: 0.3014
# Iteration 3, Epoch 4, Validation Loss: 1.7073, Accuracy: 0.7045
# Early stopping triggered.
# Self-training completed for Severe_Black_Bias.
# --- Starting Experiment: Severe_East_Asian_Female_Bias ---
# --- Starting Iteration 1/3 ---
# Unlabeled dataset size: 6141
# Processed 0 images
# Processed 0 images
# FlexMatch thresholds of the two classes: tensor([0.7419, 0.0622])
# Iteration 1, Epoch 1, Train Loss: 0.2794
# Iteration 1, Epoch 1, Validation Loss: 1.5972, Accuracy: 0.7200
# Iteration 1, Epoch 2, Train Loss: 0.3545
# Iteration 1, Epoch 2, Validation Loss: 0.9983, Accuracy: 0.7458
# Iteration 1, Epoch 3, Train Loss: 0.2272
# Iteration 1, Epoch 3, Validation Loss: 0.9358, Accuracy: 0.7503
# Iteration 1, Epoch 4, Train Loss: 0.1853
# Iteration 1, Epoch 4, Validation Loss: 1.1519, Accuracy: 0.7335
# Iteration 1, Epoch 5, Train Loss: 0.2107
# Iteration 1, Epoch 5, Validation Loss: 0.9877, Accuracy: 0.7413
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 2/3 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.3579, 0.2779])
# Iteration 2, Epoch 1, Train Loss: 0.4592
# Iteration 2, Epoch 1, Validation Loss: 1.3489, Accuracy: 0.7426
# Iteration 2, Epoch 2, Train Loss: 0.3752
# Iteration 2, Epoch 2, Validation Loss: 1.7025, Accuracy: 0.7252
# Iteration 2, Epoch 3, Train Loss: 0.2999
# Iteration 2, Epoch 3, Validation Loss: 2.1306, Accuracy: 0.7135
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# --- Starting Iteration 3/3 ---
# Unlabeled dataset size: 6141
# FlexMatch thresholds of the two classes: tensor([0.3224, 0.3110])
# Iteration 3, Epoch 1, Train Loss: 0.3848
# Iteration 3, Epoch 1, Validation Loss: 1.8016, Accuracy: 0.7155
# Iteration 3, Epoch 2, Train Loss: 0.3126
# Iteration 3, Epoch 2, Validation Loss: 2.1719, Accuracy: 0.7071
# Iteration 3, Epoch 3, Train Loss: 0.2996
# Iteration 3, Epoch 3, Validation Loss: 2.3063, Accuracy: 0.7194
# Early stopping triggered.
# Self-training completed for Severe_East_Asian_Female_Bias.
# All experiments completed.

# %%
import os
import random
import shutil
from torchvision.datasets import ImageFolder
from torch.utils.data import Subset
from tqdm import tqdm

# Define the validation folder
validation_folder = "../AAF-Dataset-Pseudo-Labeling-UDA/aaf_dataset/Validation"

# Define the paths to the female and male folders within the validation folder
validation_female_folder = os.path.join(validation_folder, "female")
validation_male_folder = os.path.join(validation_folder, "male")

# Count the number of samples in each folder
num_validation_female_samples = len(os.listdir(validation_female_folder))
num_validation_male_samples = len(os.listdir(validation_male_folder))

# Print the counts
print("Number of samples in Validation - Female:", num_validation_female_samples)
print("Number of samples in Validation - Male:", num_validation_male_samples)

# Balance the Validation set to have the same number of female/male classes
# Determine the minimum class count
min_validation_samples = min(num_validation_female_samples, num_validation_male_samples)
print("Balancing Validation Set...")
print(f"Minimum class count: {min_validation_samples}")

# Load the full validation dataset
validation_dataset = ImageFolder(validation_folder, transform=None)

# Separate indices for female and male classes
female_indices = [i for i, (_, label) in enumerate(validation_dataset) if label == 0]
male_indices = [i for i, (_, label) in enumerate(validation_dataset) if label == 1]

# Randomly select a subset of indices for each class
random.seed(42)  # For reproducibility
balanced_female_indices = random.sample(female_indices, min_validation_samples)
balanced_male_indices = random.sample(male_indices, min_validation_samples)

# Combine balanced indices and create a balanced dataset
balanced_indices = balanced_female_indices + balanced_male_indices
balanced_validation_dataset = Subset(validation_dataset, balanced_indices)

# Print the final balanced validation set counts
print(f"Balanced Validation Set - Female: {len(balanced_female_indices)}")
print(f"Balanced Validation Set - Male: {len(balanced_male_indices)}")
print(f"Total Balanced Validation Samples: {len(balanced_validation_dataset)}")

# Create a new folder for the balanced validation set
balanced_validation_folder = os.path.join(os.path.dirname(validation_folder), "Balanced_Validation")
# Paths for the balanced validation set
balanced_validation_female_folder = os.path.join(balanced_validation_folder, "female")
balanced_validation_male_folder = os.path.join(balanced_validation_folder, "male")

# Create directories for the balanced validation set
os.makedirs(balanced_validation_female_folder, exist_ok=True)
os.makedirs(balanced_validation_male_folder, exist_ok=True)

# Copy balanced female samples
print("Copying balanced female samples...")
for idx in tqdm(balanced_female_indices):
    source_path = validation_dataset.samples[idx][0]  # Get the file path from the dataset
    filename = os.path.basename(source_path)
    destination_path = os.path.join(balanced_validation_female_folder, filename)
    shutil.copy(source_path, destination_path)

# Copy balanced male samples
print("Copying balanced male samples...")
for idx in tqdm(balanced_male_indices):
    source_path = validation_dataset.samples[idx][0]  # Get the file path from the dataset
    filename = os.path.basename(source_path)
    destination_path = os.path.join(balanced_validation_male_folder, filename)
    shutil.copy(source_path, destination_path)

print("Balanced validation set copied successfully!")
# Out:
# Number of samples in Validation - Female: 3167
# Number of samples in Validation - Male: 2524
# Balancing Validation Set...
# Minimum class count: 2524
# Balanced Validation Set - Female: 2524
# Balanced Validation Set - Male: 2524
# Total Balanced Validation Samples: 5048
# Copying balanced female samples...
# 100%|██████████| 2524/2524 [00:03<00:00, 644.45it/s]
# Copying balanced male samples...
# 100%|██████████| 2524/2524 [00:04<00:00, 580.84it/s]
# Balanced validation set copied successfully!

# %% [markdown]
# ###  Obtain performance results from every experiment

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import pandas as pd

# Function to display images
def imshow(input, title):
    input = input.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    plt.imshow(input)
    plt.title(title)
    plt.show()

# Define transformations
transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define paths
aaf_dataset_path = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset"
test_folders = {
    "East_Asian_Validation": os.path.join(aaf_dataset_path, "East_Asian_Validation"),  # FairFace East Asian validation
    "Balanced_Validation": os.path.join(aaf_dataset_path, "Balanced_Validation"),  # FairFace Multi-Race test
    "AAF_Validation": "../AAF-Dataset-Pseudo-Labeling-UDA/aaf_dataset/Balanced_Validation"  # AAF test
}
# Define FixMatch folders
data_path = "bias_training_data"
fixmatch_folders = [
    "bias_Severe_East_Asian_Female_Bias_0.6",  # "Controlled_Bias_0.6_{1,2,3...5}_balanced_best.pth", "Controlled_Bias_0.6_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_East_Asian_Female_Bias_0.9",  # "Controlled_Bias_0.9_{1,2,3...5}_balanced_best.pth", "Controlled_Bias_0.9_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_Black_Bias_0.6",  # "Controlled_Bias_0.6_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.6_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_Black_Bias_0.9",  # "Controlled_Bias_0.9_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.9_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_Male_Gender_0.6",  # "Controlled_Bias_0.6_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.6_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_Male_Gender_0.9",  # "Controlled_Bias_0.9_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.9_{1,2,3}_unbalanced_best.pth"
    "bias_Gender_Balanced_Unlabeled_0.6",  # "Controlled_Bias_0.6_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.6_{1,2,3}_unbalanced_best.pth"
    "bias_Gender_Balanced_Unlabeled_0.9",  # "Controlled_Bias_0.9_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.9_{1,2,3}_unbalanced_best.pth"
    "bias_Unlabeled_0.6",  # "Controlled_Bias_0.6_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.6_{1,2,3}_unbalanced_best.pth"
    "bias_Unlabeled_0.9",  # "Controlled_Bias_0.9_{1,2,3...10}_balanced_best.pth", "Controlled_Bias_0.9_{1,2,3}_unbalanced_best.pth"
    "bias_Severe_East_Asian_Bias_0.6",  # "Controlled_Bias_0.6_{1,2,3...5}_balanced_best.pth"
    "bias_Severe_East_Asian_Bias_0.9",  # "Controlled_Bias_0.9_{1,2,3...5}_balanced_best.pth"
    "bias_Severe_Female_Gender_0.6",  # "Controlled_Bias_0.6_{1,2,3...10}_balanced_best.pth"
    "bias_Severe_Female_Gender_0.9"  # "Controlled_Bias_0.9_{1,2,3...10}_balanced_best.pth"
]
fixmatch_folders = [os.path.join(data_path, folder) for folder in fixmatch_folders]

# Initialize results storage
results = []

# Load model
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 2)  # Binary classification
criterion = nn.CrossEntropyLoss()

# Loop over test folders
for test_name, test_folder in test_folders.items():
    print(f"--- Testing on {test_name} ---")

    # Load test dataset
    test_dataset = ImageFolder(test_folder, transform=transforms_val)
    test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True, num_workers=4)
    class_names = test_dataset.classes
    print('Class names:', class_names)

    # Loop over FixMatch folders
    for fixmatch_folder in fixmatch_folders:
        # Determine the number of models based on the folder name
        if "Severe_East_Asian_Female_Bias_0.6" in fixmatch_folder or "Severe_East_Asian_Female_Bias_0.9" in fixmatch_folder:
            num_balanced = 5  # 1-5 balanced models
            num_unbalanced = 3  # 1-3 unbalanced models
        elif "Severe_East_Asian_Bias_0.6" in fixmatch_folder or "Severe_East_Asian_Bias_0.9" in fixmatch_folder:
            num_balanced = 5  # 1-5 balanced models
            num_unbalanced = 0  # No unbalanced models
        elif "Severe_Female_Gender_0.6" in fixmatch_folder or "Severe_Female_Gender_0.9" in fixmatch_folder:
            num_balanced = 10  # 1-10 balanced models
            num_unbalanced = 0  # No unbalanced models
        else:
            num_balanced = 10  # 1-10 balanced models
            num_unbalanced = 3  # 1-3 unbalanced models
        # Generate model paths
        if "0.6" in fixmatch_folder:
            model_paths_balanced = [os.path.join(fixmatch_folder, f"Controlled_Bias_0.6_{j}_balanced_best.pth") for j in range(1, num_balanced + 1)]
            model_paths_unbalanced = [os.path.join(fixmatch_folder, f"Controlled_Bias_0.6_{j}_unbalanced_best.pth") for j in range(1, num_unbalanced + 1)]
        else:
            model_paths_balanced = [os.path.join(fixmatch_folder, f"Controlled_Bias_0.9_{j}_balanced_best.pth") for j in range(1, num_balanced + 1)]
            model_paths_unbalanced = [os.path.join(fixmatch_folder, f"Controlled_Bias_0.9_{j}_unbalanced_best.pth") for j in range(1, num_unbalanced+ 1)]
        # Combine all model paths
        all_model_paths = model_paths_balanced + model_paths_unbalanced

        # Loop over models in the current folder
        for model_path in all_model_paths:
            print(f"--- Testing model: {model_path} ---")

            # Load model state
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            state_dict = torch.load(model_path, map_location=device)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()

            # Initialize metrics
            male_corrects = 0
            male_total = 0
            female_corrects = 0
            female_total = 0
            running_loss = 0.0
            running_corrects = 0

            start_time = time.time()

            # Test loop
            with torch.no_grad():
                for i, (inputs, labels) in enumerate(test_dataloader):
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    male_mask = labels == class_names.index('male')
                    female_mask = labels == class_names.index('female')

                    male_corrects += torch.sum(preds[male_mask] == labels[male_mask])
                    male_total += torch.sum(male_mask)

                    female_corrects += torch.sum(preds[female_mask] == labels[female_mask])
                    female_total += torch.sum(female_mask)

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                    # if i == 0:
                        # print('[Prediction Result Examples]')
                        # pred_labels = [class_names[x] for x in preds]
                        # images = torchvision.utils.make_grid(inputs[:8])
                        # imshow(images.cpu(), title=pred_labels)

            # Calculate metrics
            male_acc = male_corrects.double() / male_total * 100. if male_total > 0 else 0
            female_acc = female_corrects.double() / female_total * 100. if female_total > 0 else 0
            epoch_loss = running_loss / len(test_dataset)
            epoch_acc = running_corrects / len(test_dataset) * 100.

            # Print results
            print(f'[Test] Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}% Time: {time.time() - start_time:.4f}s')
            print(f'[Test] Male Accuracy: {male_acc:.4f}%')
            print(f'[Test] Female Accuracy: {female_acc:.4f}%')

            # Save results
            results.append({
                "Test Dataset": test_name,
                "Model Folder": fixmatch_folder,
                "Model": model_path,
                "Loss": epoch_loss,
                "Accuracy": epoch_acc.item(),
                "Male Accuracy": male_acc.item(),
                "Female Accuracy": female_acc.item()
            })

# Save results to CSV
df = pd.DataFrame(results)
df.to_csv("all_FixMatch_experiments_results.csv", index=False)
print("All experiments completed. Results saved to 'all_FixMatch_experiments_results.csv'.")
# Out:
# [Test] Loss: 0.9503 Acc: 79.2258% Time: 28.6596s
# [Test] Male Accuracy: 88.9318%
# [Test] Female Accuracy: 69.4696%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.5022 Acc: 76.1936% Time: 29.4945s
# [Test] Male Accuracy: 95.1094%
# [Test] Female Accuracy: 57.1798%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.8155 Acc: 74.9677% Time: 28.5983s
# [Test] Male Accuracy: 94.8520%
# [Test] Female Accuracy: 54.9806%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.9785 Acc: 76.3871% Time: 30.1143s
# [Test] Male Accuracy: 93.1789%
# [Test] Female Accuracy: 59.5084%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.9918 Acc: 76.7742% Time: 30.7057s
# [Test] Male Accuracy: 93.9511%
# [Test] Female Accuracy: 59.5084%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.9361 Acc: 77.9355% Time: 28.4146s
# [Test] Male Accuracy: 92.6641%
# [Test] Female Accuracy: 63.1307%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 2.1143 Acc: 76.0000% Time: 29.3521s
# [Test] Male Accuracy: 93.9511%
# [Test] Female Accuracy: 57.9560%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 2.3278 Acc: 77.0968% Time: 29.2490s
# [Test] Male Accuracy: 94.2085%
# [Test] Female Accuracy: 59.8965%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 2.2692 Acc: 77.4194% Time: 28.2278s
# [Test] Male Accuracy: 94.3372%
# [Test] Female Accuracy: 60.4140%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 2.4530 Acc: 76.8387% Time: 28.2571s
# [Test] Male Accuracy: 93.5650%
# [Test] Female Accuracy: 60.0259%
# --- Testing on Balanced_Validation ---
# Class names: ['female', 'male']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.8342 Acc: 74.3353% Time: 82.8245s
# [Test] Male Accuracy: 88.3392%
# [Test] Female Accuracy: 58.2211%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 2.1598 Acc: 72.7402% Time: 82.9191s
# [Test] Male Accuracy: 91.6740%
# [Test] Female Accuracy: 50.9530%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 2.2430 Acc: 72.3148% Time: 82.0432s
# [Test] Male Accuracy: 91.2544%
# [Test] Female Accuracy: 50.5210%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 2.1970 Acc: 74.1463% Time: 82.8296s
# [Test] Male Accuracy: 89.8189%
# [Test] Female Accuracy: 56.1118%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 2.5668 Acc: 73.8863% Time: 83.2735s
# [Test] Male Accuracy: 89.8852%
# [Test] Female Accuracy: 55.4765%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.1977 Acc: 75.6115% Time: 82.0976s
# [Test] Male Accuracy: 80.9629%
# [Test] Female Accuracy: 69.4536%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 1.2216 Acc: 75.2924% Time: 82.8895s
# [Test] Male Accuracy: 74.8233%
# [Test] Female Accuracy: 75.8323%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 1.4600 Acc: 74.2999% Time: 82.5023s
# [Test] Male Accuracy: 77.4956%
# [Test] Female Accuracy: 70.6226%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 0.9625 Acc: 76.6277% Time: 82.8442s
# [Test] Male Accuracy: 91.4753%
# [Test] Female Accuracy: 59.5426%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.6860 Acc: 75.3043% Time: 81.7813s
# [Test] Male Accuracy: 93.5512%
# [Test] Female Accuracy: 54.3075%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 2.0913 Acc: 74.3708% Time: 82.6347s
# [Test] Male Accuracy: 92.6237%
# [Test] Female Accuracy: 53.3672%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 2.0168 Acc: 73.7918% Time: 82.6254s
# [Test] Male Accuracy: 93.1316%
# [Test] Female Accuracy: 51.5375%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 2.3088 Acc: 74.0636% Time: 82.6869s
# [Test] Male Accuracy: 91.5857%
# [Test] Female Accuracy: 53.9009%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 0.8874 Acc: 77.5257% Time: 81.2778s
# [Test] Male Accuracy: 87.1025%
# [Test] Female Accuracy: 66.5057%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.1300 Acc: 76.1668% Time: 83.1628s
# [Test] Male Accuracy: 81.0292%
# [Test] Female Accuracy: 70.5718%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.3675 Acc: 75.6824% Time: 81.8856s
# [Test] Male Accuracy: 82.1334%
# [Test] Female Accuracy: 68.2592%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.7527 Acc: 76.3086% Time: 82.9366s
# [Test] Male Accuracy: 76.8993%
# [Test] Female Accuracy: 75.6290%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 2.0551 Acc: 76.5568% Time: 83.5315s
# [Test] Male Accuracy: 75.0000%
# [Test] Female Accuracy: 78.3482%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 2.1787 Acc: 76.5804% Time: 82.0849s
# [Test] Male Accuracy: 74.2270%
# [Test] Female Accuracy: 79.2884%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.9512 Acc: 76.2614% Time: 82.1785s
# [Test] Male Accuracy: 75.0442%
# [Test] Female Accuracy: 77.6620%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 2.1985 Acc: 76.6513% Time: 82.4102s
# [Test] Male Accuracy: 78.2465%
# [Test] Female Accuracy: 74.8158%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 2.1868 Acc: 75.4342% Time: 82.6952s
# [Test] Male Accuracy: 75.8171%
# [Test] Female Accuracy: 74.9936%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 2.1936 Acc: 75.9305% Time: 82.4501s
# [Test] Male Accuracy: 75.8613%
# [Test] Female Accuracy: 76.0102%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 2.1502 Acc: 76.6040% Time: 81.4382s
# [Test] Male Accuracy: 77.2085%
# [Test] Female Accuracy: 75.9085%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 2.0991 Acc: 76.7813% Time: 81.2910s
# [Test] Male Accuracy: 78.5336%
# [Test] Female Accuracy: 74.7649%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 2.4731 Acc: 75.8478% Time: 82.0909s
# [Test] Male Accuracy: 73.0124%
# [Test] Female Accuracy: 79.1105%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 2.0852 Acc: 75.0089% Time: 81.3999s
# [Test] Male Accuracy: 92.1378%
# [Test] Female Accuracy: 55.2986%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 2.1655 Acc: 74.6307% Time: 82.1118s
# [Test] Male Accuracy: 91.7845%
# [Test] Female Accuracy: 54.8920%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 2.2910 Acc: 74.8789% Time: 82.5093s
# [Test] Male Accuracy: 91.8728%
# [Test] Female Accuracy: 55.3240%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 0.8916 Acc: 77.1240% Time: 82.2979s
# [Test] Male Accuracy: 85.3578%
# [Test] Female Accuracy: 67.6493%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.1728 Acc: 77.2185% Time: 82.2777s
# [Test] Male Accuracy: 86.6608%
# [Test] Female Accuracy: 66.3532%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.3329 Acc: 77.7620% Time: 82.4885s
# [Test] Male Accuracy: 80.0133%
# [Test] Female Accuracy: 75.1715%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.2082 Acc: 77.3485% Time: 85.0566s
# [Test] Male Accuracy: 76.3251%
# [Test] Female Accuracy: 78.5260%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.4701 Acc: 77.0294% Time: 99.4608s
# [Test] Male Accuracy: 78.0256%
# [Test] Female Accuracy: 75.8831%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.5374 Acc: 77.2776% Time: 99.8907s
# [Test] Male Accuracy: 76.9876%
# [Test] Female Accuracy: 77.6112%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.7099 Acc: 76.9585% Time: 95.4519s
# [Test] Male Accuracy: 77.2527%
# [Test] Female Accuracy: 76.6201%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 1.8117 Acc: 75.6233% Time: 98.6120s
# [Test] Male Accuracy: 74.5583%
# [Test] Female Accuracy: 76.8488%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 1.8557 Acc: 76.6868% Time: 96.5801s
# [Test] Male Accuracy: 75.8613%
# [Test] Female Accuracy: 77.6366%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 1.8374 Acc: 76.5095% Time: 94.7415s
# [Test] Male Accuracy: 73.7633%
# [Test] Female Accuracy: 79.6696%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.1949 Acc: 74.8080% Time: 93.5740s
# [Test] Male Accuracy: 92.0716%
# [Test] Female Accuracy: 54.9428%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.4632 Acc: 75.8833% Time: 94.2063s
# [Test] Male Accuracy: 90.1060%
# [Test] Female Accuracy: 59.5172%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.9747 Acc: 75.3279% Time: 91.5652s
# [Test] Male Accuracy: 91.4973%
# [Test] Female Accuracy: 56.7217%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.9137 Acc: 75.6351% Time: 98.9094s
# [Test] Male Accuracy: 70.9585%
# [Test] Female Accuracy: 81.0165%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.9458 Acc: 75.6233% Time: 96.4744s
# [Test] Male Accuracy: 68.1758%
# [Test] Female Accuracy: 84.1931%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.9633 Acc: 75.4342% Time: 100.3998s
# [Test] Male Accuracy: 68.7721%
# [Test] Female Accuracy: 83.1004%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.9510 Acc: 74.8552% Time: 96.2993s
# [Test] Male Accuracy: 68.1095%
# [Test] Female Accuracy: 82.6175%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.9464 Acc: 75.6942% Time: 94.0650s
# [Test] Male Accuracy: 71.7535%
# [Test] Female Accuracy: 80.2287%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 1.9693 Acc: 74.0990% Time: 92.9166s
# [Test] Male Accuracy: 65.3048%
# [Test] Female Accuracy: 84.2186%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 1.9386 Acc: 73.7445% Time: 93.6217s
# [Test] Male Accuracy: 64.5760%
# [Test] Female Accuracy: 84.2948%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 2.0725 Acc: 73.8036% Time: 94.1131s
# [Test] Male Accuracy: 65.8348%
# [Test] Female Accuracy: 82.9733%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 2.0284 Acc: 74.2054% Time: 99.8762s
# [Test] Male Accuracy: 66.4090%
# [Test] Female Accuracy: 83.1766%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 2.2318 Acc: 74.0163% Time: 93.3097s
# [Test] Male Accuracy: 66.2544%
# [Test] Female Accuracy: 82.9479%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.4718 Acc: 77.5611% Time: 94.1469s
# [Test] Male Accuracy: 89.2889%
# [Test] Female Accuracy: 64.0661%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 1.4612 Acc: 78.1401% Time: 91.4060s
# [Test] Male Accuracy: 88.2509%
# [Test] Female Accuracy: 66.5057%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 1.6070 Acc: 78.1874% Time: 96.0762s
# [Test] Male Accuracy: 87.5221%
# [Test] Female Accuracy: 67.4460%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 0.8327 Acc: 78.4710% Time: 95.7159s
# [Test] Male Accuracy: 81.6254%
# [Test] Female Accuracy: 74.8412%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.0761 Acc: 77.5021% Time: 93.6219s
# [Test] Male Accuracy: 84.0769%
# [Test] Female Accuracy: 69.9365%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.4472 Acc: 76.8167% Time: 93.3092s
# [Test] Male Accuracy: 81.2279%
# [Test] Female Accuracy: 71.7408%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.5101 Acc: 76.7931% Time: 92.1932s
# [Test] Male Accuracy: 78.7102%
# [Test] Female Accuracy: 74.5870%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.6089 Acc: 76.7458% Time: 93.8871s
# [Test] Male Accuracy: 79.4170%
# [Test] Female Accuracy: 73.6722%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.4283 Acc: 77.4193% Time: 94.5479s
# [Test] Male Accuracy: 79.1961%
# [Test] Female Accuracy: 75.3748%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.6329 Acc: 76.7104% Time: 93.6459s
# [Test] Male Accuracy: 77.8048%
# [Test] Female Accuracy: 75.4511%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 1.8076 Acc: 75.9778% Time: 93.8448s
# [Test] Male Accuracy: 74.1608%
# [Test] Female Accuracy: 78.0686%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 1.9584 Acc: 75.9305% Time: 93.6363s
# [Test] Male Accuracy: 74.4920%
# [Test] Female Accuracy: 77.5858%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 1.8937 Acc: 76.0841% Time: 92.8082s
# [Test] Male Accuracy: 72.7915%
# [Test] Female Accuracy: 79.8729%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.0101 Acc: 77.4075% Time: 93.0449s
# [Test] Male Accuracy: 87.7871%
# [Test] Female Accuracy: 65.4638%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.2762 Acc: 77.9747% Time: 93.5726s
# [Test] Male Accuracy: 88.6263%
# [Test] Female Accuracy: 65.7179%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.3068 Acc: 78.4474% Time: 93.3593s
# [Test] Male Accuracy: 87.3454%
# [Test] Female Accuracy: 68.2084%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.5663 Acc: 79.0854% Time: 93.1569s
# [Test] Male Accuracy: 81.3825%
# [Test] Female Accuracy: 76.4422%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.7071 Acc: 78.6600% Time: 92.8033s
# [Test] Male Accuracy: 82.3984%
# [Test] Female Accuracy: 74.3583%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.5356 Acc: 78.4828% Time: 91.5504s
# [Test] Male Accuracy: 82.5751%
# [Test] Female Accuracy: 73.7738%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.5693 Acc: 78.7900% Time: 93.7413s
# [Test] Male Accuracy: 83.1051%
# [Test] Female Accuracy: 73.8247%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.7817 Acc: 78.0811% Time: 93.2722s
# [Test] Male Accuracy: 82.9505%
# [Test] Female Accuracy: 72.4778%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 1.9245 Acc: 78.0692% Time: 92.7125s
# [Test] Male Accuracy: 81.4929%
# [Test] Female Accuracy: 74.1296%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 2.0590 Acc: 78.0456% Time: 93.1762s
# [Test] Male Accuracy: 82.0009%
# [Test] Female Accuracy: 73.4943%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 1.8422 Acc: 78.9673% Time: 93.3143s
# [Test] Male Accuracy: 79.7482%
# [Test] Female Accuracy: 78.0686%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 1.7649 Acc: 78.3056% Time: 93.8590s
# [Test] Male Accuracy: 82.9505%
# [Test] Female Accuracy: 72.9606%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 1.8797 Acc: 78.3646% Time: 93.5141s
# [Test] Male Accuracy: 82.1996%
# [Test] Female Accuracy: 73.9517%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.4729 Acc: 78.0220% Time: 93.2201s
# [Test] Male Accuracy: 90.1281%
# [Test] Female Accuracy: 64.0915%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 1.6806 Acc: 76.8994% Time: 93.7132s
# [Test] Male Accuracy: 91.3207%
# [Test] Female Accuracy: 60.3050%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 1.4998 Acc: 77.7502% Time: 94.0662s
# [Test] Male Accuracy: 88.7588%
# [Test] Female Accuracy: 65.0826%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 0.9838 Acc: 77.9983% Time: 91.8121s
# [Test] Male Accuracy: 81.8463%
# [Test] Female Accuracy: 73.5705%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.0184 Acc: 78.5301% Time: 92.5573s
# [Test] Male Accuracy: 82.0230%
# [Test] Female Accuracy: 74.5108%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.2766 Acc: 78.0102% Time: 91.9789s
# [Test] Male Accuracy: 82.0892%
# [Test] Female Accuracy: 73.3164%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.3660 Acc: 78.5064% Time: 93.0299s
# [Test] Male Accuracy: 85.0486%
# [Test] Female Accuracy: 70.9784%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.3360 Acc: 78.3883% Time: 91.8758s
# [Test] Male Accuracy: 86.3737%
# [Test] Female Accuracy: 69.1995%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.7674 Acc: 78.2937% Time: 94.0628s
# [Test] Male Accuracy: 85.9761%
# [Test] Female Accuracy: 69.4536%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.6577 Acc: 78.7546% Time: 94.1703s
# [Test] Male Accuracy: 85.2253%
# [Test] Female Accuracy: 71.3088%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 1.6396 Acc: 78.6719% Time: 93.6799s
# [Test] Male Accuracy: 83.3039%
# [Test] Female Accuracy: 73.3418%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 1.6121 Acc: 79.2272% Time: 91.7375s
# [Test] Male Accuracy: 84.2094%
# [Test] Female Accuracy: 73.4943%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 1.7682 Acc: 78.4237% Time: 91.7828s
# [Test] Male Accuracy: 83.6572%
# [Test] Female Accuracy: 72.4015%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.1314 Acc: 77.5848% Time: 92.0010s
# [Test] Male Accuracy: 89.2889%
# [Test] Female Accuracy: 64.1169%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.2799 Acc: 77.9038% Time: 91.7406s
# [Test] Male Accuracy: 90.2385%
# [Test] Female Accuracy: 63.7103%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.5171 Acc: 78.5537% Time: 91.7496s
# [Test] Male Accuracy: 89.2889%
# [Test] Female Accuracy: 66.2008%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.5142 Acc: 78.9909% Time: 91.1823s
# [Test] Male Accuracy: 82.1113%
# [Test] Female Accuracy: 75.4003%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.6344 Acc: 78.0574% Time: 92.8584s
# [Test] Male Accuracy: 82.3322%
# [Test] Female Accuracy: 73.1385%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.7785 Acc: 78.5183% Time: 91.4515s
# [Test] Male Accuracy: 81.9125%
# [Test] Female Accuracy: 74.6125%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.7532 Acc: 78.1874% Time: 91.5054s
# [Test] Male Accuracy: 83.0830%
# [Test] Female Accuracy: 72.5540%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.8293 Acc: 78.4355% Time: 90.3908s
# [Test] Male Accuracy: 82.2217%
# [Test] Female Accuracy: 74.0788%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 1.7396 Acc: 78.2347% Time: 91.2264s
# [Test] Male Accuracy: 79.8587%
# [Test] Female Accuracy: 76.3659%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 1.6745 Acc: 78.1756% Time: 91.8214s
# [Test] Male Accuracy: 82.0451%
# [Test] Female Accuracy: 73.7230%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 1.9643 Acc: 77.5375% Time: 92.5937s
# [Test] Male Accuracy: 81.9788%
# [Test] Female Accuracy: 72.4269%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 1.9722 Acc: 78.2937% Time: 87.4362s
# [Test] Male Accuracy: 81.7138%
# [Test] Female Accuracy: 74.3583%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 2.1383 Acc: 78.5537% Time: 94.3167s
# [Test] Male Accuracy: 80.9850%
# [Test] Female Accuracy: 75.7560%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.6153 Acc: 77.6320% Time: 92.6180s
# [Test] Male Accuracy: 91.9611%
# [Test] Female Accuracy: 61.1436%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 1.7042 Acc: 78.4474% Time: 94.1273s
# [Test] Male Accuracy: 89.9072%
# [Test] Female Accuracy: 65.2605%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 2.1922 Acc: 77.5730% Time: 94.0562s
# [Test] Male Accuracy: 91.6078%
# [Test] Female Accuracy: 61.4231%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.0760 Acc: 78.3883% Time: 92.3011s
# [Test] Male Accuracy: 87.0141%
# [Test] Female Accuracy: 68.4625%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.1441 Acc: 78.1520% Time: 93.8695s
# [Test] Male Accuracy: 86.3958%
# [Test] Female Accuracy: 68.6658%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.4184 Acc: 78.8491% Time: 93.5538s
# [Test] Male Accuracy: 85.3578%
# [Test] Female Accuracy: 71.3596%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.4191 Acc: 78.8255% Time: 94.2683s
# [Test] Male Accuracy: 84.5627%
# [Test] Female Accuracy: 72.2236%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.6218 Acc: 78.4946% Time: 93.6091s
# [Test] Male Accuracy: 86.1749%
# [Test] Female Accuracy: 69.6569%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.5429 Acc: 79.3454% Time: 92.0499s
# [Test] Male Accuracy: 83.3260%
# [Test] Female Accuracy: 74.7649%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.6077 Acc: 78.6364% Time: 93.8737s
# [Test] Male Accuracy: 82.9064%
# [Test] Female Accuracy: 73.7230%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 1.7134 Acc: 78.9200% Time: 93.4589s
# [Test] Male Accuracy: 84.2094%
# [Test] Female Accuracy: 72.8335%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 1.8749 Acc: 78.6364% Time: 94.4721s
# [Test] Male Accuracy: 82.9064%
# [Test] Female Accuracy: 73.7230%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 1.9148 Acc: 78.6955% Time: 94.2630s
# [Test] Male Accuracy: 82.6855%
# [Test] Female Accuracy: 74.1042%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.2229 Acc: 78.5655% Time: 93.4543s
# [Test] Male Accuracy: 89.3993%
# [Test] Female Accuracy: 66.0991%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.3226 Acc: 78.4355% Time: 93.7175s
# [Test] Male Accuracy: 91.1219%
# [Test] Female Accuracy: 63.8374%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.8778 Acc: 77.5966% Time: 93.8001s
# [Test] Male Accuracy: 91.7182%
# [Test] Female Accuracy: 61.3469%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.1626 Acc: 78.8609% Time: 93.7314s
# [Test] Male Accuracy: 84.9602%
# [Test] Female Accuracy: 71.8424%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.4289 Acc: 78.4237% Time: 94.4195s
# [Test] Male Accuracy: 83.1272%
# [Test] Female Accuracy: 73.0114%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.3292 Acc: 77.2539% Time: 94.0935s
# [Test] Male Accuracy: 86.6608%
# [Test] Female Accuracy: 66.4295%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.4971 Acc: 77.5257% Time: 92.7804s
# [Test] Male Accuracy: 87.8313%
# [Test] Female Accuracy: 65.6671%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.5535 Acc: 74.8552% Time: 91.6931s
# [Test] Male Accuracy: 67.8004%
# [Test] Female Accuracy: 82.9733%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 0.8252 Acc: 78.4237% Time: 93.3908s
# [Test] Male Accuracy: 83.9664%
# [Test] Female Accuracy: 72.0457%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 0.9518 Acc: 79.2745% Time: 93.4819s
# [Test] Male Accuracy: 83.7014%
# [Test] Female Accuracy: 74.1804%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.0124 Acc: 77.9393% Time: 94.0003s
# [Test] Male Accuracy: 80.2783%
# [Test] Female Accuracy: 75.2478%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.3773 Acc: 78.6837% Time: 93.4672s
# [Test] Male Accuracy: 84.0106%
# [Test] Female Accuracy: 72.5540%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.1408 Acc: 78.7664% Time: 94.1167s
# [Test] Male Accuracy: 86.4399%
# [Test] Female Accuracy: 69.9365%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 2.9266 Acc: 74.7962% Time: 93.7346s
# [Test] Male Accuracy: 92.5133%
# [Test] Female Accuracy: 54.4091%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 2.6600 Acc: 74.6544% Time: 93.5682s
# [Test] Male Accuracy: 93.0875%
# [Test] Female Accuracy: 53.4435%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 2.3976 Acc: 75.3752% Time: 93.5274s
# [Test] Male Accuracy: 90.9231%
# [Test] Female Accuracy: 57.4841%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 2.9887 Acc: 75.4461% Time: 94.0835s
# [Test] Male Accuracy: 91.2544%
# [Test] Female Accuracy: 57.2554%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 3.2719 Acc: 74.9852% Time: 93.0722s
# [Test] Male Accuracy: 92.8887%
# [Test] Female Accuracy: 54.3837%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 3.1541 Acc: 75.8124% Time: 93.1272s
# [Test] Male Accuracy: 90.8348%
# [Test] Female Accuracy: 58.5260%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 3.3147 Acc: 74.8316% Time: 92.2702s
# [Test] Male Accuracy: 92.2261%
# [Test] Female Accuracy: 54.8158%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 3.7655 Acc: 74.2526% Time: 93.4165s
# [Test] Male Accuracy: 93.8163%
# [Test] Female Accuracy: 51.7408%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 3.1098 Acc: 75.0443% Time: 93.8715s
# [Test] Male Accuracy: 92.6458%
# [Test] Female Accuracy: 54.7903%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 3.3098 Acc: 75.4224% Time: 93.3876s
# [Test] Male Accuracy: 91.6078%
# [Test] Female Accuracy: 56.7980%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.0903 Acc: 77.2776% Time: 92.1537s
# [Test] Male Accuracy: 87.7871%
# [Test] Female Accuracy: 65.1842%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.7108 Acc: 75.3870% Time: 93.4537s
# [Test] Male Accuracy: 93.6396%
# [Test] Female Accuracy: 54.3837%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.9208 Acc: 74.5244% Time: 93.7939s
# [Test] Male Accuracy: 93.7058%
# [Test] Female Accuracy: 52.4524%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 2.1952 Acc: 74.7725% Time: 93.9484s
# [Test] Male Accuracy: 91.9611%
# [Test] Female Accuracy: 54.9936%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 2.3177 Acc: 75.1034% Time: 93.7354s
# [Test] Male Accuracy: 92.6458%
# [Test] Female Accuracy: 54.9174%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 2.2933 Acc: 76.1787% Time: 93.2082s
# [Test] Male Accuracy: 91.6078%
# [Test] Female Accuracy: 58.4244%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 2.3474 Acc: 75.1034% Time: 93.2220s
# [Test] Male Accuracy: 92.4691%
# [Test] Female Accuracy: 55.1207%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 2.5784 Acc: 75.6706% Time: 94.4079s
# [Test] Male Accuracy: 91.4532%
# [Test] Female Accuracy: 57.5095%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 2.5538 Acc: 75.5406% Time: 93.7291s
# [Test] Male Accuracy: 91.5857%
# [Test] Female Accuracy: 57.0775%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 2.7486 Acc: 74.9380% Time: 93.3567s
# [Test] Male Accuracy: 91.7845%
# [Test] Female Accuracy: 55.5527%
# --- Testing on AAF_Validation ---
# Class names: ['female', 'male']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 2.6943 Acc: 68.3637% Time: 63.0997s
# [Test] Male Accuracy: 98.6529%
# [Test] Female Accuracy: 38.0745%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 3.3420 Acc: 64.7781% Time: 61.6284s
# [Test] Male Accuracy: 99.1284%
# [Test] Female Accuracy: 30.4279%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 3.8401 Acc: 62.8368% Time: 60.4862s
# [Test] Male Accuracy: 99.2472%
# [Test] Female Accuracy: 26.4263%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 3.0561 Acc: 69.0372% Time: 62.0381s
# [Test] Male Accuracy: 97.2266%
# [Test] Female Accuracy: 40.8479%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 3.7194 Acc: 67.5911% Time: 61.3651s
# [Test] Male Accuracy: 97.9398%
# [Test] Female Accuracy: 37.2425%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 0.9287 Acc: 78.3281% Time: 62.0749s
# [Test] Male Accuracy: 91.3629%
# [Test] Female Accuracy: 65.2932%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 0.7410 Acc: 79.0808% Time: 61.9469s
# [Test] Male Accuracy: 87.0048%
# [Test] Female Accuracy: 71.1569%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 1.0664 Acc: 77.1593% Time: 61.6831s
# [Test] Male Accuracy: 91.1252%
# [Test] Female Accuracy: 63.1933%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.3972 Acc: 71.6323% Time: 62.1497s
# [Test] Male Accuracy: 99.1680%
# [Test] Female Accuracy: 44.0967%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.9897 Acc: 70.3843% Time: 63.4669s
# [Test] Male Accuracy: 98.7718%
# [Test] Female Accuracy: 41.9968%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 2.8911 Acc: 65.5705% Time: 61.9980s
# [Test] Male Accuracy: 99.1284%
# [Test] Female Accuracy: 32.0127%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 2.6579 Acc: 65.4319% Time: 62.0984s
# [Test] Male Accuracy: 98.1379%
# [Test] Female Accuracy: 32.7258%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 3.0790 Acc: 66.8978% Time: 61.8914s
# [Test] Male Accuracy: 98.1775%
# [Test] Female Accuracy: 35.6181%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.1146 Acc: 74.6038% Time: 61.7076s
# [Test] Male Accuracy: 97.6624%
# [Test] Female Accuracy: 51.5452%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.1628 Acc: 76.4857% Time: 62.3369s
# [Test] Male Accuracy: 96.2361%
# [Test] Female Accuracy: 56.7353%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 1.1071 Acc: 77.0602% Time: 62.2051s
# [Test] Male Accuracy: 93.8590%
# [Test] Female Accuracy: 60.2615%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 2.2410 Acc: 68.8590% Time: 61.6080s
# [Test] Male Accuracy: 97.3059%
# [Test] Female Accuracy: 40.4120%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 2.5113 Acc: 70.2853% Time: 61.9499s
# [Test] Male Accuracy: 96.7512%
# [Test] Female Accuracy: 43.8193%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 2.3342 Acc: 70.1466% Time: 61.5830s
# [Test] Male Accuracy: 94.7306%
# [Test] Female Accuracy: 45.5626%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 2.0859 Acc: 70.7013% Time: 61.8053s
# [Test] Male Accuracy: 94.4532%
# [Test] Female Accuracy: 46.9493%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 2.9868 Acc: 67.6506% Time: 61.9108s
# [Test] Male Accuracy: 96.2758%
# [Test] Female Accuracy: 39.0254%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 3.4993 Acc: 62.5991% Time: 62.2271s
# [Test] Male Accuracy: 96.9493%
# [Test] Female Accuracy: 28.2488%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 2.5656 Acc: 68.4430% Time: 61.8349s
# [Test] Male Accuracy: 96.7908%
# [Test] Female Accuracy: 40.0951%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 2.6811 Acc: 67.8685% Time: 61.5453s
# [Test] Male Accuracy: 97.7021%
# [Test] Female Accuracy: 38.0349%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 3.3502 Acc: 65.2140% Time: 61.3753s
# [Test] Male Accuracy: 97.8605%
# [Test] Female Accuracy: 32.5674%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 2.9128 Acc: 68.4430% Time: 61.4213s
# [Test] Male Accuracy: 96.0380%
# [Test] Female Accuracy: 40.8479%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 3.6557 Acc: 67.0365% Time: 61.5079s
# [Test] Male Accuracy: 99.5642%
# [Test] Female Accuracy: 34.5087%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 3.4943 Acc: 67.8288% Time: 60.4867s
# [Test] Male Accuracy: 99.1680%
# [Test] Female Accuracy: 36.4897%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 4.5225 Acc: 64.8772% Time: 61.4484s
# [Test] Male Accuracy: 99.5642%
# [Test] Female Accuracy: 30.1902%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.1304 Acc: 73.5341% Time: 61.8168s
# [Test] Male Accuracy: 97.5436%
# [Test] Female Accuracy: 49.5246%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.7493 Acc: 69.9485% Time: 62.4129s
# [Test] Male Accuracy: 98.7718%
# [Test] Female Accuracy: 41.1252%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.4474 Acc: 74.3859% Time: 61.8417s
# [Test] Male Accuracy: 96.9889%
# [Test] Female Accuracy: 51.7829%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.3397 Acc: 74.4057% Time: 59.4134s
# [Test] Male Accuracy: 96.7116%
# [Test] Female Accuracy: 52.0998%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 2.1493 Acc: 70.2258% Time: 62.3157s
# [Test] Male Accuracy: 97.5040%
# [Test] Female Accuracy: 42.9477%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.7017 Acc: 72.5634% Time: 62.2656s
# [Test] Male Accuracy: 96.8700%
# [Test] Female Accuracy: 48.2567%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.8551 Acc: 71.9493% Time: 62.2219s
# [Test] Male Accuracy: 94.8494%
# [Test] Female Accuracy: 49.0491%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 1.8035 Acc: 69.9485% Time: 62.2186s
# [Test] Male Accuracy: 96.2361%
# [Test] Female Accuracy: 43.6609%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 2.3405 Acc: 69.7504% Time: 63.1054s
# [Test] Male Accuracy: 96.6323%
# [Test] Female Accuracy: 42.8685%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 2.0644 Acc: 72.1672% Time: 62.2626s
# [Test] Male Accuracy: 96.4739%
# [Test] Female Accuracy: 47.8605%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.4514 Acc: 71.3550% Time: 62.4591s
# [Test] Male Accuracy: 99.0491%
# [Test] Female Accuracy: 43.6609%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 2.0117 Acc: 71.2163% Time: 62.0780s
# [Test] Male Accuracy: 98.7322%
# [Test] Female Accuracy: 43.7005%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 3.5162 Acc: 66.5214% Time: 62.3082s
# [Test] Male Accuracy: 99.4453%
# [Test] Female Accuracy: 33.5975%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.7893 Acc: 76.4263% Time: 62.4245s
# [Test] Male Accuracy: 91.6006%
# [Test] Female Accuracy: 61.2520%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.5027 Acc: 78.1101% Time: 62.3229s
# [Test] Male Accuracy: 86.3312%
# [Test] Female Accuracy: 69.8891%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.7248 Acc: 75.8320% Time: 63.2113s
# [Test] Male Accuracy: 88.4707%
# [Test] Female Accuracy: 63.1933%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.8754 Acc: 74.2868% Time: 61.8543s
# [Test] Male Accuracy: 86.9651%
# [Test] Female Accuracy: 61.6086%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.8819 Acc: 75.1387% Time: 61.2811s
# [Test] Male Accuracy: 91.4025%
# [Test] Female Accuracy: 58.8748%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 1.4006 Acc: 76.3273% Time: 62.3459s
# [Test] Male Accuracy: 82.6862%
# [Test] Female Accuracy: 69.9683%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 1.5442 Acc: 73.9303% Time: 62.3445s
# [Test] Male Accuracy: 81.5769%
# [Test] Female Accuracy: 66.2837%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 1.5899 Acc: 73.6727% Time: 62.3172s
# [Test] Male Accuracy: 80.5071%
# [Test] Female Accuracy: 66.8384%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 1.8216 Acc: 72.3851% Time: 62.1380s
# [Test] Male Accuracy: 81.6957%
# [Test] Female Accuracy: 63.0745%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 1.8137 Acc: 73.8114% Time: 61.8546s
# [Test] Male Accuracy: 85.0634%
# [Test] Female Accuracy: 62.5594%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.5313 Acc: 77.9517% Time: 61.8801s
# [Test] Male Accuracy: 95.9984%
# [Test] Female Accuracy: 59.9049%
# ...
# [Test] Male Accuracy: 99.0095%
# [Test] Female Accuracy: 41.6006%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 2.7373 Acc: 69.2552% Time: 62.8800s
# [Test] Male Accuracy: 99.0491%
# [Test] Female Accuracy: 39.4612%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 2.4052 Acc: 71.4739% Time: 62.2570s
# [Test] Male Accuracy: 98.2964%
# [Test] Female Accuracy: 44.6513%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.1646 Acc: 78.6450% Time: 62.2901s
# [Test] Male Accuracy: 95.9588%
# [Test] Female Accuracy: 61.3312%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.5938 Acc: 74.1878% Time: 62.0700s
# [Test] Male Accuracy: 96.8304%
# [Test] Female Accuracy: 51.5452%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.5682 Acc: 76.2678% Time: 62.0503s
# [Test] Male Accuracy: 92.8288%
# [Test] Female Accuracy: 59.7068%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.7345 Acc: 73.9699% Time: 61.8382s
# [Test] Male Accuracy: 95.2456%
# [Test] Female Accuracy: 52.6941%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.6589 Acc: 72.9794% Time: 61.9182s
# [Test] Male Accuracy: 95.7211%
# [Test] Female Accuracy: 50.2377%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 2.0894 Acc: 74.0293% Time: 64.1668s
# [Test] Male Accuracy: 93.1458%
# [Test] Female Accuracy: 54.9128%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 1.7889 Acc: 75.1189% Time: 62.3575s
# [Test] Male Accuracy: 93.5024%
# [Test] Female Accuracy: 56.7353%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 2.0349 Acc: 73.1973% Time: 62.5450s
# [Test] Male Accuracy: 92.7100%
# [Test] Female Accuracy: 53.6846%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 1.7621 Acc: 75.3368% Time: 61.9261s
# [Test] Male Accuracy: 92.8288%
# [Test] Female Accuracy: 57.8447%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 2.1829 Acc: 73.7718% Time: 61.9975s
# [Test] Male Accuracy: 93.2647%
# [Test] Female Accuracy: 54.2789%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.7952 Acc: 72.8605% Time: 62.2053s
# [Test] Male Accuracy: 98.6529%
# [Test] Female Accuracy: 47.0681%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 2.1691 Acc: 71.7908% Time: 62.0185s
# [Test] Male Accuracy: 98.9699%
# [Test] Female Accuracy: 44.6117%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 2.4073 Acc: 72.4247% Time: 61.7702s
# [Test] Male Accuracy: 98.6133%
# [Test] Female Accuracy: 46.2361%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.8407 Acc: 76.1688% Time: 61.9651s
# [Test] Male Accuracy: 91.7987%
# [Test] Female Accuracy: 60.5388%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.8338 Acc: 76.4857% Time: 61.8901s
# [Test] Male Accuracy: 92.1553%
# [Test] Female Accuracy: 60.8162%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.9842 Acc: 76.9216% Time: 62.6497s
# [Test] Male Accuracy: 92.8288%
# [Test] Female Accuracy: 61.0143%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.9721 Acc: 76.9414% Time: 61.8932s
# [Test] Male Accuracy: 93.7005%
# [Test] Female Accuracy: 60.1823%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.7807 Acc: 78.1300% Time: 62.4452s
# [Test] Male Accuracy: 90.3328%
# [Test] Female Accuracy: 65.9271%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 1.7648 Acc: 77.2979% Time: 61.9503s
# [Test] Male Accuracy: 89.9762%
# [Test] Female Accuracy: 64.6197%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 1.5222 Acc: 77.3376% Time: 61.9572s
# [Test] Male Accuracy: 89.8177%
# [Test] Female Accuracy: 64.8574%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 1.9851 Acc: 77.3177% Time: 62.0842s
# [Test] Male Accuracy: 92.4723%
# [Test] Female Accuracy: 62.1632%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 2.0017 Acc: 78.5063% Time: 62.4520s
# [Test] Male Accuracy: 92.4326%
# [Test] Female Accuracy: 64.5800%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 1.9625 Acc: 78.2092% Time: 62.0195s
# [Test] Male Accuracy: 91.1648%
# [Test] Female Accuracy: 65.2536%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_1_unbalanced_best.pth ---
# [Test] Loss: 1.6998 Acc: 76.9216% Time: 62.6763s
# [Test] Male Accuracy: 96.1965%
# [Test] Female Accuracy: 57.6466%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_2_unbalanced_best.pth ---
# [Test] Loss: 2.1542 Acc: 74.8217% Time: 62.1387s
# [Test] Male Accuracy: 95.1664%
# [Test] Female Accuracy: 54.4770%
# --- Testing model: bias_training_data\bias_Unlabeled_0.6\Controlled_Bias_0.6_3_unbalanced_best.pth ---
# [Test] Loss: 2.4715 Acc: 75.8320% Time: 61.8132s
# [Test] Male Accuracy: 95.9984%
# [Test] Female Accuracy: 55.6656%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.5117 Acc: 75.7330% Time: 62.8035s
# [Test] Male Accuracy: 97.5832%
# [Test] Female Accuracy: 53.8827%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.4946 Acc: 76.0103% Time: 61.7696s
# [Test] Male Accuracy: 96.7512%
# [Test] Female Accuracy: 55.2694%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 1.9716 Acc: 75.2971% Time: 62.1619s
# [Test] Male Accuracy: 95.2853%
# [Test] Female Accuracy: 55.3090%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.6782 Acc: 76.1094% Time: 61.9568s
# [Test] Male Accuracy: 94.3740%
# [Test] Female Accuracy: 57.8447%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.9901 Acc: 74.7821% Time: 62.0294s
# [Test] Male Accuracy: 96.0380%
# [Test] Female Accuracy: 53.5261%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 1.7114 Acc: 77.2187% Time: 61.8459s
# [Test] Male Accuracy: 93.1062%
# [Test] Female Accuracy: 61.3312%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 2.0199 Acc: 76.3867% Time: 62.3204s
# [Test] Male Accuracy: 94.4532%
# [Test] Female Accuracy: 58.3201%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 2.3307 Acc: 74.4849% Time: 62.0929s
# [Test] Male Accuracy: 95.6815%
# [Test] Female Accuracy: 53.2884%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 2.1452 Acc: 76.5055% Time: 61.9102s
# [Test] Male Accuracy: 93.7005%
# [Test] Female Accuracy: 59.3106%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 2.1300 Acc: 77.4762% Time: 61.5965s
# [Test] Male Accuracy: 92.8685%
# [Test] Female Accuracy: 62.0840%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_1_unbalanced_best.pth ---
# [Test] Loss: 1.9735 Acc: 74.6434% Time: 61.6813s
# [Test] Male Accuracy: 98.6926%
# [Test] Female Accuracy: 50.5943%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_2_unbalanced_best.pth ---
# [Test] Loss: 1.6405 Acc: 75.7330% Time: 62.0015s
# [Test] Male Accuracy: 97.3455%
# [Test] Female Accuracy: 54.1204%
# --- Testing model: bias_training_data\bias_Unlabeled_0.9\Controlled_Bias_0.9_3_unbalanced_best.pth ---
# [Test] Loss: 2.6771 Acc: 73.2766% Time: 63.1897s
# [Test] Male Accuracy: 97.5040%
# [Test] Female Accuracy: 49.0491%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 1.5760 Acc: 76.6838% Time: 62.3056s
# [Test] Male Accuracy: 97.9794%
# [Test] Female Accuracy: 55.3883%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 1.4942 Acc: 78.6846% Time: 61.9593s
# [Test] Male Accuracy: 96.7116%
# [Test] Female Accuracy: 60.6577%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 1.5453 Acc: 73.9105% Time: 60.6767s
# [Test] Male Accuracy: 95.4041%
# [Test] Female Accuracy: 52.4168%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 1.7729 Acc: 75.8320% Time: 61.8007s
# [Test] Male Accuracy: 97.3059%
# [Test] Female Accuracy: 54.3582%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 1.3041 Acc: 79.9326% Time: 62.3422s
# [Test] Male Accuracy: 90.6498%
# [Test] Female Accuracy: 69.2155%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.1288 Acc: 76.7829% Time: 62.9767s
# [Test] Male Accuracy: 98.1775%
# [Test] Female Accuracy: 55.3883%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 1.0195 Acc: 79.1799% Time: 61.9793s
# [Test] Male Accuracy: 97.1474%
# [Test] Female Accuracy: 61.2124%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 0.8630 Acc: 80.5864% Time: 62.0211s
# [Test] Male Accuracy: 95.5626%
# [Test] Female Accuracy: 65.6101%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 1.5701 Acc: 78.9620% Time: 61.9962s
# [Test] Male Accuracy: 96.5531%
# [Test] Female Accuracy: 61.3708%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 1.4009 Acc: 76.2876% Time: 61.8679s
# [Test] Male Accuracy: 97.8209%
# [Test] Female Accuracy: 54.7544%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_1_balanced_best.pth ---
# [Test] Loss: 4.7513 Acc: 65.8082% Time: 62.2252s
# [Test] Male Accuracy: 98.7322%
# [Test] Female Accuracy: 32.8843%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_2_balanced_best.pth ---
# [Test] Loss: 4.5901 Acc: 64.0452% Time: 62.0342s
# [Test] Male Accuracy: 99.0491%
# [Test] Female Accuracy: 29.0412%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_3_balanced_best.pth ---
# [Test] Loss: 3.6892 Acc: 66.0460% Time: 61.8919s
# [Test] Male Accuracy: 97.9398%
# [Test] Female Accuracy: 34.1521%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_4_balanced_best.pth ---
# [Test] Loss: 4.6180 Acc: 65.3922% Time: 59.3325s
# [Test] Male Accuracy: 98.2171%
# [Test] Female Accuracy: 32.5674%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_5_balanced_best.pth ---
# [Test] Loss: 6.2896 Acc: 61.8463% Time: 62.5046s
# [Test] Male Accuracy: 99.0491%
# [Test] Female Accuracy: 24.6434%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_6_balanced_best.pth ---
# [Test] Loss: 4.9111 Acc: 67.1157% Time: 62.3782s
# [Test] Male Accuracy: 98.2567%
# [Test] Female Accuracy: 35.9746%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_7_balanced_best.pth ---
# [Test] Loss: 5.8697 Acc: 61.7472% Time: 62.2963s
# [Test] Male Accuracy: 99.0491%
# [Test] Female Accuracy: 24.4453%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_8_balanced_best.pth ---
# [Test] Loss: 5.7089 Acc: 64.4017% Time: 62.7528s
# [Test] Male Accuracy: 98.8510%
# [Test] Female Accuracy: 29.9525%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_9_balanced_best.pth ---
# [Test] Loss: 5.4409 Acc: 63.6292% Time: 62.2798s
# [Test] Male Accuracy: 98.9303%
# [Test] Female Accuracy: 28.3281%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.6\Controlled_Bias_0.6_10_balanced_best.pth ---
# [Test] Loss: 5.5327 Acc: 64.7187% Time: 63.0774s
# [Test] Male Accuracy: 98.6926%
# [Test] Female Accuracy: 30.7448%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_1_balanced_best.pth ---
# [Test] Loss: 1.4108 Acc: 76.1886% Time: 62.1525s
# [Test] Male Accuracy: 97.8605%
# [Test] Female Accuracy: 54.5166%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_2_balanced_best.pth ---
# [Test] Loss: 2.6317 Acc: 67.8487% Time: 62.6246s
# [Test] Male Accuracy: 99.1284%
# [Test] Female Accuracy: 36.5689%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_3_balanced_best.pth ---
# [Test] Loss: 3.1610 Acc: 66.2441% Time: 62.3335s
# [Test] Male Accuracy: 99.1680%
# [Test] Female Accuracy: 33.3201%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_4_balanced_best.pth ---
# [Test] Loss: 3.5929 Acc: 66.0856% Time: 62.3425s
# [Test] Male Accuracy: 98.9303%
# [Test] Female Accuracy: 33.2409%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_5_balanced_best.pth ---
# [Test] Loss: 3.8914 Acc: 65.4120% Time: 61.7528s
# [Test] Male Accuracy: 98.9699%
# [Test] Female Accuracy: 31.8542%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_6_balanced_best.pth ---
# [Test] Loss: 3.4278 Acc: 68.6807% Time: 62.1551s
# [Test] Male Accuracy: 98.0983%
# [Test] Female Accuracy: 39.2631%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_7_balanced_best.pth ---
# [Test] Loss: 3.5845 Acc: 66.8185% Time: 62.5575s
# [Test] Male Accuracy: 98.8114%
# [Test] Female Accuracy: 34.8257%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_8_balanced_best.pth ---
# [Test] Loss: 4.1359 Acc: 65.6300% Time: 62.3335s
# [Test] Male Accuracy: 98.3360%
# [Test] Female Accuracy: 32.9239%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_9_balanced_best.pth ---
# [Test] Loss: 4.3718 Acc: 64.2037% Time: 62.5134s
# [Test] Male Accuracy: 98.9303%
# [Test] Female Accuracy: 29.4770%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_0.9\Controlled_Bias_0.9_10_balanced_best.pth ---
# [Test] Loss: 4.5977 Acc: 64.4414% Time: 62.1104s
# [Test] Male Accuracy: 98.4152%
# [Test] Female Accuracy: 30.4675%
# All experiments completed. Results saved to 'all_FixMatch_experiments_results.csv'.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import pandas as pd

# Function to display images
def imshow(input, title):
    input = input.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    plt.imshow(input)
    plt.title(title)
    plt.show()

# Define transformations
transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define paths
aaf_dataset_path = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset"
test_folders = {
    "East_Asian_Validation": os.path.join(aaf_dataset_path, "East_Asian_Validation"),  # FairFace East Asian validation
    "Balanced_Validation": os.path.join(aaf_dataset_path, "Balanced_Validation"),  # FairFace Multi-Race test
    "AAF_Validation": "../AAF-Dataset-Pseudo-Labeling-UDA/aaf_dataset/Balanced_Validation"  # AAF test
}

# Define model paths

data_path = "bias_training_data"

flexmatch_folders = [
    "bias_Gender_Balanced_Unlabeled_FlexMatch", # FlexMatch_{1-5}_best, FlexMatch_{1-3}_unbalanced_best
    "bias_Unlabeled_FlexMatch", # FlexMatch_{1-5}_best, FlexMatch_{1-3}_unbalanced_best
    "bias_Severe_Black_Bias_FlexMatch", # FlexMatch_{1-5}_best, FlexMatch_{1-3}_unbalanced_best
    "bias_Severe_Male_Gender_FlexMatch", # FlexMatch_{1-5}_best, FlexMatch_{1-3}_unbalanced_best
    "bias_Severe_East_Asian_Female_Bias_FlexMatch",# FlexMatch_{1-5}_best, FlexMatch_{1-3}_unbalanced_best
    "bias_Severe_East_Asian_Bias_FlexMatch",# FlexMatch_{1-5}_best
    "bias_Severe_Female_Gender_FlexMatch"# FlexMatch_{1-5}_best

]
flexmatch_folders = [os.path.join(data_path, folder) for folder in flexmatch_folders]

# Initialize results storage
results = []

# Load model
criterion = nn.CrossEntropyLoss()
model = models.resnet18(pretrained=True)
num_features = model.fc.in_features

# Loop over test folders
for test_name, test_folder in test_folders.items():
    print(f"--- Testing on {test_name} ---")

    # Load test dataset
    test_dataset = ImageFolder(test_folder, transform=transforms_val)
    test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True, num_workers=4)
    class_names = test_dataset.classes
    print('Class names:', class_names)

    for flexmatch_folder in flexmatch_folders:
        # Define model paths for the current folder
        model_paths = [os.path.join(flexmatch_folder, f"FlexMatch_{j}_best.pth") for j in range(1, 6)]
        # Check if either substring is in the folder name
        if "Severe_East_Asian_Bias" in flexmatch_folder or "Severe_Female_Gender" in flexmatch_folder:
            all_model_paths = model_paths
        else:
            model_paths_unbalanced = [os.path.join(flexmatch_folder, f"FlexMatch_{i}_unbalanced_best.pth") for i in range(1, 4)]
            all_model_paths = model_paths + model_paths_unbalanced
        
        print(all_model_paths)

        for model_path in all_model_paths:
            print(f"--- Testing model: {model_path} ---")

            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            state_dict = torch.load(model_path, map_location=device)
            filtered_state_dict = {k: v for k, v in state_dict.items() if not k.startswith("fc.")}
            model.load_state_dict(filtered_state_dict, strict=False)  # strict=False ignores missing layers
            # binary classification
            model.fc = nn.Linear(num_features, 2)

            model.to(device)
            model.eval()

            # Initialize metrics
            male_corrects = 0
            male_total = 0
            female_corrects = 0
            female_total = 0
            running_loss = 0.0
            running_corrects = 0

            start_time = time.time()

            # Test loop
            with torch.no_grad():
                for i, (inputs, labels) in enumerate(test_dataloader):
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    male_mask = labels == class_names.index('male')
                    female_mask = labels == class_names.index('female')

                    male_corrects += torch.sum(preds[male_mask] == labels[male_mask])
                    male_total += torch.sum(male_mask)

                    female_corrects += torch.sum(preds[female_mask] == labels[female_mask])
                    female_total += torch.sum(female_mask)

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                    if i == 0:
                        print('[Prediction Result Examples]')
                        pred_labels = [class_names[x] for x in preds]
                        # images = torchvision.utils.make_grid(inputs[:8])
                        # imshow(images.cpu(), title=pred_labels)

            # Calculate metrics
            male_acc = male_corrects.double() / male_total * 100. if male_total > 0 else 0
            female_acc = female_corrects.double() / female_total * 100. if female_total > 0 else 0
            epoch_loss = running_loss / len(test_dataset)
            epoch_acc = running_corrects / len(test_dataset) * 100.

            # Print results
            print(f'[Test] Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}% Time: {time.time() - start_time:.4f}s')
            print(f'[Test] Male Accuracy: {male_acc:.4f}%')
            print(f'[Test] Female Accuracy: {female_acc:.4f}%')

            # Save results
            results.append({
                "Dataset": test_name,
                "Model Folder": flexmatch_folder,
                "Model": model_path,
                "Loss": epoch_loss,
                "Accuracy": epoch_acc.item(),
                "Male Accuracy": male_acc.item(),
                "Female Accuracy": female_acc.item()
            })

# Save results to CSV
df = pd.DataFrame(results)
df.to_csv("all_FlexMatch_experiments_results.csv", index=False)
print("All experiments completed. Results saved to 'all_FlexMatch_experiments_results.csv'.")
# Out:
# --- Testing on East_Asian_Validation ---
# Class names: ['female', 'male']
# ['bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# C:\Users\haohu\AppData\Local\Temp\ipykernel_10120\2883745821.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# [Prediction Result Examples]
# [Test] Loss: 0.8274 Acc: 42.0645% Time: 32.5842s
# [Test] Male Accuracy: 10.1673%
# [Test] Female Accuracy: 74.1268%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5765 Acc: 72.4516% Time: 32.1051s
# [Test] Male Accuracy: 87.9022%
# [Test] Female Accuracy: 56.9211%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7237 Acc: 43.6774% Time: 31.6695s
# [Test] Male Accuracy: 29.3436%
# [Test] Female Accuracy: 58.0854%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7781 Acc: 51.9355% Time: 31.9934s
# [Test] Male Accuracy: 98.7130%
# [Test] Female Accuracy: 4.9159%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7380 Acc: 50.7097% Time: 31.5700s
# [Test] Male Accuracy: 99.4852%
# [Test] Female Accuracy: 1.6818%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6825 Acc: 55.6774% Time: 32.0205s
# [Test] Male Accuracy: 69.4981%
# [Test] Female Accuracy: 41.7853%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6640 Acc: 50.9032% Time: 31.8299s
# [Test] Male Accuracy: 99.3565%
# [Test] Female Accuracy: 2.1992%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.0025 Acc: 49.0968% Time: 32.2101s
# [Test] Male Accuracy: 0.2574%
# [Test] Female Accuracy: 98.1889%
# ['bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7817 Acc: 50.0645% Time: 32.0061s
# [Test] Male Accuracy: 0.6435%
# [Test] Female Accuracy: 99.7413%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7403 Acc: 42.7742% Time: 31.7765s
# [Test] Male Accuracy: 63.9640%
# [Test] Female Accuracy: 21.4748%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8988 Acc: 21.3548% Time: 32.0999s
# [Test] Male Accuracy: 21.6216%
# [Test] Female Accuracy: 21.0867%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7713 Acc: 49.4839% Time: 32.1032s
# [Test] Male Accuracy: 3.7323%
# [Test] Female Accuracy: 95.4722%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6767 Acc: 47.9355% Time: 32.2867s
# [Test] Male Accuracy: 36.8082%
# [Test] Female Accuracy: 59.1203%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6502 Acc: 60.7742% Time: 31.9601s
# [Test] Male Accuracy: 36.0360%
# [Test] Female Accuracy: 85.6404%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6046 Acc: 67.8064% Time: 31.7166s
# [Test] Male Accuracy: 67.6963%
# [Test] Female Accuracy: 67.9172%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6287 Acc: 59.8710% Time: 32.0236s
# [Test] Male Accuracy: 96.3964%
# [Test] Female Accuracy: 23.1565%
# ['bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7618 Acc: 42.8387% Time: 31.3992s
# [Test] Male Accuracy: 64.0927%
# [Test] Female Accuracy: 21.4748%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.0176 Acc: 32.5806% Time: 31.4915s
# [Test] Male Accuracy: 11.7117%
# [Test] Female Accuracy: 53.5576%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6002 Acc: 70.1290% Time: 31.8667s
# [Test] Male Accuracy: 64.3501%
# [Test] Female Accuracy: 75.9379%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.3467 Acc: 50.1290% Time: 31.9876s
# [Test] Male Accuracy: 100.0000%
# [Test] Female Accuracy: 0.0000%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8722 Acc: 49.8710% Time: 31.7429s
# [Test] Male Accuracy: 0.0000%
# [Test] Female Accuracy: 100.0000%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8045 Acc: 40.1290% Time: 31.7081s
# [Test] Male Accuracy: 57.1429%
# [Test] Female Accuracy: 23.0272%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9050 Acc: 31.6774% Time: 31.8099s
# [Test] Male Accuracy: 43.8867%
# [Test] Female Accuracy: 19.4049%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6165 Acc: 63.7419% Time: 31.7697s
# [Test] Male Accuracy: 79.6654%
# [Test] Female Accuracy: 47.7361%
# ['bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8313 Acc: 38.7097% Time: 31.5469s
# [Test] Male Accuracy: 10.1673%
# [Test] Female Accuracy: 67.3997%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6314 Acc: 59.0968% Time: 31.9206s
# [Test] Male Accuracy: 29.3436%
# [Test] Female Accuracy: 89.0039%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8126 Acc: 39.4839% Time: 31.7530s
# [Test] Male Accuracy: 32.0463%
# [Test] Female Accuracy: 46.9599%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7688 Acc: 50.7742% Time: 29.1910s
# [Test] Male Accuracy: 2.7027%
# [Test] Female Accuracy: 99.0944%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7017 Acc: 54.1936% Time: 31.8463s
# [Test] Male Accuracy: 87.0013%
# [Test] Female Accuracy: 21.2160%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9086 Acc: 34.9677% Time: 31.9499s
# [Test] Male Accuracy: 14.8005%
# [Test] Female Accuracy: 55.2393%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6769 Acc: 54.3226% Time: 32.0293s
# [Test] Male Accuracy: 12.2265%
# [Test] Female Accuracy: 96.6365%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6491 Acc: 51.6129% Time: 31.9832s
# [Test] Male Accuracy: 98.8417%
# [Test] Female Accuracy: 4.1397%
# ['bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7878 Acc: 44.7097% Time: 32.2333s
# [Test] Male Accuracy: 81.4672%
# [Test] Female Accuracy: 7.7620%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8305 Acc: 46.1290% Time: 31.9532s
# [Test] Male Accuracy: 4.6332%
# [Test] Female Accuracy: 87.8396%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7813 Acc: 47.4839% Time: 32.2935s
# [Test] Male Accuracy: 80.3089%
# [Test] Female Accuracy: 14.4890%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8287 Acc: 42.5806% Time: 32.3767s
# [Test] Male Accuracy: 65.1223%
# [Test] Female Accuracy: 19.9224%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8136 Acc: 43.9355% Time: 32.4067s
# [Test] Male Accuracy: 6.9498%
# [Test] Female Accuracy: 81.1125%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8155 Acc: 38.4516% Time: 32.0306s
# [Test] Male Accuracy: 24.1956%
# [Test] Female Accuracy: 52.7814%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6533 Acc: 56.6452% Time: 32.3820s
# [Test] Male Accuracy: 24.9678%
# [Test] Female Accuracy: 88.4864%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6612 Acc: 57.8710% Time: 32.0433s
# [Test] Male Accuracy: 90.3475%
# [Test] Female Accuracy: 25.2264%
# ['bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6628 Acc: 57.4839% Time: 32.9108s
# [Test] Male Accuracy: 88.6744%
# [Test] Female Accuracy: 26.1320%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7524 Acc: 48.7742% Time: 31.8765s
# [Test] Male Accuracy: 5.4054%
# [Test] Female Accuracy: 92.3674%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8789 Acc: 42.7097% Time: 32.2712s
# [Test] Male Accuracy: 3.8610%
# [Test] Female Accuracy: 81.7594%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7353 Acc: 51.4194% Time: 31.9258s
# [Test] Male Accuracy: 6.1776%
# [Test] Female Accuracy: 96.8952%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7225 Acc: 50.8387% Time: 32.4995s
# [Test] Male Accuracy: 91.6345%
# [Test] Female Accuracy: 9.8318%
# ['bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8827 Acc: 31.7419% Time: 32.1434s
# [Test] Male Accuracy: 37.5804%
# [Test] Female Accuracy: 25.8732%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6169 Acc: 65.6774% Time: 32.2101s
# [Test] Male Accuracy: 85.0708%
# [Test] Female Accuracy: 46.1837%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7910 Acc: 29.4839% Time: 31.8798s
# [Test] Male Accuracy: 33.5907%
# [Test] Female Accuracy: 25.3558%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9857 Acc: 34.2581% Time: 31.9430s
# [Test] Male Accuracy: 3.2175%
# [Test] Female Accuracy: 65.4592%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7040 Acc: 57.3548% Time: 32.1765s
# [Test] Male Accuracy: 97.5547%
# [Test] Female Accuracy: 16.9470%
# --- Testing on Balanced_Validation ---
# Class names: ['female', 'male']
# ['bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7147 Acc: 52.4755% Time: 101.1276s
# [Test] Male Accuracy: 30.1678%
# [Test] Female Accuracy: 78.1449%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5405 Acc: 70.2588% Time: 97.5359s
# [Test] Male Accuracy: 94.5671%
# [Test] Female Accuracy: 42.2872%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8264 Acc: 34.6213% Time: 100.8840s
# [Test] Male Accuracy: 9.1210%
# [Test] Female Accuracy: 63.9644%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6050 Acc: 67.9310% Time: 100.8488s
# [Test] Male Accuracy: 56.7359%
# [Test] Female Accuracy: 80.8132%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9607 Acc: 52.8654% Time: 101.5068s
# [Test] Male Accuracy: 97.3719%
# [Test] Female Accuracy: 1.6518%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6366 Acc: 63.2991% Time: 101.0909s
# [Test] Male Accuracy: 85.8436%
# [Test] Female Accuracy: 37.3571%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.1043 Acc: 25.8655% Time: 100.8006s
# [Test] Male Accuracy: 10.0486%
# [Test] Female Accuracy: 44.0661%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6423 Acc: 54.2125% Time: 100.8605s
# [Test] Male Accuracy: 97.7473%
# [Test] Female Accuracy: 4.1169%
# ['bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7639 Acc: 46.8274% Time: 107.1159s
# [Test] Male Accuracy: 4.9691%
# [Test] Female Accuracy: 94.9936%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5988 Acc: 72.5511% Time: 100.7683s
# [Test] Male Accuracy: 64.7747%
# [Test] Female Accuracy: 81.4994%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7641 Acc: 44.8304% Time: 100.5072s
# [Test] Male Accuracy: 25.0442%
# [Test] Female Accuracy: 67.5985%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.0811 Acc: 33.5815% Time: 97.8289s
# [Test] Male Accuracy: 3.1140%
# [Test] Female Accuracy: 68.6404%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8449 Acc: 49.7460% Time: 100.6335s
# [Test] Male Accuracy: 87.9196%
# [Test] Female Accuracy: 5.8196%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8212 Acc: 45.2086% Time: 100.1937s
# [Test] Male Accuracy: 7.6855%
# [Test] Female Accuracy: 88.3863%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.4984 Acc: 79.3218% Time: 100.8146s
# [Test] Male Accuracy: 78.6440%
# [Test] Female Accuracy: 80.1017%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.1522 Acc: 26.3145% Time: 100.3093s
# [Test] Male Accuracy: 7.9284%
# [Test] Female Accuracy: 47.4714%
# ['bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6781 Acc: 55.3232% Time: 100.4536s
# [Test] Male Accuracy: 99.2712%
# [Test] Female Accuracy: 4.7522%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7532 Acc: 44.6768% Time: 100.5171s
# [Test] Male Accuracy: 59.6069%
# [Test] Female Accuracy: 27.4968%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 1.0565 Acc: 53.5035% Time: 100.1758s
# [Test] Male Accuracy: 100.0000%
# [Test] Female Accuracy: 0.0000%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6672 Acc: 57.7927% Time: 100.9341s
# [Test] Male Accuracy: 54.7703%
# [Test] Female Accuracy: 61.2706%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6430 Acc: 58.5608% Time: 100.6672s
# [Test] Male Accuracy: 26.0601%
# [Test] Female Accuracy: 95.9593%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7257 Acc: 48.6234% Time: 97.3702s
# [Test] Male Accuracy: 54.0194%
# [Test] Female Accuracy: 42.4142%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6446 Acc: 60.9358% Time: 100.9712s
# [Test] Male Accuracy: 64.8852%
# [Test] Female Accuracy: 56.3914%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7448 Acc: 54.5551% Time: 101.0843s
# [Test] Male Accuracy: 22.7473%
# [Test] Female Accuracy: 91.1563%
# ['bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6356 Acc: 62.2474% Time: 100.7669s
# [Test] Male Accuracy: 83.7014%
# [Test] Female Accuracy: 37.5604%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6813 Acc: 55.7013% Time: 101.3344s
# [Test] Male Accuracy: 92.7562%
# [Test] Female Accuracy: 13.0623%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8896 Acc: 45.9530% Time: 101.4683s
# [Test] Male Accuracy: 2.2527%
# [Test] Female Accuracy: 96.2389%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8180 Acc: 46.7683% Time: 100.8607s
# [Test] Male Accuracy: 1.5239%
# [Test] Female Accuracy: 98.8310%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7506 Acc: 45.1377% Time: 101.0008s
# [Test] Male Accuracy: 34.8940%
# [Test] Female Accuracy: 56.9250%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6050 Acc: 66.6430% Time: 100.5359s
# [Test] Male Accuracy: 78.3569%
# [Test] Female Accuracy: 53.1639%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7872 Acc: 43.9088% Time: 101.3847s
# [Test] Male Accuracy: 25.9276%
# [Test] Female Accuracy: 64.5997%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6169 Acc: 61.3376% Time: 97.7419s
# [Test] Male Accuracy: 89.6201%
# [Test] Female Accuracy: 28.7929%
# ['bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6099 Acc: 65.4614% Time: 101.1442s
# [Test] Male Accuracy: 69.8542%
# [Test] Female Accuracy: 60.4066%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6759 Acc: 57.5919% Time: 100.9484s
# [Test] Male Accuracy: 79.1740%
# [Test] Female Accuracy: 32.7573%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9485 Acc: 37.4572% Time: 100.9441s
# [Test] Male Accuracy: 5.6316%
# [Test] Female Accuracy: 74.0788%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7981 Acc: 45.1731% Time: 101.1815s
# [Test] Male Accuracy: 74.1608%
# [Test] Female Accuracy: 11.8170%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9582 Acc: 30.4266% Time: 101.0955s
# [Test] Male Accuracy: 26.3251%
# [Test] Female Accuracy: 35.1461%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8875 Acc: 34.4795% Time: 100.4670s
# [Test] Male Accuracy: 24.5141%
# [Test] Female Accuracy: 45.9466%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7467 Acc: 54.8978% Time: 100.9243s
# [Test] Male Accuracy: 97.2173%
# [Test] Female Accuracy: 6.2008%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8092 Acc: 53.6098% Time: 100.5031s
# [Test] Male Accuracy: 99.8675%
# [Test] Female Accuracy: 0.3812%
# ['bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5822 Acc: 69.2662% Time: 100.5473s
# [Test] Male Accuracy: 72.9682%
# [Test] Female Accuracy: 65.0064%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9334 Acc: 37.7526% Time: 66.1887s
# [Test] Male Accuracy: 5.1899%
# [Test] Female Accuracy: 75.2224%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8062 Acc: 38.1071% Time: 67.8897s
# [Test] Male Accuracy: 61.3737%
# [Test] Female Accuracy: 11.3342%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8023 Acc: 46.9101% Time: 68.2403s
# [Test] Male Accuracy: 1.3472%
# [Test] Female Accuracy: 99.3393%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8000 Acc: 47.4418% Time: 63.6420s
# [Test] Male Accuracy: 6.1175%
# [Test] Female Accuracy: 94.9936%
# ['bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6927 Acc: 54.0707% Time: 57.2448s
# [Test] Male Accuracy: 22.6811%
# [Test] Female Accuracy: 90.1906%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9983 Acc: 34.8812% Time: 57.2310s
# [Test] Male Accuracy: 5.4329%
# [Test] Female Accuracy: 68.7675%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6884 Acc: 49.1788% Time: 53.8444s
# [Test] Male Accuracy: 15.0618%
# [Test] Female Accuracy: 88.4371%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9321 Acc: 46.4965% Time: 63.0629s
# [Test] Male Accuracy: 0.0000%
# [Test] Female Accuracy: 100.0000%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7459 Acc: 45.0549% Time: 67.2284s
# [Test] Male Accuracy: 76.2809%
# [Test] Female Accuracy: 9.1233%
# --- Testing on AAF_Validation ---
# Class names: ['female', 'male']
# ['bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Gender_Balanced_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9276 Acc: 43.4231% Time: 48.2975s
# [Test] Male Accuracy: 1.6640%
# [Test] Female Accuracy: 85.1823%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7685 Acc: 50.8122% Time: 48.2231s
# [Test] Male Accuracy: 100.0000%
# [Test] Female Accuracy: 1.6244%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8845 Acc: 27.1395% Time: 44.0092s
# [Test] Male Accuracy: 10.9746%
# [Test] Female Accuracy: 43.3043%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6071 Acc: 67.4921% Time: 43.0073s
# [Test] Male Accuracy: 94.9287%
# [Test] Female Accuracy: 40.0555%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7613 Acc: 43.3835% Time: 42.4601s
# [Test] Male Accuracy: 8.5975%
# [Test] Female Accuracy: 78.1696%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7588 Acc: 48.7124% Time: 44.1774s
# [Test] Male Accuracy: 87.2029%
# [Test] Female Accuracy: 10.2219%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7378 Acc: 45.4437% Time: 47.4114s
# [Test] Male Accuracy: 59.3899%
# [Test] Female Accuracy: 31.4976%
# --- Testing model: bias_training_data\bias_Gender_Balanced_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9013 Acc: 40.9469% Time: 38.3050s
# [Test] Male Accuracy: 4.0808%
# [Test] Female Accuracy: 77.8130%
# ['bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Unlabeled_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6904 Acc: 53.1894% Time: 51.2538s
# [Test] Male Accuracy: 12.9952%
# [Test] Female Accuracy: 93.3835%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7108 Acc: 50.1585% Time: 50.2932s
# [Test] Male Accuracy: 6.5769%
# [Test] Female Accuracy: 93.7401%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9613 Acc: 30.5468% Time: 43.4451s
# [Test] Male Accuracy: 47.7417%
# [Test] Female Accuracy: 13.3518%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.4950 Acc: 83.3597% Time: 48.4151s
# [Test] Male Accuracy: 89.6197%
# [Test] Female Accuracy: 77.0998%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7808 Acc: 29.7742% Time: 50.6182s
# [Test] Male Accuracy: 53.4865%
# [Test] Female Accuracy: 6.0618%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7150 Acc: 52.3970% Time: 44.6567s
# [Test] Male Accuracy: 85.3407%
# [Test] Female Accuracy: 19.4532%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6806 Acc: 52.9120% Time: 45.5588s
# [Test] Male Accuracy: 79.6355%
# [Test] Female Accuracy: 26.1886%
# --- Testing model: bias_training_data\bias_Unlabeled_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5695 Acc: 79.1799% Time: 44.6961s
# [Test] Male Accuracy: 67.7496%
# [Test] Female Accuracy: 90.6101%
# ['bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Black_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6932 Acc: 53.7639% Time: 50.0401s
# [Test] Male Accuracy: 61.4501%
# [Test] Female Accuracy: 46.0777%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6729 Acc: 57.7258% Time: 46.0263s
# [Test] Male Accuracy: 94.2552%
# [Test] Female Accuracy: 21.1965%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6533 Acc: 61.8661% Time: 49.4497s
# [Test] Male Accuracy: 81.1014%
# [Test] Female Accuracy: 42.6307%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6944 Acc: 52.4366% Time: 48.0800s
# [Test] Male Accuracy: 99.2868%
# [Test] Female Accuracy: 5.5864%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8194 Acc: 48.7916% Time: 39.9191s
# [Test] Male Accuracy: 1.8621%
# [Test] Female Accuracy: 95.7211%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7615 Acc: 51.6046% Time: 55.9945s
# [Test] Male Accuracy: 99.0095%
# [Test] Female Accuracy: 4.1997%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7157 Acc: 53.4073% Time: 57.7155s
# [Test] Male Accuracy: 29.0016%
# [Test] Female Accuracy: 77.8130%
# --- Testing model: bias_training_data\bias_Severe_Black_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9098 Acc: 37.5594% Time: 60.7151s
# [Test] Male Accuracy: 55.5468%
# [Test] Female Accuracy: 19.5721%
# ['bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_Male_Gender_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6411 Acc: 62.9160% Time: 46.7597s
# [Test] Male Accuracy: 52.6149%
# [Test] Female Accuracy: 73.2171%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8001 Acc: 49.9802% Time: 44.5813s
# [Test] Male Accuracy: 1.6640%
# [Test] Female Accuracy: 98.2964%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7490 Acc: 44.0769% Time: 45.1786s
# [Test] Male Accuracy: 76.6640%
# [Test] Female Accuracy: 11.4897%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8178 Acc: 30.1704% Time: 47.5363s
# [Test] Male Accuracy: 17.8685%
# [Test] Female Accuracy: 42.4723%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8786 Acc: 45.8796% Time: 47.5196s
# [Test] Male Accuracy: 1.9810%
# [Test] Female Accuracy: 89.7781%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7324 Acc: 54.1601% Time: 46.4047s
# [Test] Male Accuracy: 19.0174%
# [Test] Female Accuracy: 89.3027%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8884 Acc: 35.8360% Time: 46.7140s
# [Test] Male Accuracy: 6.8146%
# [Test] Female Accuracy: 64.8574%
# --- Testing model: bias_training_data\bias_Severe_Male_Gender_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6427 Acc: 53.9818% Time: 42.4234s
# [Test] Male Accuracy: 97.3851%
# [Test] Female Accuracy: 10.5784%
# ['bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_5_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_1_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_2_unbalanced_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Female_Bias_FlexMatch\\FlexMatch_3_unbalanced_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7594 Acc: 46.8700% Time: 43.5734s
# [Test] Male Accuracy: 73.8114%
# [Test] Female Accuracy: 19.9287%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.5782 Acc: 71.8701% Time: 41.5568s
# [Test] Male Accuracy: 83.4390%
# [Test] Female Accuracy: 60.3011%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7276 Acc: 45.5824% Time: 50.0289s
# [Test] Male Accuracy: 56.4580%
# [Test] Female Accuracy: 34.7068%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8211 Acc: 49.9604% Time: 41.8946s
# [Test] Male Accuracy: 0.2377%
# [Test] Female Accuracy: 99.6830%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7971 Acc: 50.6933% Time: 51.0233s
# [Test] Male Accuracy: 98.6529%
# [Test] Female Accuracy: 2.7338%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_1_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6892 Acc: 56.0420% Time: 46.4919s
# [Test] Male Accuracy: 76.0697%
# [Test] Female Accuracy: 36.0143%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_2_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7937 Acc: 50.3962% Time: 44.9980s
# [Test] Male Accuracy: 97.5436%
# [Test] Female Accuracy: 3.2488%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Female_Bias_FlexMatch\FlexMatch_3_unbalanced_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7743 Acc: 48.1775% Time: 46.7386s
# [Test] Male Accuracy: 6.6561%
# [Test] Female Accuracy: 89.6989%
# ['bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_East_Asian_Bias_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8422 Acc: 49.1878% Time: 45.4030s
# [Test] Male Accuracy: 3.2092%
# [Test] Female Accuracy: 95.1664%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8291 Acc: 41.5610% Time: 43.1269s
# [Test] Male Accuracy: 69.2155%
# [Test] Female Accuracy: 13.9065%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7750 Acc: 50.3170% Time: 43.0141s
# [Test] Male Accuracy: 99.9604%
# [Test] Female Accuracy: 0.6735%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8046 Acc: 50.0792% Time: 43.7523s
# [Test] Male Accuracy: 98.9303%
# [Test] Female Accuracy: 1.2282%
# --- Testing model: bias_training_data\bias_Severe_East_Asian_Bias_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7887 Acc: 50.4556% Time: 44.7932s
# [Test] Male Accuracy: 99.1680%
# [Test] Female Accuracy: 1.7433%
# ['bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_1_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_2_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_3_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_4_best.pth', 'bias_training_data\\bias_Severe_Female_Gender_FlexMatch\\FlexMatch_5_best.pth']
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_1_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7174 Acc: 51.5452% Time: 44.6844s
# [Test] Male Accuracy: 11.4897%
# [Test] Female Accuracy: 91.6006%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_2_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.8885 Acc: 47.9794% Time: 44.1431s
# [Test] Male Accuracy: 2.2583%
# [Test] Female Accuracy: 93.7005%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_3_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.7088 Acc: 54.1006% Time: 42.8874s
# [Test] Male Accuracy: 68.5024%
# [Test] Female Accuracy: 39.6989%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_4_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.9518 Acc: 50.0000% Time: 43.3233s
# [Test] Male Accuracy: 0.0000%
# [Test] Female Accuracy: 100.0000%
# --- Testing model: bias_training_data\bias_Severe_Female_Gender_FlexMatch\FlexMatch_5_best.pth ---
# [Prediction Result Examples]
# [Test] Loss: 0.6820 Acc: 52.5951% Time: 44.8283s
# [Test] Male Accuracy: 97.7813%
# [Test] Female Accuracy: 7.4089%
# All experiments completed. Results saved to 'all_FlexMatch_experiments_results.csv'.

# %%
# Test Phase
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import pandas as pd

# Function to display images
def imshow(input, title):
    input = input.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    plt.imshow(input)
    plt.title(title)
    plt.show()

# Define validation transforms
transforms_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define dataset paths
aaf_dataset_path = "../AAF-Dataset-Pseudo-Labeling-UDA/fairface_race_dataset"
balanced_east_asian_folder = os.path.join(aaf_dataset_path, "East_Asian_Validation")  # East Asian Validation dataset
balanced_val_folder = os.path.join(aaf_dataset_path, "Balanced_Validation")
balanced_test_folder = "../AAF-Dataset-Pseudo-Labeling-UDA/aaf_dataset/Balanced_Validation"

# Define models to evaluate
models_to_evaluate = [
    '../classification_model.pth',
    '../5epoch_fairface.pth',
    '../5epoch_fairface_5epoch_mixed.pth',
    '../5epoch_mixed.pth'
]

# Define datasets to evaluate
datasets_to_evaluate = {
    "East_Asian_Validation": balanced_east_asian_folder,
    "Balanced_Validation": balanced_val_folder,
    "Balanced_Test": balanced_test_folder,
}

# Initialize results list
results = []

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loop through each model
for model_path in models_to_evaluate:
    # Load the model
    model = models.resnet18(pretrained=True)
    model.fc = nn.Linear(model.fc.in_features, 2)  # Binary classification
    state_dict = torch.load(model_path, map_location=device)
    model.load_state_dict(state_dict)
    model.to(device)
    model.eval()

    # Loop through each dataset
    for dataset_name, dataset_path in datasets_to_evaluate.items():
        # Load the dataset
        dataset = ImageFolder(dataset_path, transform=transforms_val)
        dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=4)
        class_names = dataset.classes

        # Initialize metrics
        male_corrects = 0
        male_total = 0
        female_corrects = 0
        female_total = 0
        running_loss = 0.0
        running_corrects = 0

        # Evaluate the model on the dataset
        start_time = time.time()
        with torch.no_grad():
            for i, (inputs, labels) in enumerate(dataloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                male_mask = labels == class_names.index('male')
                female_mask = labels == class_names.index('female')

                male_corrects += torch.sum(preds[male_mask] == labels[male_mask])
                male_total += torch.sum(male_mask)
                female_corrects += torch.sum(preds[female_mask] == labels[female_mask])
                female_total += torch.sum(female_mask)

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                if i == 0:
                    print(f'[Prediction Result Examples for {model_path} on {dataset_name}]')
                    # pred_labels = [class_names[x] for x in preds]
                    # images = torchvision.utils.make_grid(inputs[:8])
                    # imshow(images.cpu(), title=pred_labels)

        # Compute metrics
        male_acc = male_corrects.double() / male_total * 100. if male_total > 0 else 0
        female_acc = female_corrects.double() / female_total * 100. if female_total > 0 else 0
        epoch_loss = running_loss / len(dataset)
        epoch_acc = running_corrects / len(dataset) * 100.

        # Print results
        print(f'[Validation] Model: {model_path}, Dataset: {dataset_name}')
        print(f'[Validation] Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}%, Time: {time.time() - start_time:.4f}s')
        print(f'[Validation] Male Accuracy: {male_acc:.4f}%')
        print(f'[Validation] Female Accuracy: {female_acc:.4f}%')

        # Save results
        results.append([model_path, dataset_name, epoch_loss, epoch_acc, male_acc.item(), female_acc.item()])

# Save results to CSV
df = pd.DataFrame(results, columns=["Model", "Dataset", "Loss", "Accuracy", "Male Accuracy", "Female Accuracy"])
df.to_csv("model_evaluation_results.csv", index=False)
print("Results saved to model_evaluation_results.csv")
# Out:
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\haohu\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\haohu\AppData\Local\Temp\ipykernel_10120\151564472.py:66: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# [Prediction Result Examples for ../classification_model.pth on East_Asian_Validation]
# [Validation] Model: ../classification_model.pth, Dataset: East_Asian_Validation
# [Validation] Loss: 0.4813, Acc: 77.9355%, Time: 36.5609s
# [Validation] Male Accuracy: 85.9717%
# [Validation] Female Accuracy: 69.8577%
# [Prediction Result Examples for ../classification_model.pth on Balanced_Validation]
# [Validation] Model: ../classification_model.pth, Dataset: Balanced_Validation
# [Validation] Loss: 0.5048, Acc: 76.4032%, Time: 111.6237s
# [Validation] Male Accuracy: 86.6387%
# [Validation] Female Accuracy: 64.6252%
# [Prediction Result Examples for ../classification_model.pth on Balanced_Test]
# [Validation] Model: ../classification_model.pth, Dataset: Balanced_Test
# [Validation] Loss: 0.6715, Acc: 73.2766%, Time: 53.0309s
# [Validation] Male Accuracy: 97.9398%
# [Validation] Female Accuracy: 48.6133%
# [Prediction Result Examples for ../5epoch_fairface.pth on East_Asian_Validation]
# [Validation] Model: ../5epoch_fairface.pth, Dataset: East_Asian_Validation
# [Validation] Loss: 0.1788, Acc: 93.4194%, Time: 25.3350s
# [Validation] Male Accuracy: 93.1789%
# [Validation] Female Accuracy: 93.6611%
# [Prediction Result Examples for ../5epoch_fairface.pth on Balanced_Validation]
# [Validation] Model: ../5epoch_fairface.pth, Dataset: Balanced_Validation
# [Validation] Loss: 0.1771, Acc: 92.7094%, Time: 61.2263s
# [Validation] Male Accuracy: 93.5954%
# [Validation] Female Accuracy: 91.6900%
# [Prediction Result Examples for ../5epoch_fairface.pth on Balanced_Test]
# [Validation] Model: ../5epoch_fairface.pth, Dataset: Balanced_Test
# [Validation] Loss: 0.3202, Acc: 87.5396%, Time: 57.0367s
# [Validation] Male Accuracy: 95.3645%
# [Validation] Female Accuracy: 79.7147%
# [Prediction Result Examples for ../5epoch_fairface_5epoch_mixed.pth on East_Asian_Validation]
# [Validation] Model: ../5epoch_fairface_5epoch_mixed.pth, Dataset: East_Asian_Validation
# [Validation] Loss: 0.3191, Acc: 87.4194%, Time: 32.7499s
# [Validation] Male Accuracy: 84.4273%
# [Validation] Female Accuracy: 90.4269%
# [Prediction Result Examples for ../5epoch_fairface_5epoch_mixed.pth on Balanced_Validation]
# [Validation] Model: ../5epoch_fairface_5epoch_mixed.pth, Dataset: Balanced_Validation
# [Validation] Loss: 0.3349, Acc: 87.4867%, Time: 98.5988s
# [Validation] Male Accuracy: 87.9638%
# [Validation] Female Accuracy: 86.9377%
# [Prediction Result Examples for ../5epoch_fairface_5epoch_mixed.pth on Balanced_Test]
# [Validation] Model: ../5epoch_fairface_5epoch_mixed.pth, Dataset: Balanced_Test
# [Validation] Loss: 0.1530, Acc: 96.2163%, Time: 65.0977s
# [Validation] Male Accuracy: 96.1965%
# [Validation] Female Accuracy: 96.2361%
# [Prediction Result Examples for ../5epoch_mixed.pth on East_Asian_Validation]
# [Validation] Model: ../5epoch_mixed.pth, Dataset: East_Asian_Validation
# [Validation] Loss: 0.5733, Acc: 77.4839%, Time: 31.7431s
# [Validation] Male Accuracy: 77.7349%
# [Validation] Female Accuracy: 77.2316%
# [Prediction Result Examples for ../5epoch_mixed.pth on Balanced_Validation]
# [Validation] Model: ../5epoch_mixed.pth, Dataset: Balanced_Validation
# [Validation] Loss: 0.6198, Acc: 76.9940%, Time: 98.9381s
# [Validation] Male Accuracy: 82.9947%
# [Validation] Female Accuracy: 70.0889%
# [Prediction Result Examples for ../5epoch_mixed.pth on Balanced_Test]
# [Validation] Model: ../5epoch_mixed.pth, Dataset: Balanced_Test
# [Validation] Loss: 0.1550, Acc: 95.1664%, Time: 65.7990s
# [Validation] Male Accuracy: 93.9382%
# [Validation] Female Accuracy: 96.3946%
# Results saved to model_evaluation_results.csv
